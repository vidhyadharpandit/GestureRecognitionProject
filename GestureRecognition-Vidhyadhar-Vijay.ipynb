# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.18.0-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Collecting tensorflow-intel==2.18.0 (from tensorflow)
#   Downloading tensorflow_intel-2.18.0-cp312-cp312-win_amd64.whl.metadata (4.9 kB)
# Collecting absl-py>=1.0.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading termcolor-2.5.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.14.1)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading grpcio-1.67.1-cp312-cp312-win_amd64.whl.metadata (4.0 kB)
# Collecting tensorboard<2.19,>=2.18 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras>=3.5.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading keras-3.6.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.11.0)
# Collecting ml-dtypes<0.5.0,>=0.4.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading ml_dtypes-0.4.1-cp312-cp312-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\admin\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\admin\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.7.1)
# Collecting namex (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow)
#   Downloading namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Collecting optree (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow)
#   Downloading optree-0.13.0-cp312-cp312-win_amd64.whl.metadata (48 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\admin\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\admin\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\admin\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\admin\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.0)
# Downloading tensorflow-2.18.0-cp312-cp312-win_amd64.whl (7.5 kB)
# Downloading tensorflow_intel-2.18.0-cp312-cp312-win_amd64.whl (390.3 MB)
#    ---------------------------------------- 0.0/390.3 MB ? eta -:--:--
#    ------ -------------------------------- 66.8/390.3 MB 328.0 MB/s eta 0:00:01
#    ------------ ------------------------- 131.6/390.3 MB 322.7 MB/s eta 0:00:01
#    ------------------- ------------------ 204.5/390.3 MB 334.8 MB/s eta 0:00:01
#    -------------------------- ----------- 269.5/390.3 MB 322.5 MB/s eta 0:00:01
#    -------------------------------- ----- 333.4/390.3 MB 322.1 MB/s eta 0:00:01
#    -------------------------------------  390.1/390.3 MB 316.3 MB/s eta 0:00:01
#    -------------------------------------  390.1/390.3 MB 316.3 MB/s eta 0:00:01
#    -------------------------------------  390.1/390.3 MB 316.3 MB/s eta 0:00:01
#    -------------------------------------  390.1/390.3 MB 316.3 MB/s eta 0:00:01
#    -------------------------------------  390.1/390.3 MB 316.3 MB/s eta 0:00:01
#    -------------------------------------  390.1/390.3 MB 316.3 MB/s eta 0:00:01
#    -------------------------------------  390.1/390.3 MB 316.3 MB/s eta 0:00:01
#    -------------------------------------  390.1/390.3 MB 316.3 MB/s eta 0:00:01
#    -------------------------------------  390.1/390.3 MB 316.3 MB/s eta 0:00:01
#    -------------------------------------  390.1/390.3 MB 316.3 MB/s eta 0:00:01
#    -------------------------------------  390.1/390.3 MB 316.3 MB/s eta 0:00:01
#    -------------------------------------  390.1/390.3 MB 316.3 MB/s eta 0:00:01
#    -------------------------------------  390.1/390.3 MB 316.3 MB/s eta 0:00:01
#    -------------------------------------  390.1/390.3 MB 316.3 MB/s eta 0:00:01
#    -------------------------------------  390.1/390.3 MB 316.3 MB/s eta 0:00:01
#    -------------------------------------  390.1/390.3 MB 316.3 MB/s eta 0:00:01
#    --------------------------------------- 390.3/390.3 MB 62.8 MB/s eta 0:00:00
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading grpcio-1.67.1-cp312-cp312-win_amd64.whl (4.3 MB)
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ---------------------------------------- 4.3/4.3 MB 255.3 MB/s eta 0:00:00
# Downloading keras-3.6.0-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 58.1 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
#    ---------------------------------------- 0.0/26.4 MB ? eta -:--:--
#    ---------------------------------------- 26.4/26.4 MB 166.6 MB/s eta 0:00:00
# Downloading ml_dtypes-0.4.1-cp312-cp312-win_amd64.whl (127 kB)
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ---------------------------------------- 5.5/5.5 MB 169.1 MB/s eta 0:00:00
# Downloading termcolor-2.5.0-py3-none-any.whl (7.8 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading optree-0.13.0-cp312-cp312-win_amd64.whl (283 kB)
# Installing collected packages: namex, libclang, flatbuffers, termcolor, tensorboard-data-server, optree, opt-einsum, ml-dtypes, grpcio, google-pasta, gast, astunparse, absl-py, tensorboard, keras, tensorflow-intel, tensorflow
# Successfully installed absl-py-2.1.0 astunparse-1.6.3 flatbuffers-24.3.25 gast-0.6.0 google-pasta-0.2.0 grpcio-1.67.1 keras-3.6.0 libclang-18.1.1 ml-dtypes-0.4.1 namex-0.0.8 opt-einsum-3.4.0 optree-0.13.0 tensorboard-2.18.0 tensorboard-data-server-0.7.2 tensorflow-2.18.0 tensorflow-intel-2.18.0 termcolor-2.5.0

# %%
# !pip3 install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\admin\anaconda3\lib\site-packages (from opencv-python) (1.26.4)
# Downloading opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------  38.8/38.8 MB 275.3 MB/s eta 0:00:01
#    ---------------------------------------- 38.8/38.8 MB 123.7 MB/s eta 0:00:00
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.10.0.84

# %%
import numpy as np
import os
# from scipy.misc import imread, imresize
import datetime
import os
import tensorflow as tf
from imageio import imread
import cv2

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K

tf.random.set_seed(30)

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
train_doc = np.random.permutation(open(r'C:\Users\admin\Vidhya\Project_data\train.csv').readlines())
val_doc = np.random.permutation(open(r'C:\Users\admin\Vidhya\Project_data\val.csv').readlines())
batch_size = 10 #experiment with the batch size

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
#Set the parameters, should be used in model architecture also

#More images
start_frames = [1, 2, 3, 6]  # Gesture initiation
middle_frames = [8, 9, 10, 14, 15, 16, 17, 20]  # Early movement & middle
end_frames = [22, 23, 24, 25, 26, 27, 28, 29]  # Gesture completion

# Combine selected frames
img_idx = start_frames + middle_frames + end_frames


y, z = 128, 128  # Desired height and width
target_size = (y, z)
x = len(img_idx)  # Number of frames per video
print(x)
print(img_idx)
# Out:
# 20
# [1, 2, 3, 6, 8, 9, 10, 14, 15, 16, 17, 20, 22, 23, 24, 25, 26, 27, 28, 29]

# %%
def generator(source_path, folder_list, batch_size):
    print('Source path =', source_path, '; batch size =', batch_size)

    #print('Source path =', source_path, '; batch size =', batch_size)
    print('Number of folders:', len(folder_list))  # Debug print
    
    # Validate inputs
    if folder_list.size == 0:  # Check if folder_list is empty
        raise ValueError("folder_list is empty")
    

    
    #if not os.path.exists(source_path):
    #    raise ValueError(f"Source path does not exist: {source_path}")
    
    #img_idx = [1,5,6,7,8,9,13,15,17,20,22,24,25,27,30]
    img_idx = [1, 2, 3, 6, 8, 9, 10, 14, 15, 16, 17, 20, 22, 23, 24, 25, 26, 27, 28, 29]
    #img_idx = [1, 2, 3, 5, 6, 8, 9, 10, 13, 14, 15, 16, 18, 20, 22, 23, 24, 25, 26, 27, 28, 29]
    
    y, z = 128, 128  # Desired height and width
    target_size = (y, z)
    x = len(img_idx)  # Number of frames per video

    
    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(folder_list) // batch_size
        
        for batch in range(num_batches):
            batch_data = np.zeros((batch_size, x, y, z, 3))
            batch_labels = np.zeros((batch_size, 5))
            
            for folder in range(batch_size):
                #folder_path = os.path.normpath((os.path.join(source_path, t[folder + (batch * batch_size)].strip().split(';')[0])))
                folder_name = t[folder + (batch * batch_size)].strip().split(';')[0]
                folder_path = os.path.join(source_path, folder_name)
                folder_path = os.path.normpath(folder_path)  # Ensure a consistent path format

                imgs = os.listdir(folder_path)
                
                for idx, item in enumerate(img_idx):
                    if item >= len(imgs):
                        print(f"Warning: Frame {item} not found in folder, skipping...")
                        continue
                    
                    image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
                    
                    # Crop to square and resize
                    if image.shape[1] > image.shape[0]:
                        crop_start = (image.shape[1] - image.shape[0]) // 2
                        crop_end = crop_start + image.shape[0]
                        image = image[:, crop_start:crop_end]
                    elif image.shape[0] > image.shape[1]:
                        crop_start = (image.shape[0] - image.shape[1]) // 2
                        crop_end = crop_start + image.shape[1]
                        image = image[crop_start:crop_end, :]

                    image_resized = cv2.resize(image, target_size, interpolation=cv2.INTER_LINEAR)

                    # Augmentation: Horizontal flip and brightness adjustment
                    if rn.choice([True, False]):  # Random horizontal flip
                        image_resized = cv2.flip(image_resized, 1)
                    
                    brightness_factor = 0.8 + 0.4 * rn.random()  # Random brightness factor
                    image_resized = np.clip(image_resized * brightness_factor, 0, 255)

                    # Normalize each channel
                    mean_r, mean_g, mean_b = image_resized[:, :, 0].mean(), image_resized[:, :, 1].mean(), image_resized[:, :, 2].mean()
                    std_r, std_g, std_b = image_resized[:, :, 0].std(), image_resized[:, :, 1].std(), image_resized[:, :, 2].std()

                    batch_data[folder, idx, :, :, 0] = (image_resized[:, :, 0] - mean_r) / (std_r + 1e-7)
                    batch_data[folder, idx, :, :, 1] = (image_resized[:, :, 1] - mean_g) / (std_g + 1e-7)
                    batch_data[folder, idx, :, :, 2] = (image_resized[:, :, 2] - mean_b) / (std_b + 1e-7)
                
                # Set one-hot encoded label
                label_index = int(t[folder + (batch * batch_size)].strip().split(';')[2])
                batch_labels[folder, label_index] = 1
            
            yield batch_data, batch_labels  # Yield the batch

        # Process remaining data points
        remaining_datapoints = len(folder_list) % batch_size
        if remaining_datapoints > 0:
            batch_data = np.zeros((remaining_datapoints, x, y, z, 3))
            batch_labels = np.zeros((remaining_datapoints, 5))
            start_index = num_batches * batch_size
            
            for folder in range(remaining_datapoints):
                #folder_path = os.path.normpath(os.path.join(source_path, t[folder + start_index].strip().split(';')[0]))
                folder_name = t[folder + start_index].strip().split(';')[0]
                folder_path = os.path.join(source_path, folder_name)
                folder_path = os.path.normpath(folder_path)  # Ensure a consistent path format

                imgs = os.listdir(folder_path)
                
                for idx, item in enumerate(img_idx):
                    if item >= len(imgs):
                        print(f"Warning: Frame {item} not found in folder, skipping...")
                        continue
                    
                    image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
                    
                    # Crop to square and resize
                    if image.shape[1] > image.shape[0]:
                        crop_start = (image.shape[1] - image.shape[0]) // 2
                        crop_end = crop_start + image.shape[0]
                        image = image[:, crop_start:crop_end]
                    elif image.shape[0] > image.shape[1]:
                        crop_start = (image.shape[0] - image.shape[1]) // 2
                        crop_end = crop_start + image.shape[1]
                        image = image[crop_start:crop_end, :]

                    image_resized = cv2.resize(image, target_size, interpolation=cv2.INTER_LINEAR)

                    # Augmentation
                    if rn.choice([True, False]):
                        image_resized = cv2.flip(image_resized, 1)
                    
                    brightness_factor = 0.8 + 0.4 * rn.random()
                    image_resized = np.clip(image_resized * brightness_factor, 0, 255)

                    # Normalize each channel
                    mean_r, mean_g, mean_b = image_resized[:, :, 0].mean(), image_resized[:, :, 1].mean(), image_resized[:, :, 2].mean()
                    std_r, std_g, std_b = image_resized[:, :, 0].std(), image_resized[:, :, 1].std(), image_resized[:, :, 2].std()

                    batch_data[folder, idx, :, :, 0] = (image_resized[:, :, 0] - mean_r) / (std_r + 1e-7)
                    batch_data[folder, idx, :, :, 1] = (image_resized[:, :, 1] - mean_g) / (std_g + 1e-7)
                    batch_data[folder, idx, :, :, 2] = (image_resized[:, :, 2] - mean_b) / (std_b + 1e-7)
                
                label_index = int(t[folder + start_index].strip().split(';')[2])
                batch_labels[folder, label_index] = 1
            
            yield batch_data, batch_labels  # Yield the remaining batch

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = r'C:\Users\admin\Vidhya\Project_data\train'
val_path = r'C:\Users\admin\Vidhya\Project_data\val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 20
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 20

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout, LSTM
# from keras.layers.convolutional import Conv3D, MaxPooling3D
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Conv3D, MaxPooling3D

from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout, LSTM
# from keras.layers.convolutional import Conv3D, MaxPooling3D
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Conv3D, MaxPooling3D

from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers

#write your model here

# Define input shape (frames, height, width, channels)
input_shape = (15, 128, 128, 3)
num_classes = 5

model = Sequential()

# First Conv2D Block - More aggressive pooling
model.add(TimeDistributed(Conv2D(16, (3, 3), padding='same'), input_shape=input_shape))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(Activation('relu')))
model.add(TimeDistributed(MaxPooling2D((4, 4))))  # More aggressive pooling

# Second Conv2D Block
model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(Activation('relu')))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Dropout(0.25)))

# Flatten and LSTM
model.add(TimeDistributed(Flatten()))
model.add(LSTM(64))
model.add(Dense(num_classes, activation='softmax'))

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = 'adam'
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed_15             │ (None, 15, 128, 128,   │           448 │
# │ (TimeDistributed)               │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_16             │ (None, 15, 128, 128,   │            64 │
# │ (TimeDistributed)               │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_17             │ (None, 15, 128, 128,   │             0 │
# │ (TimeDistributed)               │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_18             │ (None, 15, 32, 32, 16) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_19             │ (None, 15, 32, 32, 32) │         4,640 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_20             │ (None, 15, 32, 32, 32) │           128 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_21             │ (None, 15, 32, 32, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_22             │ (None, 15, 16, 16, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_23             │ (None, 15, 16, 16, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_24             │ (None, 15, 8192)       │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │     2,113,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,119,397 (8.08 MB)
#  Trainable params: 2,119,301 (8.08 MB)
#  Non-trainable params: 96 (384.00 B)
# None

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'

if not os.path.exists(model_name):
    os.mkdir(model_name)

#filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.keras'

#checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', save_freq='epoch')

#LR = # write the REducelronplateau code here
LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-6, verbose=1)
callbacks_list = [checkpoint, LR]

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

print(steps_per_epoch,validation_steps)
# Out:
# 67 10

# %%
# At the start of your script, let's print folder contents
#print("Checking paths and data...")
#print(f"Train path exists: {os.path.exists(train_path)}")
"""print(f"Val path exists: {os.path.exists(val_path)}")
print(f"Length of train_doc: {len(train_doc)}")
print(f"Length of val_doc: {len(val_doc)}")
print(type(train_doc))
#print(train_doc)

# Before creating generators, let's verify batch_size is defined
if 'batch_size' not in locals():
    batch_size = 32  # or whatever default you want
print(f"Batch size: {batch_size}")

# Let's modify your generator creation to include try-except
try:
    print("Creating train generator...")
    train_generator = generator(train_path, train_doc, batch_size)
    # Verify generator works by getting first batch
    print("Testing train generator...")
    first_batch = next(train_generator)
    print("Train generator successfully created and tested")
except Exception as e:
    print(f"Error with train generator: {str(e)}")
    raise

try:
    print("Creating validation generator...")
    val_generator = generator(val_path, val_doc, batch_size)
    # Verify generator works by getting first batch
    print("Testing validation generator...")
    first_batch = next(val_generator)
    print("Validation generator successfully created and tested")
except Exception as e:
    print(f"Error with validation generator: {str(e)}")
    raise

# Print your steps calculations
print(f"Number of train sequences: {num_train_sequences}")
print(f"Number of val sequences: {num_val_sequences}")
print(f"Calculated steps_per_epoch: {steps_per_epoch}")
print(f"Calculated validation_steps: {validation_steps}")

# Then proceed with your model.fit()"""
# Out:
# 'print(f"Val path exists: {os.path.exists(val_path)}")\nprint(f"Length of train_doc: {len(train_doc)}")\nprint(f"Length of val_doc: {len(val_doc)}")\nprint(type(train_doc))\n#print(train_doc)\n\n# Before creating generators, let\'s verify batch_size is defined\nif \'batch_size\' not in locals():\n    batch_size = 32  # or whatever default you want\nprint(f"Batch size: {batch_size}")\n\n# Let\'s modify your generator creation to include try-except\ntry:\n    print("Creating train generator...")\n    train_generator = generator(train_path, train_doc, batch_size)\n    # Verify generator works by getting first batch\n    print("Testing train generator...")\n    first_batch = next(train_generator)\n    print("Train generator successfully created and tested")\nexcept Exception as e:\n    print(f"Error with train generator: {str(e)}")\n    raise\n\ntry:\n    print("Creating validation generator...")\n    val_generator = generator(val_path, val_doc, batch_size)\n    # Verify generator works by getting first batch\n    print("Testing validation generator...")\n    first_batch = next(val_generator)\n    print("Validation generator successfully created and tested")\nexcept Exception as e:\n    print(f"Error with validation generator: {str(e)}")\n    raise\n\n# Print your steps calculations\nprint(f"Number of train sequences: {num_train_sequences}")\nprint(f"Number of val sequences: {num_val_sequences}")\nprint(f"Calculated steps_per_epoch: {steps_per_epoch}")\nprint(f"Calculated validation_steps: {validation_steps}")\n\n# Then proceed with your model.fit()'

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, initial_epoch=0)
# Out:
# Source path = C:\Users\admin\Vidhya\Project_data\train ; batch size = 10
# Number of folders: 663
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_5248\950058156.py:46: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# Epoch 1/20
# 65/67 ━━━━━━━━━━━━━━━━━━━━ 5s 3s/step - categorical_accuracy: 0.2202 - loss: 1.7386
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_5248\950058156.py:101: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.2194 - loss: 1.7370Source path = C:\Users\admin\Vidhya\Project_data\val ; batch size = 10
# Number of folders: 100
#
# Epoch 1: saving model to model_init_2024-11-0804_40_40.716983/model-00001-1.68358-0.19457-1.60495-0.18000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 234s 3s/step - categorical_accuracy: 0.2191 - loss: 1.7362 - val_categorical_accuracy: 0.1800 - val_loss: 1.6050 - learning_rate: 0.0010
# Epoch 2/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2201 - loss: 1.6111
# Epoch 2: saving model to model_init_2024-11-0804_40_40.716983/model-00002-1.63106-0.21116-1.57833-0.24000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - categorical_accuracy: 0.2200 - loss: 1.6114 - val_categorical_accuracy: 0.2400 - val_loss: 1.5783 - learning_rate: 0.0010
# Epoch 3/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.2624 - loss: 1.5847
# Epoch 3: saving model to model_init_2024-11-0804_40_40.716983/model-00003-1.57980-0.28205-1.59410-0.25000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 109s 2s/step - categorical_accuracy: 0.2627 - loss: 1.5846 - val_categorical_accuracy: 0.2500 - val_loss: 1.5941 - learning_rate: 0.0010
# Epoch 4/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.2702 - loss: 1.5782
# Epoch 4: saving model to model_init_2024-11-0804_40_40.716983/model-00004-1.57828-0.29864-1.56583-0.34000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 102s 2s/step - categorical_accuracy: 0.2706 - loss: 1.5782 - val_categorical_accuracy: 0.3400 - val_loss: 1.5658 - learning_rate: 0.0010
# Epoch 5/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.3261 - loss: 1.5345
# Epoch 5: saving model to model_init_2024-11-0804_40_40.716983/model-00005-1.52919-0.34087-1.57343-0.32000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - categorical_accuracy: 0.3263 - loss: 1.5344 - val_categorical_accuracy: 0.3200 - val_loss: 1.5734 - learning_rate: 0.0010
# Epoch 6/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.3597 - loss: 1.5456
# Epoch 6: saving model to model_init_2024-11-0804_40_40.716983/model-00006-1.53248-0.35143-1.50593-0.39000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - categorical_accuracy: 0.3596 - loss: 1.5454 - val_categorical_accuracy: 0.3900 - val_loss: 1.5059 - learning_rate: 0.0010
# Epoch 7/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.3756 - loss: 1.4922
# Epoch 7: saving model to model_init_2024-11-0804_40_40.716983/model-00007-1.49093-0.38763-1.50069-0.41000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - categorical_accuracy: 0.3757 - loss: 1.4922 - val_categorical_accuracy: 0.4100 - val_loss: 1.5007 - learning_rate: 0.0010
# Epoch 8/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.3921 - loss: 1.4982
# Epoch 8: saving model to model_init_2024-11-0804_40_40.716983/model-00008-1.49675-0.38311-1.46526-0.40000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - categorical_accuracy: 0.3919 - loss: 1.4982 - val_categorical_accuracy: 0.4000 - val_loss: 1.4653 - learning_rate: 0.0010
# Epoch 9/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.4477 - loss: 1.4506
# Epoch 9: saving model to model_init_2024-11-0804_40_40.716983/model-00009-1.45697-0.42383-1.41900-0.52000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - categorical_accuracy: 0.4474 - loss: 1.4507 - val_categorical_accuracy: 0.5200 - val_loss: 1.4190 - learning_rate: 0.0010
# Epoch 10/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.4819 - loss: 1.4070
# Epoch 10: saving model to model_init_2024-11-0804_40_40.716983/model-00010-1.43650-0.43288-1.43102-0.47000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 109s 2s/step - categorical_accuracy: 0.4812 - loss: 1.4075 - val_categorical_accuracy: 0.4700 - val_loss: 1.4310 - learning_rate: 0.0010
# Epoch 11/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.4955 - loss: 1.3891
# Epoch 11: saving model to model_init_2024-11-0804_40_40.716983/model-00011-1.38854-0.48567-1.38039-0.48000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 109s 2s/step - categorical_accuracy: 0.4954 - loss: 1.3891 - val_categorical_accuracy: 0.4800 - val_loss: 1.3804 - learning_rate: 0.0010
# Epoch 12/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.5504 - loss: 1.3432
# Epoch 12: saving model to model_init_2024-11-0804_40_40.716983/model-00012-1.36300-0.53544-1.40472-0.46000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 109s 2s/step - categorical_accuracy: 0.5501 - loss: 1.3435 - val_categorical_accuracy: 0.4600 - val_loss: 1.4047 - learning_rate: 0.0010
# Epoch 13/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.5601 - loss: 1.3297
# Epoch 13: saving model to model_init_2024-11-0804_40_40.716983/model-00013-1.35436-0.52640-1.39499-0.44000.keras
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 109s 2s/step - categorical_accuracy: 0.5596 - loss: 1.3301 - val_categorical_accuracy: 0.4400 - val_loss: 1.3950 - learning_rate: 0.0010
# Epoch 14/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.5344 - loss: 1.3307
# Epoch 14: saving model to model_init_2024-11-0804_40_40.716983/model-00014-1.31108-0.54600-1.33832-0.51000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 108s 2s/step - categorical_accuracy: 0.5346 - loss: 1.3304 - val_categorical_accuracy: 0.5100 - val_loss: 1.3383 - learning_rate: 5.0000e-04
# Epoch 15/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.6078 - loss: 1.2587
# Epoch 15: saving model to model_init_2024-11-0804_40_40.716983/model-00015-1.27222-0.59125-1.31646-0.55000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - categorical_accuracy: 0.6076 - loss: 1.2589 - val_categorical_accuracy: 0.5500 - val_loss: 1.3165 - learning_rate: 5.0000e-04
# Epoch 16/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.6215 - loss: 1.2204
# Epoch 16: saving model to model_init_2024-11-0804_40_40.716983/model-00016-1.23823-0.60181-1.31491-0.54000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 108s 2s/step - categorical_accuracy: 0.6212 - loss: 1.2207 - val_categorical_accuracy: 0.5400 - val_loss: 1.3149 - learning_rate: 5.0000e-04
# Epoch 17/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.6244 - loss: 1.2254
# Epoch 17: saving model to model_init_2024-11-0804_40_40.716983/model-00017-1.23271-0.61237-1.27949-0.57000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - categorical_accuracy: 0.6242 - loss: 1.2255 - val_categorical_accuracy: 0.5700 - val_loss: 1.2795 - learning_rate: 5.0000e-04
# Epoch 18/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.5788 - loss: 1.2265
# Epoch 18: saving model to model_init_2024-11-0804_40_40.716983/model-00018-1.23836-0.57164-1.27323-0.57000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 106s 2s/step - categorical_accuracy: 0.5787 - loss: 1.2267 - val_categorical_accuracy: 0.5700 - val_loss: 1.2732 - learning_rate: 5.0000e-04
# Epoch 19/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.6359 - loss: 1.1861
# Epoch 19: saving model to model_init_2024-11-0804_40_40.716983/model-00019-1.18131-0.62293-1.23008-0.61000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 106s 2s/step - categorical_accuracy: 0.6357 - loss: 1.1860 - val_categorical_accuracy: 0.6100 - val_loss: 1.2301 - learning_rate: 5.0000e-04
# Epoch 20/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.6547 - loss: 1.1545
# Epoch 20: saving model to model_init_2024-11-0804_40_40.716983/model-00020-1.15581-0.63650-1.25497-0.53000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 106s 2s/step - categorical_accuracy: 0.6544 - loss: 1.1546 - val_categorical_accuracy: 0.5300 - val_loss: 1.2550 - learning_rate: 5.0000e-04

# %%
# Plotting function
import matplotlib.pyplot as plt

def plot_training(history):
    plt.figure(figsize=(12, 6))

    # Plot accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['categorical_accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_categorical_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Training and Validation Accuracy')

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Training and Validation Loss')

    plt.show()

plot_training(history)

# %% [markdown]
# # Model 2 CONV2D + RNN (more complex)

# %%
# Updated model architecture
model = Sequential()

# First Conv2D Block
model.add(TimeDistributed(Conv2D(16, (3, 3), padding='same'), input_shape=input_shape))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(Activation('relu')))
model.add(TimeDistributed(MaxPooling2D((2, 2))))

# Second Conv2D Block
model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(Activation('relu')))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Dropout(0.25)))

# Third Conv2D Block
model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(Activation('relu')))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Dropout(0.25)))

# Flatten and LSTM
model.add(TimeDistributed(Flatten()))
model.add(LSTM(128, return_sequences=False))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\keras\src\layers\core\wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
from tensorflow.keras.optimizers import Adam
#learning_rate = 0.0001
optimizer = 'adam'
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed_48             │ (None, 15, 128, 128,   │           448 │
# │ (TimeDistributed)               │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_49             │ (None, 15, 128, 128,   │            64 │
# │ (TimeDistributed)               │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_50             │ (None, 15, 128, 128,   │             0 │
# │ (TimeDistributed)               │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_51             │ (None, 15, 64, 64, 16) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_52             │ (None, 15, 64, 64, 32) │         4,640 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_53             │ (None, 15, 64, 64, 32) │           128 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_54             │ (None, 15, 64, 64, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_55             │ (None, 15, 32, 32, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_56             │ (None, 15, 32, 32, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_57             │ (None, 15, 32, 32, 64) │        18,496 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_58             │ (None, 15, 32, 32, 64) │           256 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_59             │ (None, 15, 32, 32, 64) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_60             │ (None, 15, 16, 16, 64) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_61             │ (None, 15, 16, 16, 64) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_62             │ (None, 15, 16384)      │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 128)            │     8,454,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,479,333 (32.35 MB)
#  Trainable params: 8,479,109 (32.35 MB)
#  Non-trainable params: 224 (896.00 B)
# None

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

print(steps_per_epoch,validation_steps)
# Out:
# 67 10

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                    callbacks=callbacks_list, validation_data=val_generator,
                    validation_steps=validation_steps, class_weight=None, initial_epoch=0)
# Out:
# Source path = C:\Users\admin\Vidhya\Project_data\train ; batch size = 10
# Number of folders: 663
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_5248\950058156.py:46: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# Epoch 1/20
# 65/67 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - categorical_accuracy: 0.1976 - loss: 2.1336
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_5248\950058156.py:101: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1972 - loss: 2.1304Source path = C:\Users\admin\Vidhya\Project_data\val ; batch size = 10
# Number of folders: 100
#
# Epoch 1: saving model to model_init_2024-11-0804_40_40.716983/model-00001-2.02867-0.18401-1.60866-0.23000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 173s 2s/step - categorical_accuracy: 0.1970 - loss: 2.1289 - val_categorical_accuracy: 0.2300 - val_loss: 1.6087 - learning_rate: 0.0010
# Epoch 2/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1928 - loss: 1.8710
# Epoch 2: saving model to model_init_2024-11-0804_40_40.716983/model-00002-1.84967-0.21267-1.60575-0.23000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - categorical_accuracy: 0.1930 - loss: 1.8707 - val_categorical_accuracy: 0.2300 - val_loss: 1.6058 - learning_rate: 0.0010
# Epoch 3/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1675 - loss: 1.9052
# Epoch 3: saving model to model_init_2024-11-0804_40_40.716983/model-00003-1.88981-0.16440-1.61158-0.21000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - categorical_accuracy: 0.1675 - loss: 1.9050 - val_categorical_accuracy: 0.2100 - val_loss: 1.6116 - learning_rate: 0.0010
# Epoch 4/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1961 - loss: 1.8310
# Epoch 4: saving model to model_init_2024-11-0804_40_40.716983/model-00004-1.81263-0.20814-1.60447-0.23000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 131s 2s/step - categorical_accuracy: 0.1963 - loss: 1.8307 - val_categorical_accuracy: 0.2300 - val_loss: 1.6045 - learning_rate: 0.0010
# Epoch 5/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1916 - loss: 1.7783
# Epoch 5: saving model to model_init_2024-11-0804_40_40.716983/model-00005-1.79880-0.20664-1.60733-0.18000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 137s 2s/step - categorical_accuracy: 0.1918 - loss: 1.7786 - val_categorical_accuracy: 0.1800 - val_loss: 1.6073 - learning_rate: 0.0010
# Epoch 6/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2292 - loss: 1.7371
# Epoch 6: saving model to model_init_2024-11-0804_40_40.716983/model-00006-1.74192-0.22624-1.61745-0.18000.keras
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 136s 2s/step - categorical_accuracy: 0.2292 - loss: 1.7372 - val_categorical_accuracy: 0.1800 - val_loss: 1.6174 - learning_rate: 0.0010
# Epoch 7/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2004 - loss: 1.7430
# Epoch 7: saving model to model_init_2024-11-0804_40_40.716983/model-00007-1.75585-0.20060-1.61073-0.18000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 136s 2s/step - categorical_accuracy: 0.2004 - loss: 1.7432 - val_categorical_accuracy: 0.1800 - val_loss: 1.6107 - learning_rate: 5.0000e-04
# Epoch 8/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2164 - loss: 1.7529
# Epoch 8: saving model to model_init_2024-11-0804_40_40.716983/model-00008-1.76007-0.20814-1.60957-0.23000.keras
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 136s 2s/step - categorical_accuracy: 0.2163 - loss: 1.7530 - val_categorical_accuracy: 0.2300 - val_loss: 1.6096 - learning_rate: 5.0000e-04
# Epoch 9/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2155 - loss: 1.7412
# Epoch 9: saving model to model_init_2024-11-0804_40_40.716983/model-00009-1.72041-0.21267-1.60696-0.23000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 136s 2s/step - categorical_accuracy: 0.2154 - loss: 1.7409 - val_categorical_accuracy: 0.2300 - val_loss: 1.6070 - learning_rate: 2.5000e-04
# Epoch 10/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1648 - loss: 1.7708
# Epoch 10: saving model to model_init_2024-11-0804_40_40.716983/model-00010-1.75476-0.17798-1.60664-0.23000.keras
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 136s 2s/step - categorical_accuracy: 0.1650 - loss: 1.7706 - val_categorical_accuracy: 0.2300 - val_loss: 1.6066 - learning_rate: 2.5000e-04
# Epoch 11/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2046 - loss: 1.7195
# Epoch 11: saving model to model_init_2024-11-0804_40_40.716983/model-00011-1.73219-0.19005-1.60643-0.23000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - categorical_accuracy: 0.2044 - loss: 1.7197 - val_categorical_accuracy: 0.2300 - val_loss: 1.6064 - learning_rate: 1.2500e-04
# Epoch 12/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1695 - loss: 1.7619
# Epoch 12: saving model to model_init_2024-11-0804_40_40.716983/model-00012-1.75494-0.17496-1.60619-0.23000.keras
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - categorical_accuracy: 0.1696 - loss: 1.7618 - val_categorical_accuracy: 0.2300 - val_loss: 1.6062 - learning_rate: 1.2500e-04
# Epoch 13/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2188 - loss: 1.6941
# Epoch 13: saving model to model_init_2024-11-0804_40_40.716983/model-00013-1.71143-0.22323-1.60636-0.23000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - categorical_accuracy: 0.2189 - loss: 1.6944 - val_categorical_accuracy: 0.2300 - val_loss: 1.6064 - learning_rate: 6.2500e-05
# Epoch 14/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2006 - loss: 1.7096
# Epoch 14: saving model to model_init_2024-11-0804_40_40.716983/model-00014-1.71209-0.20814-1.60641-0.23000.keras
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - categorical_accuracy: 0.2007 - loss: 1.7096 - val_categorical_accuracy: 0.2300 - val_loss: 1.6064 - learning_rate: 6.2500e-05
# Epoch 15/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1898 - loss: 1.7184
# Epoch 15: saving model to model_init_2024-11-0804_40_40.716983/model-00015-1.73458-0.17647-1.60641-0.23000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 137s 2s/step - categorical_accuracy: 0.1896 - loss: 1.7187 - val_categorical_accuracy: 0.2300 - val_loss: 1.6064 - learning_rate: 3.1250e-05
# Epoch 16/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1947 - loss: 1.7524
# Epoch 16: saving model to model_init_2024-11-0804_40_40.716983/model-00016-1.76236-0.19457-1.60648-0.23000.keras
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 137s 2s/step - categorical_accuracy: 0.1947 - loss: 1.7526 - val_categorical_accuracy: 0.2300 - val_loss: 1.6065 - learning_rate: 3.1250e-05
# Epoch 17/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1878 - loss: 1.7748
# Epoch 17: saving model to model_init_2024-11-0804_40_40.716983/model-00017-1.75930-0.19457-1.60648-0.23000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 135s 2s/step - categorical_accuracy: 0.1879 - loss: 1.7746 - val_categorical_accuracy: 0.2300 - val_loss: 1.6065 - learning_rate: 1.5625e-05
# Epoch 18/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2139 - loss: 1.6827
# Epoch 18: saving model to model_init_2024-11-0804_40_40.716983/model-00018-1.68928-0.21569-1.60658-0.23000.keras
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 136s 2s/step - categorical_accuracy: 0.2140 - loss: 1.6827 - val_categorical_accuracy: 0.2300 - val_loss: 1.6066 - learning_rate: 1.5625e-05
# Epoch 19/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1923 - loss: 1.7434
# Epoch 19: saving model to model_init_2024-11-0804_40_40.716983/model-00019-1.76350-0.19306-1.60651-0.23000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 135s 2s/step - categorical_accuracy: 0.1923 - loss: 1.7437 - val_categorical_accuracy: 0.2300 - val_loss: 1.6065 - learning_rate: 7.8125e-06
# Epoch 20/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1967 - loss: 1.7367
# Epoch 20: saving model to model_init_2024-11-0804_40_40.716983/model-00020-1.73884-0.18250-1.60656-0.23000.keras
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 135s 2s/step - categorical_accuracy: 0.1965 - loss: 1.7367 - val_categorical_accuracy: 0.2300 - val_loss: 1.6066 - learning_rate: 7.8125e-06

# %%
plot_training(history)

# %% [markdown]
# ### Exp 2 - Extremely low accuracy

# %% [markdown]
# ## Experiment 3 Conv2D + LSTM, mor images, increased filters
# Will select more images, back to same learning rate, changes in model Architecture, increased filters

# %%
# Define input shape (frames, height, width, channels)
input_shape = (20, 128, 128, 3)
num_classes = 5

# Updated model architecture
model = Sequential()

# First Conv2D Block
model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same'), input_shape=input_shape))  # Increased filters
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(Activation('relu')))
model.add(TimeDistributed(MaxPooling2D((2, 2))))

# Second Conv2D Block
model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same')))  # Increased filters
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(Activation('relu')))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Dropout(0.2)))  # Adjusted dropout

# Third Conv2D Block
model.add(TimeDistributed(Conv2D(128, (3, 3), padding='same')))  # Increased filters
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(Activation('relu')))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Dropout(0.3)))  # Adjusted dropout

# Flatten and LSTM
model.add(TimeDistributed(Flatten()))
model.add(LSTM(256, return_sequences=False))  # Increased LSTM units
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# Compile the model with a lower learning rate
#model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
optimiser = 'adam'
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed_25             │ (None, 20, 128, 128,   │           896 │
# │ (TimeDistributed)               │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_26             │ (None, 20, 128, 128,   │           128 │
# │ (TimeDistributed)               │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_27             │ (None, 20, 128, 128,   │             0 │
# │ (TimeDistributed)               │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_28             │ (None, 20, 64, 64, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_29             │ (None, 20, 64, 64, 64) │        18,496 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_30             │ (None, 20, 64, 64, 64) │           256 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_31             │ (None, 20, 64, 64, 64) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_32             │ (None, 20, 32, 32, 64) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_33             │ (None, 20, 32, 32, 64) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_34             │ (None, 20, 32, 32,     │        73,856 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_35             │ (None, 20, 32, 32,     │           512 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_36             │ (None, 20, 32, 32,     │             0 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_37             │ (None, 20, 16, 16,     │             0 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_38             │ (None, 20, 16, 16,     │             0 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_39             │ (None, 20, 32768)      │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 256)            │    33,817,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 33,913,029 (129.37 MB)
#  Trainable params: 33,912,581 (129.37 MB)
#  Non-trainable params: 448 (1.75 KB)
# None

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

print(steps_per_epoch,validation_steps)
# Out:
# 67 10

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                    callbacks=callbacks_list, validation_data=val_generator,
                    validation_steps=validation_steps, class_weight=None, initial_epoch=0)
# Out:
# Source path = C:\Users\admin\Vidhya\Project_data\train ; batch size = 10
# Number of folders: 663
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_3044\950058156.py:46: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# Epoch 1/20
# 65/67 ━━━━━━━━━━━━━━━━━━━━ 9s 5s/step - categorical_accuracy: 0.2425 - loss: 1.9105
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_3044\950058156.py:101: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.2413 - loss: 1.9097Source path = C:\Users\admin\Vidhya\Project_data\val ; batch size = 10
# Number of folders: 100
#
# Epoch 1: saving model to model_init_2024-11-0807_39_15.049899/model-00001-1.88527-0.20362-1.60299-0.21000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 369s 5s/step - categorical_accuracy: 0.2408 - loss: 1.9093 - val_categorical_accuracy: 0.2100 - val_loss: 1.6030 - learning_rate: 0.0010
# Epoch 2/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.1669 - loss: 1.8415
# Epoch 2: saving model to model_init_2024-11-0807_39_15.049899/model-00002-1.81664-0.19457-1.64527-0.16000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 217s 3s/step - categorical_accuracy: 0.1673 - loss: 1.8412 - val_categorical_accuracy: 0.1600 - val_loss: 1.6453 - learning_rate: 0.0010
# Epoch 3/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.2396 - loss: 1.7649
# Epoch 3: saving model to model_init_2024-11-0807_39_15.049899/model-00003-1.78183-0.21116-1.61792-0.18000.keras
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 211s 3s/step - categorical_accuracy: 0.2391 - loss: 1.7651 - val_categorical_accuracy: 0.1800 - val_loss: 1.6179 - learning_rate: 0.0010
# Epoch 4/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.1595 - loss: 1.8290
# Epoch 4: saving model to model_init_2024-11-0807_39_15.049899/model-00004-1.78972-0.18552-1.60556-0.21000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 211s 3s/step - categorical_accuracy: 0.1599 - loss: 1.8284 - val_categorical_accuracy: 0.2100 - val_loss: 1.6056 - learning_rate: 5.0000e-04
# Epoch 5/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.2247 - loss: 1.7193
# Epoch 5: saving model to model_init_2024-11-0807_39_15.049899/model-00005-1.76047-0.20362-1.61154-0.23000.keras
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 213s 3s/step - categorical_accuracy: 0.2244 - loss: 1.7199 - val_categorical_accuracy: 0.2300 - val_loss: 1.6115 - learning_rate: 5.0000e-04
# Epoch 6/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.2132 - loss: 1.7450
# Epoch 6: saving model to model_init_2024-11-0807_39_15.049899/model-00006-1.74771-0.19910-1.61003-0.18000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 209s 3s/step - categorical_accuracy: 0.2130 - loss: 1.7450 - val_categorical_accuracy: 0.1800 - val_loss: 1.6100 - learning_rate: 2.5000e-04
# Epoch 7/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.1777 - loss: 1.7795
# Epoch 7: saving model to model_init_2024-11-0807_39_15.049899/model-00007-1.76697-0.18401-1.60620-0.21000.keras
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 210s 3s/step - categorical_accuracy: 0.1778 - loss: 1.7793 - val_categorical_accuracy: 0.2100 - val_loss: 1.6062 - learning_rate: 2.5000e-04
# Epoch 8/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.1973 - loss: 1.7357
# Epoch 8: saving model to model_init_2024-11-0807_39_15.049899/model-00008-1.72339-0.19457-1.60547-0.21000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 210s 3s/step - categorical_accuracy: 0.1972 - loss: 1.7355 - val_categorical_accuracy: 0.2100 - val_loss: 1.6055 - learning_rate: 1.2500e-04
# Epoch 9/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.2199 - loss: 1.7232
# Epoch 9: saving model to model_init_2024-11-0807_39_15.049899/model-00009-1.72096-0.20814-1.60750-0.21000.keras
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 208s 3s/step - categorical_accuracy: 0.2197 - loss: 1.7231 - val_categorical_accuracy: 0.2100 - val_loss: 1.6075 - learning_rate: 1.2500e-04
# Epoch 10/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.1850 - loss: 1.8084
# Epoch 10: saving model to model_init_2024-11-0807_39_15.049899/model-00010-1.78039-0.20513-1.60616-0.21000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 209s 3s/step - categorical_accuracy: 0.1853 - loss: 1.8080 - val_categorical_accuracy: 0.2100 - val_loss: 1.6062 - learning_rate: 6.2500e-05
# Epoch 11/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.1792 - loss: 1.7354
# Epoch 11: saving model to model_init_2024-11-0807_39_15.049899/model-00011-1.71503-0.20362-1.60650-0.21000.keras
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 210s 3s/step - categorical_accuracy: 0.1795 - loss: 1.7351 - val_categorical_accuracy: 0.2100 - val_loss: 1.6065 - learning_rate: 6.2500e-05
# Epoch 12/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.1937 - loss: 1.7929
# Epoch 12: saving model to model_init_2024-11-0807_39_15.049899/model-00012-1.76085-0.20211-1.60663-0.21000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 209s 3s/step - categorical_accuracy: 0.1939 - loss: 1.7925 - val_categorical_accuracy: 0.2100 - val_loss: 1.6066 - learning_rate: 3.1250e-05
# Epoch 13/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.2120 - loss: 1.6989
# Epoch 13: saving model to model_init_2024-11-0807_39_15.049899/model-00013-1.73096-0.20965-1.60644-0.21000.keras
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 210s 3s/step - categorical_accuracy: 0.2120 - loss: 1.6993 - val_categorical_accuracy: 0.2100 - val_loss: 1.6064 - learning_rate: 3.1250e-05
# Epoch 14/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.1820 - loss: 1.7242
# Epoch 14: saving model to model_init_2024-11-0807_39_15.049899/model-00014-1.74124-0.18250-1.60608-0.21000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 210s 3s/step - categorical_accuracy: 0.1820 - loss: 1.7245 - val_categorical_accuracy: 0.2100 - val_loss: 1.6061 - learning_rate: 1.5625e-05
# Epoch 15/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.1821 - loss: 1.7533
# Epoch 15: saving model to model_init_2024-11-0807_39_15.049899/model-00015-1.74530-0.18703-1.60603-0.21000.keras
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 212s 3s/step - categorical_accuracy: 0.1822 - loss: 1.7532 - val_categorical_accuracy: 0.2100 - val_loss: 1.6060 - learning_rate: 1.5625e-05
# Epoch 16/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.2750 - loss: 1.6487
# Epoch 16: saving model to model_init_2024-11-0807_39_15.049899/model-00016-1.70118-0.23831-1.60521-0.21000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 210s 3s/step - categorical_accuracy: 0.2744 - loss: 1.6495 - val_categorical_accuracy: 0.2100 - val_loss: 1.6052 - learning_rate: 7.8125e-06
# Epoch 17/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.1937 - loss: 1.7646
# Epoch 17: saving model to model_init_2024-11-0807_39_15.049899/model-00017-1.72448-0.22323-1.60516-0.21000.keras
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 210s 3s/step - categorical_accuracy: 0.1941 - loss: 1.7640 - val_categorical_accuracy: 0.2100 - val_loss: 1.6052 - learning_rate: 7.8125e-06
# Epoch 18/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.1815 - loss: 1.7579
# Epoch 18: saving model to model_init_2024-11-0807_39_15.049899/model-00018-1.75224-0.19306-1.60488-0.21000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 210s 3s/step - categorical_accuracy: 0.1817 - loss: 1.7578 - val_categorical_accuracy: 0.2100 - val_loss: 1.6049 - learning_rate: 3.9063e-06
# Epoch 19/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.1740 - loss: 1.7534
# Epoch 19: saving model to model_init_2024-11-0807_39_15.049899/model-00019-1.76121-0.17798-1.60496-0.21000.keras
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 210s 3s/step - categorical_accuracy: 0.1741 - loss: 1.7535 - val_categorical_accuracy: 0.2100 - val_loss: 1.6050 - learning_rate: 3.9063e-06
# Epoch 20/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.1779 - loss: 1.7504
# Epoch 20: saving model to model_init_2024-11-0807_39_15.049899/model-00020-1.76495-0.18250-1.60432-0.21000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 208s 3s/step - categorical_accuracy: 0.1779 - loss: 1.7506 - val_categorical_accuracy: 0.2100 - val_loss: 1.6043 - learning_rate: 1.9531e-06

# %%
plot_training(history)

# %% [markdown]
# ### Above one gave better results with 20 epochs. So we will do 20 epochs atleast.
# Also will try to reduce the model complexity and see once.

# %% [markdown]
# ## Exp 4 - Conv3D + GRU

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import TimeDistributed, Conv2D, BatchNormalization, Activation, MaxPooling2D, Dropout, Flatten, GRU, Dense
from tensorflow.keras.optimizers import Adam

# Define input shape and parameters
input_shape = (20, 128, 128, 3)  # 20 frames
num_classes = 5

# Initialize Sequential model
model = Sequential()

# First Conv2D Block
model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same', activation='relu'), input_shape=input_shape))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Dropout(0.2)))  # Moderate dropout

# Second Conv2D Block
model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Dropout(0.3)))  # Adjusted dropout to reduce overfitting

# Third Conv2D Block
model.add(TimeDistributed(Conv2D(128, (3, 3), padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Dropout(0.3)))

# Fourth Conv2D Block (if needed, you can remove this if the model is still complex)
model.add(TimeDistributed(Conv2D(256, (3, 3), padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Dropout(0.4)))  # Higher dropout to improve generalization

# Flatten and GRU
model.add(TimeDistributed(Flatten()))
model.add(GRU(128, return_sequences=False))  # Reduced GRU units for efficiency
model.add(Dropout(0.5))

# Output Layer
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# Summary of the model
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed_17             │ (None, 20, 128, 128,   │           896 │
# │ (TimeDistributed)               │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_18             │ (None, 20, 128, 128,   │           128 │
# │ (TimeDistributed)               │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_19             │ (None, 20, 64, 64, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_20             │ (None, 20, 64, 64, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_21             │ (None, 20, 64, 64, 64) │        18,496 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_22             │ (None, 20, 64, 64, 64) │           256 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_23             │ (None, 20, 32, 32, 64) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_24             │ (None, 20, 32, 32, 64) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_25             │ (None, 20, 32, 32,     │        73,856 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_26             │ (None, 20, 32, 32,     │           512 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_27             │ (None, 20, 16, 16,     │             0 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_28             │ (None, 20, 16, 16,     │             0 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_29             │ (None, 20, 16, 16,     │       295,168 │
# │ (TimeDistributed)               │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_30             │ (None, 20, 16, 16,     │         1,024 │
# │ (TimeDistributed)               │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_31             │ (None, 20, 8, 8, 256)  │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_32             │ (None, 20, 8, 8, 256)  │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_33             │ (None, 20, 16384)      │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 128)            │     6,341,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,732,357 (25.68 MB)
#  Trainable params: 6,731,397 (25.68 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

print(steps_per_epoch,validation_steps)
print(num_epochs)
# Out:
# 67 10
# 20

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                    callbacks=callbacks_list, validation_data=val_generator,
                    validation_steps=validation_steps, class_weight=None, initial_epoch=0)
# Out:
# Source path = C:\Users\admin\Vidhya\Project_data\train ; batch size = 10
# Number of folders: 663
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_588\950058156.py:46: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# Epoch 1/20
# 65/67 ━━━━━━━━━━━━━━━━━━━━ 8s 4s/step - categorical_accuracy: 0.2626 - loss: 2.0599
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_588\950058156.py:101: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.2631 - loss: 2.0567Source path = C:\Users\admin\Vidhya\Project_data\val ; batch size = 10
# Number of folders: 100
#
# Epoch 1: saving model to model_init_2024-11-0810_55_20.469517/model-00001-1.94905-0.28356-1.78009-0.38000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 328s 4s/step - categorical_accuracy: 0.2634 - loss: 2.0551 - val_categorical_accuracy: 0.3800 - val_loss: 1.7801 - learning_rate: 1.0000e-04
# Epoch 2/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.3391 - loss: 1.6951
# Epoch 2: saving model to model_init_2024-11-0810_55_20.469517/model-00002-1.71315-0.31825-1.77824-0.37000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 186s 3s/step - categorical_accuracy: 0.3388 - loss: 1.6954 - val_categorical_accuracy: 0.3700 - val_loss: 1.7782 - learning_rate: 1.0000e-04
# Epoch 3/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.3478 - loss: 1.6539
# Epoch 3: saving model to model_init_2024-11-0810_55_20.469517/model-00003-1.61741-0.35143-1.78357-0.39000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 186s 3s/step - categorical_accuracy: 0.3479 - loss: 1.6533 - val_categorical_accuracy: 0.3900 - val_loss: 1.7836 - learning_rate: 1.0000e-04
# Epoch 4/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.3767 - loss: 1.5617
# Epoch 4: saving model to model_init_2024-11-0810_55_20.469517/model-00004-1.53676-0.38009-1.73899-0.43000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 182s 3s/step - categorical_accuracy: 0.3768 - loss: 1.5614 - val_categorical_accuracy: 0.4300 - val_loss: 1.7390 - learning_rate: 1.0000e-04
# Epoch 5/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.4216 - loss: 1.4980
# Epoch 5: saving model to model_init_2024-11-0810_55_20.469517/model-00005-1.45347-0.42534-1.71275-0.45000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 188s 3s/step - categorical_accuracy: 0.4216 - loss: 1.4974 - val_categorical_accuracy: 0.4500 - val_loss: 1.7127 - learning_rate: 1.0000e-04
# Epoch 6/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.4609 - loss: 1.4000
# Epoch 6: saving model to model_init_2024-11-0810_55_20.469517/model-00006-1.39154-0.45551-1.57718-0.49000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 184s 3s/step - categorical_accuracy: 0.4608 - loss: 1.3999 - val_categorical_accuracy: 0.4900 - val_loss: 1.5772 - learning_rate: 1.0000e-04
# Epoch 7/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5142 - loss: 1.2255
# Epoch 7: saving model to model_init_2024-11-0810_55_20.469517/model-00007-1.24081-0.51131-1.79091-0.45000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 184s 3s/step - categorical_accuracy: 0.5142 - loss: 1.2258 - val_categorical_accuracy: 0.4500 - val_loss: 1.7909 - learning_rate: 1.0000e-04
# Epoch 8/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5320 - loss: 1.2054
# Epoch 8: saving model to model_init_2024-11-0810_55_20.469517/model-00008-1.22618-0.53394-1.71891-0.44000.keras
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 184s 3s/step - categorical_accuracy: 0.5320 - loss: 1.2057 - val_categorical_accuracy: 0.4400 - val_loss: 1.7189 - learning_rate: 1.0000e-04
# Epoch 9/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5949 - loss: 1.1113
# Epoch 9: saving model to model_init_2024-11-0810_55_20.469517/model-00009-1.11886-0.58824-1.73830-0.52000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 184s 3s/step - categorical_accuracy: 0.5948 - loss: 1.1114 - val_categorical_accuracy: 0.5200 - val_loss: 1.7383 - learning_rate: 5.0000e-05
# Epoch 10/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6037 - loss: 1.0438
# Epoch 10: saving model to model_init_2024-11-0810_55_20.469517/model-00010-1.04766-0.60935-1.69091-0.48000.keras
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 184s 3s/step - categorical_accuracy: 0.6038 - loss: 1.0439 - val_categorical_accuracy: 0.4800 - val_loss: 1.6909 - learning_rate: 5.0000e-05
# Epoch 11/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6077 - loss: 1.0253
# Epoch 11: saving model to model_init_2024-11-0810_55_20.469517/model-00011-0.98370-0.62745-1.62619-0.53000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 184s 3s/step - categorical_accuracy: 0.6080 - loss: 1.0247 - val_categorical_accuracy: 0.5300 - val_loss: 1.6262 - learning_rate: 2.5000e-05
# Epoch 12/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6277 - loss: 0.9856
# Epoch 12: saving model to model_init_2024-11-0810_55_20.469517/model-00012-0.94241-0.64404-1.63815-0.49000.keras
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 183s 3s/step - categorical_accuracy: 0.6280 - loss: 0.9849 - val_categorical_accuracy: 0.4900 - val_loss: 1.6382 - learning_rate: 2.5000e-05
# Epoch 13/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6863 - loss: 0.8191
# Epoch 13: saving model to model_init_2024-11-0810_55_20.469517/model-00013-0.87162-0.65913-1.66004-0.49000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 182s 3s/step - categorical_accuracy: 0.6859 - loss: 0.8198 - val_categorical_accuracy: 0.4900 - val_loss: 1.6600 - learning_rate: 1.2500e-05
# Epoch 14/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6426 - loss: 0.9137
# Epoch 14: saving model to model_init_2024-11-0810_55_20.469517/model-00014-0.88961-0.66063-1.53085-0.55000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 183s 3s/step - categorical_accuracy: 0.6429 - loss: 0.9133 - val_categorical_accuracy: 0.5500 - val_loss: 1.5308 - learning_rate: 1.2500e-05
# Epoch 15/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7035 - loss: 0.8333
# Epoch 15: saving model to model_init_2024-11-0810_55_20.469517/model-00015-0.87728-0.67421-1.61856-0.52000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 184s 3s/step - categorical_accuracy: 0.7031 - loss: 0.8340 - val_categorical_accuracy: 0.5200 - val_loss: 1.6186 - learning_rate: 1.2500e-05
# Epoch 16/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6995 - loss: 0.8444
# Epoch 16: saving model to model_init_2024-11-0810_55_20.469517/model-00016-0.86679-0.68175-1.59174-0.50000.keras
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 183s 3s/step - categorical_accuracy: 0.6992 - loss: 0.8448 - val_categorical_accuracy: 0.5000 - val_loss: 1.5917 - learning_rate: 1.2500e-05
# Epoch 17/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7107 - loss: 0.8320
# Epoch 17: saving model to model_init_2024-11-0810_55_20.469517/model-00017-0.85065-0.69532-1.64269-0.49000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 184s 3s/step - categorical_accuracy: 0.7105 - loss: 0.8323 - val_categorical_accuracy: 0.4900 - val_loss: 1.6427 - learning_rate: 6.2500e-06
# Epoch 18/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6979 - loss: 0.8044
# Epoch 18: saving model to model_init_2024-11-0810_55_20.469517/model-00018-0.80229-0.69683-1.63426-0.52000.keras
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 183s 3s/step - categorical_accuracy: 0.6979 - loss: 0.8043 - val_categorical_accuracy: 0.5200 - val_loss: 1.6343 - learning_rate: 6.2500e-06
# Epoch 19/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6529 - loss: 0.8680
# Epoch 19: saving model to model_init_2024-11-0810_55_20.469517/model-00019-0.82594-0.67722-1.63868-0.51000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 181s 3s/step - categorical_accuracy: 0.6532 - loss: 0.8674 - val_categorical_accuracy: 0.5100 - val_loss: 1.6387 - learning_rate: 3.1250e-06
# Epoch 20/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7026 - loss: 0.7797
# Epoch 20: saving model to model_init_2024-11-0810_55_20.469517/model-00020-0.79997-0.70437-1.66805-0.51000.keras
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 182s 3s/step - categorical_accuracy: 0.7027 - loss: 0.7800 - val_categorical_accuracy: 0.5100 - val_loss: 1.6681 - learning_rate: 3.1250e-06

# %%
plot_training(history)

# %% [markdown]
# ### The pattern in the results suggests that while the model's training accuracy improves, the validation accuracy remains stagnant at around 50%. This hints at possible overfitting or issues in the model's capacity to generalize effectively. Here are some adjustments to try:
#
# Experiment with More Layers: Consider adding an additional Conv2D block with fewer filters (to keep memory usage in check) to capture more nuanced spatial features before passing data to the GRU.
#
# Reduce Conv2D Filter Sizes: Try smaller filter sizes (e.g., (3, 3) and (2, 2)) in initial layers to improve feature granularity.
#
# Tweak Dropout: Increasing dropout in both Conv2D and GRU layers can help generalization. Using SpatialDropout2D after Conv2D layers may also help, as it drops entire feature maps, encouraging robust feature extraction.
#
# Early Stop & LR Tuning: Since the learning rate already reduces, consider early stopping based on validation loss if the accuracy doesn't increase after a set number of epochs.

# %% [markdown]
# ## EXP 4 - Conv2D + GRU, more epochs, improved Generalization with SpacialDropout, an additional Conv2D layers

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import TimeDistributed, Conv2D, BatchNormalization, Activation, MaxPooling2D, Dropout, Flatten, GRU, Dense, SpatialDropout2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint

# Define input shape and parameters
input_shape = (20, 128, 128, 3)  #
num_classes = 5

# Initialize Sequential model
model = Sequential()

# First Conv2D Block
model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same', activation='relu'), input_shape=input_shape))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(SpatialDropout2D(0.2)))  # Improved generalization

# Second Conv2D Block
model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(SpatialDropout2D(0.3)))

# Third Conv2D Block (additional layer for deeper feature extraction)
model.add(TimeDistributed(Conv2D(128, (2, 2), padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(SpatialDropout2D(0.3)))

# Fourth Conv2D Block
model.add(TimeDistributed(Conv2D(256, (2, 2), padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Dropout(0.4)))

# Flatten and GRU
model.add(TimeDistributed(Flatten()))
model.add(GRU(128, return_sequences=False))
model.add(Dropout(0.5))

# Output Layer
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# Summary of the model
model.summary()
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\keras\src\layers\core\wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed_51             │ (None, 20, 128, 128,   │           896 │
# │ (TimeDistributed)               │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_52             │ (None, 20, 128, 128,   │           128 │
# │ (TimeDistributed)               │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_53             │ (None, 20, 64, 64, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_54             │ (None, 20, 64, 64, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_55             │ (None, 20, 64, 64, 64) │        18,496 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_56             │ (None, 20, 64, 64, 64) │           256 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_57             │ (None, 20, 32, 32, 64) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_58             │ (None, 20, 32, 32, 64) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_59             │ (None, 20, 32, 32,     │        32,896 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_60             │ (None, 20, 32, 32,     │           512 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_61             │ (None, 20, 16, 16,     │             0 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_62             │ (None, 20, 16, 16,     │             0 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_63             │ (None, 20, 16, 16,     │       131,328 │
# │ (TimeDistributed)               │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_64             │ (None, 20, 16, 16,     │         1,024 │
# │ (TimeDistributed)               │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_65             │ (None, 20, 8, 8, 256)  │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_66             │ (None, 20, 8, 8, 256)  │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_67             │ (None, 20, 16384)      │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_3 (GRU)                     │ (None, 128)            │     6,341,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,527,557 (24.90 MB)
#  Trainable params: 6,526,597 (24.90 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
# Modify ReduceLROnPlateau with increased patience and slight factor adjustment
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'

if not os.path.exists(model_name):
    os.mkdir(model_name)

#filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.keras'
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', save_freq='epoch')
LR = ReduceLROnPlateau(monitor='val_loss', factor=0.7, patience=3, min_lr=1e-6, verbose=1)
callbacks_list = [checkpoint, LR]

# %%
#increase epochs
num_epochs = 40

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

print(steps_per_epoch,validation_steps)
print(num_epochs)
# Out:
# 67 10
# 40

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                    callbacks=callbacks_list, validation_data=val_generator,
                    validation_steps=validation_steps, class_weight=None, initial_epoch=0)
# Out:
# Source path = C:\Users\admin\Vidhya\Project_data\train ; batch size = 10
# Number of folders: 663
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_588\950058156.py:46: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# Epoch 1/40
# 65/67 ━━━━━━━━━━━━━━━━━━━━ 5s 3s/step - categorical_accuracy: 0.2327 - loss: 2.1492
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_588\950058156.py:101: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.2335 - loss: 2.1453Source path = C:\Users\admin\Vidhya\Project_data\val ; batch size = 10
# Number of folders: 100
#
# Epoch 1: saving model to model_init_2024-11-0810_55_20.469517/model-00001-2.01746-0.25943-1.32709-0.43000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 224s 3s/step - categorical_accuracy: 0.2338 - loss: 2.1434 - val_categorical_accuracy: 0.4300 - val_loss: 1.3271 - learning_rate: 1.0000e-04
# Epoch 2/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.3055 - loss: 1.7325
# Epoch 2: saving model to model_init_2024-11-0810_55_20.469517/model-00002-1.70650-0.32881-1.36141-0.50000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 183s 3s/step - categorical_accuracy: 0.3058 - loss: 1.7321 - val_categorical_accuracy: 0.5000 - val_loss: 1.3614 - learning_rate: 1.0000e-04
# Epoch 3/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.3926 - loss: 1.6122
# Epoch 3: saving model to model_init_2024-11-0810_55_20.469517/model-00003-1.59846-0.38462-1.29481-0.51000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 181s 3s/step - categorical_accuracy: 0.3925 - loss: 1.6120 - val_categorical_accuracy: 0.5100 - val_loss: 1.2948 - learning_rate: 1.0000e-04
# Epoch 4/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.4703 - loss: 1.3784
# Epoch 4: saving model to model_init_2024-11-0810_55_20.469517/model-00004-1.38105-0.47964-1.12164-0.60000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 174s 3s/step - categorical_accuracy: 0.4704 - loss: 1.3784 - val_categorical_accuracy: 0.6000 - val_loss: 1.1216 - learning_rate: 1.0000e-04
# Epoch 5/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.4685 - loss: 1.3556
# Epoch 5: saving model to model_init_2024-11-0810_55_20.469517/model-00005-1.31375-0.47360-1.26048-0.59000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 180s 3s/step - categorical_accuracy: 0.4686 - loss: 1.3550 - val_categorical_accuracy: 0.5900 - val_loss: 1.2605 - learning_rate: 1.0000e-04
# Epoch 6/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5688 - loss: 1.0992
# Epoch 6: saving model to model_init_2024-11-0810_55_20.469517/model-00006-1.15896-0.52941-1.16780-0.62000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 177s 3s/step - categorical_accuracy: 0.5682 - loss: 1.1001 - val_categorical_accuracy: 0.6200 - val_loss: 1.1678 - learning_rate: 1.0000e-04
# Epoch 7/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5561 - loss: 1.2187
# Epoch 7: saving model to model_init_2024-11-0810_55_20.469517/model-00007-1.20688-0.53092-1.18174-0.63000.keras
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 6.999999823165126e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 177s 3s/step - categorical_accuracy: 0.5557 - loss: 1.2185 - val_categorical_accuracy: 0.6300 - val_loss: 1.1817 - learning_rate: 1.0000e-04
# Epoch 8/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5070 - loss: 1.1536
# Epoch 8: saving model to model_init_2024-11-0810_55_20.469517/model-00008-1.14564-0.54449-1.20345-0.62000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 177s 3s/step - categorical_accuracy: 0.5076 - loss: 1.1535 - val_categorical_accuracy: 0.6200 - val_loss: 1.2035 - learning_rate: 7.0000e-05
# Epoch 9/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5942 - loss: 1.0528
# Epoch 9: saving model to model_init_2024-11-0810_55_20.469517/model-00009-1.00750-0.60633-1.10356-0.67000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 176s 3s/step - categorical_accuracy: 0.5944 - loss: 1.0521 - val_categorical_accuracy: 0.6700 - val_loss: 1.1036 - learning_rate: 7.0000e-05
# Epoch 10/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6185 - loss: 0.9983
# Epoch 10: saving model to model_init_2024-11-0810_55_20.469517/model-00010-0.97282-0.62896-1.19629-0.64000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 177s 3s/step - categorical_accuracy: 0.6187 - loss: 0.9979 - val_categorical_accuracy: 0.6400 - val_loss: 1.1963 - learning_rate: 7.0000e-05
# Epoch 11/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6743 - loss: 0.9104
# Epoch 11: saving model to model_init_2024-11-0810_55_20.469517/model-00011-0.95405-0.65913-1.17751-0.63000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 177s 3s/step - categorical_accuracy: 0.6741 - loss: 0.9110 - val_categorical_accuracy: 0.6300 - val_loss: 1.1775 - learning_rate: 7.0000e-05
# Epoch 12/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6966 - loss: 0.8304
# Epoch 12: saving model to model_init_2024-11-0810_55_20.469517/model-00012-0.87006-0.66516-1.09880-0.67000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 177s 3s/step - categorical_accuracy: 0.6962 - loss: 0.8310 - val_categorical_accuracy: 0.6700 - val_loss: 1.0988 - learning_rate: 7.0000e-05
# Epoch 13/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6681 - loss: 0.8467
# Epoch 13: saving model to model_init_2024-11-0810_55_20.469517/model-00013-0.83892-0.66667-1.08825-0.69000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 176s 3s/step - categorical_accuracy: 0.6680 - loss: 0.8466 - val_categorical_accuracy: 0.6900 - val_loss: 1.0882 - learning_rate: 7.0000e-05
# Epoch 14/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7058 - loss: 0.7739
# Epoch 14: saving model to model_init_2024-11-0810_55_20.469517/model-00014-0.77157-0.69834-1.12527-0.67000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 176s 3s/step - categorical_accuracy: 0.7057 - loss: 0.7738 - val_categorical_accuracy: 0.6700 - val_loss: 1.1253 - learning_rate: 7.0000e-05
# Epoch 15/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6713 - loss: 0.7906
# Epoch 15: saving model to model_init_2024-11-0810_55_20.469517/model-00015-0.78380-0.69080-1.11039-0.68000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 177s 3s/step - categorical_accuracy: 0.6716 - loss: 0.7905 - val_categorical_accuracy: 0.6800 - val_loss: 1.1104 - learning_rate: 7.0000e-05
# Epoch 16/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7499 - loss: 0.6537
# Epoch 16: saving model to model_init_2024-11-0810_55_20.469517/model-00016-0.68119-0.74208-1.13726-0.68000.keras
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.899999621557071e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 177s 3s/step - categorical_accuracy: 0.7497 - loss: 0.6541 - val_categorical_accuracy: 0.6800 - val_loss: 1.1373 - learning_rate: 7.0000e-05
# Epoch 17/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7512 - loss: 0.6681
# Epoch 17: saving model to model_init_2024-11-0810_55_20.469517/model-00017-0.69946-0.71795-1.13411-0.69000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.7507 - loss: 0.6685 - val_categorical_accuracy: 0.6900 - val_loss: 1.1341 - learning_rate: 4.9000e-05
# Epoch 18/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7737 - loss: 0.6109
# Epoch 18: saving model to model_init_2024-11-0810_55_20.469517/model-00018-0.61575-0.76772-1.12752-0.69000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.7736 - loss: 0.6109 - val_categorical_accuracy: 0.6900 - val_loss: 1.1275 - learning_rate: 4.9000e-05
# Epoch 19/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7543 - loss: 0.5992
# Epoch 19: saving model to model_init_2024-11-0810_55_20.469517/model-00019-0.59059-0.77677-1.09370-0.70000.keras
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 3.4299996332265434e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.7546 - loss: 0.5991 - val_categorical_accuracy: 0.7000 - val_loss: 1.0937 - learning_rate: 4.9000e-05
# Epoch 20/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7972 - loss: 0.5624
# Epoch 20: saving model to model_init_2024-11-0810_55_20.469517/model-00020-0.54582-0.79638-1.11096-0.70000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.7972 - loss: 0.5622 - val_categorical_accuracy: 0.7000 - val_loss: 1.1110 - learning_rate: 3.4300e-05
# Epoch 21/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8097 - loss: 0.4993
# Epoch 21: saving model to model_init_2024-11-0810_55_20.469517/model-00021-0.53516-0.79336-1.04007-0.72000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.8094 - loss: 0.4998 - val_categorical_accuracy: 0.7200 - val_loss: 1.0401 - learning_rate: 3.4300e-05
# Epoch 22/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8248 - loss: 0.4956
# Epoch 22: saving model to model_init_2024-11-0810_55_20.469517/model-00022-0.52077-0.81900-1.03733-0.72000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 176s 3s/step - categorical_accuracy: 0.8247 - loss: 0.4959 - val_categorical_accuracy: 0.7200 - val_loss: 1.0373 - learning_rate: 3.4300e-05
# Epoch 23/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8344 - loss: 0.4706
# Epoch 23: saving model to model_init_2024-11-0810_55_20.469517/model-00023-0.45920-0.83861-1.07384-0.71000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.8344 - loss: 0.4705 - val_categorical_accuracy: 0.7100 - val_loss: 1.0738 - learning_rate: 3.4300e-05
# Epoch 24/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8167 - loss: 0.5013
# Epoch 24: saving model to model_init_2024-11-0810_55_20.469517/model-00024-0.49408-0.82504-1.04739-0.70000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.8168 - loss: 0.5012 - val_categorical_accuracy: 0.7000 - val_loss: 1.0474 - learning_rate: 3.4300e-05
# Epoch 25/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8227 - loss: 0.4447
# Epoch 25: saving model to model_init_2024-11-0810_55_20.469517/model-00025-0.42732-0.84314-1.04491-0.68000.keras
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 2.400999692326877e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.8230 - loss: 0.4444 - val_categorical_accuracy: 0.6800 - val_loss: 1.0449 - learning_rate: 3.4300e-05
# Epoch 26/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8099 - loss: 0.4734
# Epoch 26: saving model to model_init_2024-11-0810_55_20.469517/model-00026-0.43911-0.84163-1.06664-0.70000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.8103 - loss: 0.4729 - val_categorical_accuracy: 0.7000 - val_loss: 1.0666 - learning_rate: 2.4010e-05
# Epoch 27/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8321 - loss: 0.4387
# Epoch 27: saving model to model_init_2024-11-0810_55_20.469517/model-00027-0.42687-0.83710-1.00134-0.69000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.8321 - loss: 0.4385 - val_categorical_accuracy: 0.6900 - val_loss: 1.0013 - learning_rate: 2.4010e-05
# Epoch 28/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8181 - loss: 0.4738
# Epoch 28: saving model to model_init_2024-11-0810_55_20.469517/model-00028-0.44562-0.83409-1.11821-0.68000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.8183 - loss: 0.4734 - val_categorical_accuracy: 0.6800 - val_loss: 1.1182 - learning_rate: 2.4010e-05
# Epoch 29/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8811 - loss: 0.4208
# Epoch 29: saving model to model_init_2024-11-0810_55_20.469517/model-00029-0.38363-0.88688-1.07595-0.69000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.8812 - loss: 0.4202 - val_categorical_accuracy: 0.6900 - val_loss: 1.0760 - learning_rate: 2.4010e-05
# Epoch 30/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8718 - loss: 0.3785
# Epoch 30: saving model to model_init_2024-11-0810_55_20.469517/model-00030-0.38596-0.86425-1.02305-0.72000.keras
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.6806997336971108e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.8717 - loss: 0.3786 - val_categorical_accuracy: 0.7200 - val_loss: 1.0230 - learning_rate: 2.4010e-05
# Epoch 31/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8588 - loss: 0.3897
# Epoch 31: saving model to model_init_2024-11-0810_55_20.469517/model-00031-0.38455-0.86576-1.03808-0.70000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.8589 - loss: 0.3896 - val_categorical_accuracy: 0.7000 - val_loss: 1.0381 - learning_rate: 1.6807e-05
# Epoch 32/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8979 - loss: 0.3460
# Epoch 32: saving model to model_init_2024-11-0810_55_20.469517/model-00032-0.34482-0.89593-1.02238-0.70000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.8979 - loss: 0.3460 - val_categorical_accuracy: 0.7000 - val_loss: 1.0224 - learning_rate: 1.6807e-05
# Epoch 33/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8887 - loss: 0.3654
# Epoch 33: saving model to model_init_2024-11-0810_55_20.469517/model-00033-0.36877-0.87783-1.05745-0.71000.keras
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.1764897499233484e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.8886 - loss: 0.3655 - val_categorical_accuracy: 0.7100 - val_loss: 1.0575 - learning_rate: 1.6807e-05
# Epoch 34/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8835 - loss: 0.3642
# Epoch 34: saving model to model_init_2024-11-0810_55_20.469517/model-00034-0.35823-0.88989-1.03644-0.69000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 174s 3s/step - categorical_accuracy: 0.8836 - loss: 0.3641 - val_categorical_accuracy: 0.6900 - val_loss: 1.0364 - learning_rate: 1.1765e-05
# Epoch 35/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.9018 - loss: 0.3403
# Epoch 35: saving model to model_init_2024-11-0810_55_20.469517/model-00035-0.34219-0.89744-1.02959-0.73000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 174s 3s/step - categorical_accuracy: 0.9017 - loss: 0.3404 - val_categorical_accuracy: 0.7300 - val_loss: 1.0296 - learning_rate: 1.1765e-05
# Epoch 36/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8782 - loss: 0.3322
# Epoch 36: saving model to model_init_2024-11-0810_55_20.469517/model-00036-0.34493-0.88084-0.99097-0.73000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.8783 - loss: 0.3324 - val_categorical_accuracy: 0.7300 - val_loss: 0.9910 - learning_rate: 1.1765e-05
# Epoch 37/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8730 - loss: 0.3704
# Epoch 37: saving model to model_init_2024-11-0810_55_20.469517/model-00037-0.34374-0.87632-1.03828-0.72000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 174s 3s/step - categorical_accuracy: 0.8731 - loss: 0.3700 - val_categorical_accuracy: 0.7200 - val_loss: 1.0383 - learning_rate: 1.1765e-05
# Epoch 38/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.9048 - loss: 0.3392
# Epoch 38: saving model to model_init_2024-11-0810_55_20.469517/model-00038-0.30792-0.90799-1.05619-0.72000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.9049 - loss: 0.3388 - val_categorical_accuracy: 0.7200 - val_loss: 1.0562 - learning_rate: 1.1765e-05
# Epoch 39/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.9084 - loss: 0.3422
# Epoch 39: saving model to model_init_2024-11-0810_55_20.469517/model-00039-0.33288-0.90045-1.04329-0.70000.keras
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 8.235428504121954e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 174s 3s/step - categorical_accuracy: 0.9083 - loss: 0.3420 - val_categorical_accuracy: 0.7000 - val_loss: 1.0433 - learning_rate: 1.1765e-05
# Epoch 40/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.9007 - loss: 0.3378
# Epoch 40: saving model to model_init_2024-11-0810_55_20.469517/model-00040-0.30743-0.91101-1.03518-0.70000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 174s 3s/step - categorical_accuracy: 0.9008 - loss: 0.3374 - val_categorical_accuracy: 0.7000 - val_loss: 1.0352 - learning_rate: 8.2354e-06

# %%
plot_training(history)

# %% [markdown]
# ### Results: Training accuracy improved substancially to 86%, but validation accuracy is ppears to be plateauing around 72-73%.
#
# Will try Conv3d with some adjustments 1) Add a bit more frames 20 to 22 2) Finetune ReduceLROnPlateau, increase patience for stability 3) Try Conv3D

# %% [markdown]
# ## Experiment 5 - Conv3D

# %%
from tensorflow.keras.layers import Conv3D, MaxPooling3D, BatchNormalization, Dropout, Flatten, Dense


# Define input shape and parameters
input_shape = (22, 128, 128, 3)  # Adjust as per frame count, image size, and channels
num_classes = 5

# Initialize Sequential model
model = Sequential()

# First Conv3D Block
model.add(Conv3D(32, (3, 3, 3), activation='relu', padding='same', input_shape=input_shape))
model.add(BatchNormalization())
model.add(MaxPooling3D((2, 2, 2)))
model.add(Dropout(0.2))

# Second Conv3D Block
model.add(Conv3D(64, (3, 3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling3D((2, 2, 2)))
model.add(Dropout(0.3))

# Third Conv3D Block
model.add(Conv3D(128, (2, 2, 2), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling3D((2, 2, 2)))
model.add(Dropout(0.3))

# Fourth Conv3D Block
model.add(Conv3D(256, (2, 2, 2), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling3D((2, 2, 2)))
model.add(Dropout(0.4))

# Flatten and Fully Connected Layers
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d (Conv3D)                 │ (None, 22, 128, 128,   │         2,624 │
# │                                 │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 22, 128, 128,   │           128 │
# │ (BatchNormalization)            │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 11, 64, 64, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 11, 64, 64, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 11, 64, 64, 64) │        55,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 11, 64, 64, 64) │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 5, 32, 32, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 5, 32, 32, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_2 (Conv3D)               │ (None, 5, 32, 32, 128) │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 5, 32, 32, 128) │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_2 (MaxPooling3D)  │ (None, 2, 16, 16, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 2, 16, 16, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_3 (Conv3D)               │ (None, 2, 16, 16, 256) │       262,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 2, 16, 16, 256) │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_3 (MaxPooling3D)  │ (None, 1, 8, 8, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 1, 8, 8, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 512)            │     8,389,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 5)              │         2,565 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,779,653 (33.49 MB)
#  Trainable params: 8,778,693 (33.49 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
# Fine-tuned ReduceLROnPlateau for gradual learning rate adjustment
LR = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,       # Slightly more conservative reduction
    patience=5,       # Increased patience for stability
    min_lr=1e-6,
    verbose=1
)

checkpoint = ModelCheckpoint(filepath='model_init_{epoch:05d}-{loss:.5f}-{accuracy:.5f}-{val_loss:.5f}-{val_accuracy:.5f}.keras',
                             save_best_only=True,
                             monitor='val_loss',
                             mode='min',
                             verbose=1)

callbacks_list = [checkpoint, LR]

# %%
curr_dt_time = datetime.datetime.now()
train_path = r'C:\Users\admin\Vidhya\Project_data\train'
val_path = r'C:\Users\admin\Vidhya\Project_data\val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 40
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 40

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

print(steps_per_epoch,validation_steps)
# Out:
# 67 10

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                    callbacks=callbacks_list, validation_data=val_generator,
                    validation_steps=validation_steps, class_weight=None, initial_epoch=0)
# Out:
# Source path = C:\Users\admin\Vidhya\Project_data\train ; batch size = 10
# Number of folders: 663
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_588\950058156.py:46: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# Epoch 1/40
# 65/67 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - accuracy: 0.2505 - loss: 22.5760
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_588\950058156.py:101: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2520 - loss: 22.3577Source path = C:\Users\admin\Vidhya\Project_data\val ; batch size = 10
# Number of folders: 100
#
# Epoch 1: val_loss improved from inf to 2.56060, saving model to model_init_00001-15.24161-0.30015-2.56060-0.37000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 108s 2s/step - accuracy: 0.2527 - loss: 22.2531 - val_accuracy: 0.3700 - val_loss: 2.5606 - learning_rate: 0.0010
# Epoch 2/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3817 - loss: 2.9605
# Epoch 2: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 99s 1s/step - accuracy: 0.3816 - loss: 2.9507 - val_accuracy: 0.2300 - val_loss: 21.7867 - learning_rate: 0.0010
# Epoch 3/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3604 - loss: 1.8223
# Epoch 3: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 98s 1s/step - accuracy: 0.3609 - loss: 1.8192 - val_accuracy: 0.2600 - val_loss: 33.1973 - learning_rate: 0.0010
# Epoch 4/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4194 - loss: 1.4624
# Epoch 4: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.4192 - loss: 1.4623 - val_accuracy: 0.2800 - val_loss: 12.4298 - learning_rate: 0.0010
# Epoch 5/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4180 - loss: 1.4960
# Epoch 5: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 98s 1s/step - accuracy: 0.4183 - loss: 1.4962 - val_accuracy: 0.2800 - val_loss: 17.4396 - learning_rate: 0.0010
# Epoch 6/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4314 - loss: 1.5320
# Epoch 6: val_loss did not improve from 2.56060
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.4315 - loss: 1.5312 - val_accuracy: 0.3000 - val_loss: 5.8927 - learning_rate: 0.0010
# Epoch 7/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4587 - loss: 1.3479
# Epoch 7: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.4589 - loss: 1.3470 - val_accuracy: 0.3300 - val_loss: 5.8843 - learning_rate: 5.0000e-04
# Epoch 8/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4728 - loss: 1.2522
# Epoch 8: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.4732 - loss: 1.2515 - val_accuracy: 0.3100 - val_loss: 7.4492 - learning_rate: 5.0000e-04
# Epoch 9/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5468 - loss: 1.1089
# Epoch 9: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.5467 - loss: 1.1092 - val_accuracy: 0.3400 - val_loss: 7.6963 - learning_rate: 5.0000e-04
# Epoch 10/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5724 - loss: 1.0727
# Epoch 10: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.5719 - loss: 1.0731 - val_accuracy: 0.3400 - val_loss: 5.6566 - learning_rate: 5.0000e-04
# Epoch 11/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5870 - loss: 1.0334
# Epoch 11: val_loss did not improve from 2.56060
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.5867 - loss: 1.0339 - val_accuracy: 0.2900 - val_loss: 9.2769 - learning_rate: 5.0000e-04
# Epoch 12/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5385 - loss: 1.0308
# Epoch 12: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.5389 - loss: 1.0303 - val_accuracy: 0.2800 - val_loss: 6.3941 - learning_rate: 2.5000e-04
# Epoch 13/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5564 - loss: 0.9543
# Epoch 13: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.5570 - loss: 0.9542 - val_accuracy: 0.3600 - val_loss: 6.0439 - learning_rate: 2.5000e-04
# Epoch 14/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5891 - loss: 0.9842
# Epoch 14: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.5892 - loss: 0.9840 - val_accuracy: 0.3600 - val_loss: 7.0545 - learning_rate: 2.5000e-04
# Epoch 15/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5938 - loss: 0.9313
# Epoch 15: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.5943 - loss: 0.9308 - val_accuracy: 0.3900 - val_loss: 5.9374 - learning_rate: 2.5000e-04
# Epoch 16/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6003 - loss: 0.9600
# Epoch 16: val_loss did not improve from 2.56060
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.6007 - loss: 0.9592 - val_accuracy: 0.3100 - val_loss: 6.5779 - learning_rate: 2.5000e-04
# Epoch 17/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5837 - loss: 0.9968
# Epoch 17: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.5843 - loss: 0.9953 - val_accuracy: 0.3700 - val_loss: 5.8601 - learning_rate: 1.2500e-04
# Epoch 18/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6379 - loss: 0.8026
# Epoch 18: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.6381 - loss: 0.8031 - val_accuracy: 0.3600 - val_loss: 6.7907 - learning_rate: 1.2500e-04
# Epoch 19/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6770 - loss: 0.8444
# Epoch 19: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.6770 - loss: 0.8441 - val_accuracy: 0.3600 - val_loss: 4.8272 - learning_rate: 1.2500e-04
# Epoch 20/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6613 - loss: 0.8049
# Epoch 20: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.6615 - loss: 0.8046 - val_accuracy: 0.3800 - val_loss: 4.8571 - learning_rate: 1.2500e-04
# Epoch 21/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7002 - loss: 0.7308
# Epoch 21: val_loss did not improve from 2.56060
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.7000 - loss: 0.7314 - val_accuracy: 0.3600 - val_loss: 6.4289 - learning_rate: 1.2500e-04
# Epoch 22/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6780 - loss: 0.7773
# Epoch 22: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.6780 - loss: 0.7771 - val_accuracy: 0.3700 - val_loss: 5.7035 - learning_rate: 6.2500e-05
# Epoch 23/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6770 - loss: 0.7244
# Epoch 23: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.6775 - loss: 0.7240 - val_accuracy: 0.3800 - val_loss: 6.2527 - learning_rate: 6.2500e-05
# Epoch 24/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6461 - loss: 0.8234
# Epoch 24: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.6467 - loss: 0.8223 - val_accuracy: 0.3900 - val_loss: 6.0745 - learning_rate: 6.2500e-05
# Epoch 25/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6496 - loss: 0.7809
# Epoch 25: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.6499 - loss: 0.7810 - val_accuracy: 0.3400 - val_loss: 7.0267 - learning_rate: 6.2500e-05
# Epoch 26/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6857 - loss: 0.7387
# Epoch 26: val_loss did not improve from 2.56060
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.6862 - loss: 0.7385 - val_accuracy: 0.3200 - val_loss: 7.3835 - learning_rate: 6.2500e-05
# Epoch 27/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6960 - loss: 0.7316
# Epoch 27: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.6962 - loss: 0.7314 - val_accuracy: 0.3600 - val_loss: 6.7139 - learning_rate: 3.1250e-05
# Epoch 28/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7469 - loss: 0.6572
# Epoch 28: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.7468 - loss: 0.6572 - val_accuracy: 0.3700 - val_loss: 7.1026 - learning_rate: 3.1250e-05
# Epoch 29/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7366 - loss: 0.6575
# Epoch 29: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.7362 - loss: 0.6579 - val_accuracy: 0.3700 - val_loss: 7.1675 - learning_rate: 3.1250e-05
# Epoch 30/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6691 - loss: 0.7210
# Epoch 30: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.6693 - loss: 0.7209 - val_accuracy: 0.3800 - val_loss: 6.9467 - learning_rate: 3.1250e-05
# Epoch 31/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7006 - loss: 0.7185
# Epoch 31: val_loss did not improve from 2.56060
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.7007 - loss: 0.7182 - val_accuracy: 0.3300 - val_loss: 7.1137 - learning_rate: 3.1250e-05
# Epoch 32/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7272 - loss: 0.6453
# Epoch 32: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.7273 - loss: 0.6453 - val_accuracy: 0.3400 - val_loss: 7.2946 - learning_rate: 1.5625e-05
# Epoch 33/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7236 - loss: 0.7040
# Epoch 33: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.7237 - loss: 0.7035 - val_accuracy: 0.3500 - val_loss: 7.3187 - learning_rate: 1.5625e-05
# Epoch 34/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7011 - loss: 0.6644
# Epoch 34: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.7013 - loss: 0.6644 - val_accuracy: 0.3600 - val_loss: 6.3075 - learning_rate: 1.5625e-05
# Epoch 35/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7155 - loss: 0.6787
# Epoch 35: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.7155 - loss: 0.6785 - val_accuracy: 0.3700 - val_loss: 6.4616 - learning_rate: 1.5625e-05
# Epoch 36/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7138 - loss: 0.7071
# Epoch 36: val_loss did not improve from 2.56060
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.7137 - loss: 0.7070 - val_accuracy: 0.3700 - val_loss: 6.4679 - learning_rate: 1.5625e-05
# Epoch 37/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7130 - loss: 0.6655
# Epoch 37: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.7129 - loss: 0.6656 - val_accuracy: 0.3800 - val_loss: 6.2674 - learning_rate: 7.8125e-06
# Epoch 38/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7271 - loss: 0.6015
# Epoch 38: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.7270 - loss: 0.6021 - val_accuracy: 0.3500 - val_loss: 6.4779 - learning_rate: 7.8125e-06
# Epoch 39/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7168 - loss: 0.7061
# Epoch 39: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.7169 - loss: 0.7054 - val_accuracy: 0.3400 - val_loss: 6.5975 - learning_rate: 7.8125e-06
# Epoch 40/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7044 - loss: 0.6687
# Epoch 40: val_loss did not improve from 2.56060
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.7048 - loss: 0.6680 - val_accuracy: 0.3700 - val_loss: 7.2305 - learning_rate: 7.8125e-06

# %% [markdown]
# ### It looks like model has a good start but is struggling to generalize to the validation set, resulting in a high validation loss and inconsistent validation accuracy. This issue often arises due to overfitting or insufficient feature extraction in earlier layers.
#
# Add more convolutional layers , increase filter sizes Add a TimeDistributed Layer with an RNN Lower Dropout Values
#
# learning rate might be too high even with ReduceLROnPlateau

# %% [markdown]
# ## Exp 6 - Conv3D + RNN

# %% [markdown]
# #### starting with a slightly lower initial learning rate, such as 1e-4 Decrease patience

# %%
from tensorflow.keras.layers import Conv3D, MaxPooling3D, BatchNormalization, Dropout, Flatten, Dense, TimeDistributed, GRU
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

# Define input shape and parameters
input_shape = (22, 128, 128, 3)  # Adjust as per frame count, image size, and channels
num_classes = 5

# Initialize Sequential model
model = Sequential()

# Conv3D Blocks
model.add(Conv3D(32, (3, 3, 3), activation='relu', padding='same', input_shape=input_shape))
model.add(BatchNormalization())
model.add(MaxPooling3D((2, 2, 2)))
model.add(Dropout(0.2))

model.add(Conv3D(64, (3, 3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling3D((2, 2, 2)))
model.add(Dropout(0.3))

model.add(Conv3D(128, (3, 3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling3D((2, 2, 2)))
model.add(Dropout(0.3))

model.add(Conv3D(256, (3, 3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling3D((2, 2, 2)))
model.add(Dropout(0.4))

# Adding TimeDistributed wrapper and RNN for temporal features
model.add(TimeDistributed(Flatten()))
model.add(GRU(128, return_sequences=False, dropout=0.3))

# Fully Connected Layers
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# %%
# Compile the model
optimizer = Adam(learning_rate=1e-4)  # Lower initial learning rate for gradual optimization
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d_4 (Conv3D)               │ (None, 22, 128, 128,   │         2,624 │
# │                                 │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_20          │ (None, 22, 128, 128,   │           128 │
# │ (BatchNormalization)            │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_4 (MaxPooling3D)  │ (None, 11, 64, 64, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 11, 64, 64, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_5 (Conv3D)               │ (None, 11, 64, 64, 64) │        55,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_21          │ (None, 11, 64, 64, 64) │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_5 (MaxPooling3D)  │ (None, 5, 32, 32, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_20 (Dropout)            │ (None, 5, 32, 32, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_6 (Conv3D)               │ (None, 5, 32, 32, 128) │       221,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_22          │ (None, 5, 32, 32, 128) │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_6 (MaxPooling3D)  │ (None, 2, 16, 16, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_21 (Dropout)            │ (None, 2, 16, 16, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_7 (Conv3D)               │ (None, 2, 16, 16, 256) │       884,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_23          │ (None, 2, 16, 16, 256) │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_7 (MaxPooling3D)  │ (None, 1, 8, 8, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_22 (Dropout)            │ (None, 1, 8, 8, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_68             │ (None, 1, 16384)       │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_4 (GRU)                     │ (None, 128)            │     6,341,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 512)            │        66,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_23 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 5)              │         2,565 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,576,197 (28.90 MB)
#  Trainable params: 7,575,237 (28.90 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
# Callbacks
LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1)
checkpoint = ModelCheckpoint(filepath='model_best.keras', save_best_only=True, monitor='val_loss', mode='min', verbose=1)
callbacks_list = [checkpoint, LR]

# %%
# Model Training
history = model.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=num_epochs,
    callbacks=callbacks_list,
    validation_data=val_generator,
    validation_steps=validation_steps,
    class_weight=None,
    initial_epoch=0
)
# Out:
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_588\950058156.py:46: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# Epoch 1/40
# 63/67 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.1805 - loss: 1.7265
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_588\950058156.py:101: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1811 - loss: 1.7250
# Epoch 1: val_loss improved from inf to 1.61500, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.1813 - loss: 1.7246 - val_accuracy: 0.2100 - val_loss: 1.6150 - learning_rate: 1.0000e-04
# Epoch 2/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2175 - loss: 1.6372
# Epoch 2: val_loss did not improve from 1.61500
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 102s 2s/step - accuracy: 0.2176 - loss: 1.6372 - val_accuracy: 0.2300 - val_loss: 1.6189 - learning_rate: 1.0000e-04
# Epoch 3/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2140 - loss: 1.6210
# Epoch 3: val_loss did not improve from 1.61500
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 104s 2s/step - accuracy: 0.2144 - loss: 1.6208 - val_accuracy: 0.2100 - val_loss: 1.6354 - learning_rate: 1.0000e-04
# Epoch 4/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3194 - loss: 1.5373
# Epoch 4: val_loss improved from 1.61500 to 1.59302, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 97s 1s/step - accuracy: 0.3193 - loss: 1.5369 - val_accuracy: 0.2200 - val_loss: 1.5930 - learning_rate: 1.0000e-04
# Epoch 5/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3034 - loss: 1.4861
# Epoch 5: val_loss improved from 1.59302 to 1.50938, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 104s 2s/step - accuracy: 0.3038 - loss: 1.4860 - val_accuracy: 0.2900 - val_loss: 1.5094 - learning_rate: 1.0000e-04
# Epoch 6/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3873 - loss: 1.4264
# Epoch 6: val_loss did not improve from 1.50938
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 101s 2s/step - accuracy: 0.3873 - loss: 1.4266 - val_accuracy: 0.2700 - val_loss: 1.5666 - learning_rate: 1.0000e-04
# Epoch 7/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4232 - loss: 1.3970
# Epoch 7: val_loss improved from 1.50938 to 1.40428, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 102s 2s/step - accuracy: 0.4228 - loss: 1.3970 - val_accuracy: 0.3400 - val_loss: 1.4043 - learning_rate: 1.0000e-04
# Epoch 8/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4622 - loss: 1.3186
# Epoch 8: val_loss did not improve from 1.40428
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 101s 2s/step - accuracy: 0.4622 - loss: 1.3185 - val_accuracy: 0.3400 - val_loss: 1.4367 - learning_rate: 1.0000e-04
# Epoch 9/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4560 - loss: 1.2713
# Epoch 9: val_loss did not improve from 1.40428
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 101s 2s/step - accuracy: 0.4562 - loss: 1.2711 - val_accuracy: 0.3700 - val_loss: 1.5204 - learning_rate: 1.0000e-04
# Epoch 10/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4907 - loss: 1.2392
# Epoch 10: val_loss did not improve from 1.40428
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 101s 2s/step - accuracy: 0.4909 - loss: 1.2389 - val_accuracy: 0.3100 - val_loss: 1.7286 - learning_rate: 1.0000e-04
# Epoch 11/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4943 - loss: 1.1659
# Epoch 11: val_loss did not improve from 1.40428
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 101s 2s/step - accuracy: 0.4946 - loss: 1.1658 - val_accuracy: 0.4400 - val_loss: 1.4394 - learning_rate: 5.0000e-05
# Epoch 12/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5866 - loss: 1.0611
# Epoch 12: val_loss improved from 1.40428 to 1.39697, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 101s 2s/step - accuracy: 0.5861 - loss: 1.0616 - val_accuracy: 0.4700 - val_loss: 1.3970 - learning_rate: 5.0000e-05
# Epoch 13/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5527 - loss: 1.1111
# Epoch 13: val_loss did not improve from 1.39697
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 100s 2s/step - accuracy: 0.5527 - loss: 1.1108 - val_accuracy: 0.3600 - val_loss: 1.6622 - learning_rate: 5.0000e-05
# Epoch 14/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6120 - loss: 0.9802
# Epoch 14: val_loss did not improve from 1.39697
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 100s 2s/step - accuracy: 0.6116 - loss: 0.9807 - val_accuracy: 0.3900 - val_loss: 1.4865 - learning_rate: 5.0000e-05
# Epoch 15/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5589 - loss: 1.0600
# Epoch 15: val_loss did not improve from 1.39697
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 101s 2s/step - accuracy: 0.5595 - loss: 1.0594 - val_accuracy: 0.4300 - val_loss: 1.4185 - learning_rate: 5.0000e-05
# Epoch 16/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6069 - loss: 0.9742
# Epoch 16: val_loss did not improve from 1.39697
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 100s 2s/step - accuracy: 0.6069 - loss: 0.9743 - val_accuracy: 0.4400 - val_loss: 1.5084 - learning_rate: 2.5000e-05
# Epoch 17/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6407 - loss: 0.9356
# Epoch 17: val_loss improved from 1.39697 to 1.31495, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 101s 2s/step - accuracy: 0.6408 - loss: 0.9353 - val_accuracy: 0.5200 - val_loss: 1.3150 - learning_rate: 2.5000e-05
# Epoch 18/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6696 - loss: 0.9096
# Epoch 18: val_loss improved from 1.31495 to 1.31435, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 101s 2s/step - accuracy: 0.6692 - loss: 0.9101 - val_accuracy: 0.4700 - val_loss: 1.3143 - learning_rate: 2.5000e-05
# Epoch 19/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6598 - loss: 0.8823
# Epoch 19: val_loss did not improve from 1.31435
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 100s 1s/step - accuracy: 0.6598 - loss: 0.8825 - val_accuracy: 0.4900 - val_loss: 1.3585 - learning_rate: 2.5000e-05
# Epoch 20/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6204 - loss: 0.9309
# Epoch 20: val_loss did not improve from 1.31435
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 100s 2s/step - accuracy: 0.6206 - loss: 0.9304 - val_accuracy: 0.4300 - val_loss: 1.4321 - learning_rate: 2.5000e-05
# Epoch 21/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6573 - loss: 0.8665
# Epoch 21: val_loss did not improve from 1.31435
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 100s 2s/step - accuracy: 0.6573 - loss: 0.8668 - val_accuracy: 0.4500 - val_loss: 1.4309 - learning_rate: 2.5000e-05
# Epoch 22/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6630 - loss: 0.9143
# Epoch 22: val_loss improved from 1.31435 to 1.17884, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 101s 2s/step - accuracy: 0.6628 - loss: 0.9139 - val_accuracy: 0.5500 - val_loss: 1.1788 - learning_rate: 1.2500e-05
# Epoch 23/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6224 - loss: 0.8852
# Epoch 23: val_loss did not improve from 1.17884
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 100s 2s/step - accuracy: 0.6230 - loss: 0.8846 - val_accuracy: 0.4900 - val_loss: 1.3062 - learning_rate: 1.2500e-05
# Epoch 24/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6992 - loss: 0.8225
# Epoch 24: val_loss did not improve from 1.17884
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 100s 2s/step - accuracy: 0.6992 - loss: 0.8224 - val_accuracy: 0.5500 - val_loss: 1.2455 - learning_rate: 1.2500e-05
# Epoch 25/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6868 - loss: 0.8141
# Epoch 25: val_loss improved from 1.17884 to 1.16961, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 100s 2s/step - accuracy: 0.6868 - loss: 0.8144 - val_accuracy: 0.5600 - val_loss: 1.1696 - learning_rate: 1.2500e-05
# Epoch 26/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7044 - loss: 0.8072
# Epoch 26: val_loss did not improve from 1.16961
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 99s 1s/step - accuracy: 0.7040 - loss: 0.8075 - val_accuracy: 0.4100 - val_loss: 1.4430 - learning_rate: 1.2500e-05
# Epoch 27/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7206 - loss: 0.8158
# Epoch 27: val_loss did not improve from 1.16961
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 100s 1s/step - accuracy: 0.7203 - loss: 0.8158 - val_accuracy: 0.5400 - val_loss: 1.1772 - learning_rate: 1.2500e-05
# Epoch 28/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7357 - loss: 0.7719
# Epoch 28: val_loss did not improve from 1.16961
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 100s 2s/step - accuracy: 0.7354 - loss: 0.7720 - val_accuracy: 0.4700 - val_loss: 1.3637 - learning_rate: 1.2500e-05
# Epoch 29/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6887 - loss: 0.8277
# Epoch 29: val_loss improved from 1.16961 to 1.11274, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 101s 2s/step - accuracy: 0.6887 - loss: 0.8275 - val_accuracy: 0.5500 - val_loss: 1.1127 - learning_rate: 6.2500e-06
# Epoch 30/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7055 - loss: 0.7998
# Epoch 30: val_loss did not improve from 1.11274
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 100s 2s/step - accuracy: 0.7054 - loss: 0.7999 - val_accuracy: 0.5200 - val_loss: 1.2686 - learning_rate: 6.2500e-06
# Epoch 31/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7193 - loss: 0.7609
# Epoch 31: val_loss did not improve from 1.11274
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 102s 2s/step - accuracy: 0.7192 - loss: 0.7612 - val_accuracy: 0.5000 - val_loss: 1.2738 - learning_rate: 6.2500e-06
# Epoch 32/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6905 - loss: 0.7829
# Epoch 32: val_loss did not improve from 1.11274
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 101s 2s/step - accuracy: 0.6907 - loss: 0.7827 - val_accuracy: 0.5100 - val_loss: 1.2729 - learning_rate: 6.2500e-06
# Epoch 33/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6564 - loss: 0.8564
# Epoch 33: val_loss did not improve from 1.11274
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 100s 2s/step - accuracy: 0.6571 - loss: 0.8555 - val_accuracy: 0.5000 - val_loss: 1.2534 - learning_rate: 3.1250e-06
# Epoch 34/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7133 - loss: 0.7716
# Epoch 34: val_loss did not improve from 1.11274
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 99s 1s/step - accuracy: 0.7132 - loss: 0.7716 - val_accuracy: 0.4600 - val_loss: 1.3756 - learning_rate: 3.1250e-06
# Epoch 35/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7475 - loss: 0.7144
# Epoch 35: val_loss did not improve from 1.11274
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 99s 1s/step - accuracy: 0.7474 - loss: 0.7148 - val_accuracy: 0.5500 - val_loss: 1.2101 - learning_rate: 3.1250e-06
# Epoch 36/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7330 - loss: 0.7849
# Epoch 36: val_loss did not improve from 1.11274
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 99s 1s/step - accuracy: 0.7331 - loss: 0.7847 - val_accuracy: 0.5500 - val_loss: 1.1866 - learning_rate: 1.5625e-06
# Epoch 37/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6861 - loss: 0.7493
# Epoch 37: val_loss did not improve from 1.11274
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 99s 1s/step - accuracy: 0.6862 - loss: 0.7496 - val_accuracy: 0.5300 - val_loss: 1.3677 - learning_rate: 1.5625e-06
# Epoch 38/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7306 - loss: 0.7313
# Epoch 38: val_loss did not improve from 1.11274
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 99s 1s/step - accuracy: 0.7302 - loss: 0.7319 - val_accuracy: 0.5500 - val_loss: 1.2550 - learning_rate: 1.5625e-06
# Epoch 39/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7145 - loss: 0.8045
# Epoch 39: val_loss did not improve from 1.11274
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 98s 1s/step - accuracy: 0.7148 - loss: 0.8037 - val_accuracy: 0.5100 - val_loss: 1.1749 - learning_rate: 1.0000e-06
# Epoch 40/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7559 - loss: 0.7558
# Epoch 40: val_loss did not improve from 1.11274
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 99s 1s/step - accuracy: 0.7556 - loss: 0.7559 - val_accuracy: 0.5200 - val_loss: 1.2833 - learning_rate: 1.0000e-06

# %%
# Plotting function
def plot_training_conv3d(history):
    plt.figure(figsize=(12, 6))

    # Plot accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Training and Validation Accuracy')

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Training and Validation Loss')

    plt.show()

plot_training_conv3d(history)

# %% [markdown]
# #### Overfitting: Training accuracy reaches ~56% while validation accuracy stays around 34-44% Validation loss often increases while training loss decreases Large gap between training and validation metrics
#
# Analysis Looks like model is complex Four Conv3D layers might be excessive The architecture might be learning noise rather than meaningful features.

# %%
#Simlified architecture with early stopping

input_shape = (22, 128, 128, 3)  # Your current input shape
num_classes = 5

# Initialize Sequential model
model = Sequential()

# First Conv3D Block
model.add(Conv3D(32, (3, 3, 3), activation='relu', padding='same', input_shape=input_shape))
model.add(BatchNormalization())
model.add(MaxPooling3D((2, 2, 2)))
model.add(Dropout(0.3))

# Second Conv3D Block
model.add(Conv3D(64, (3, 3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling3D((2, 2, 2)))
model.add(Dropout(0.4))

# Flatten and RNN
model.add(TimeDistributed(Flatten()))
model.add(GRU(64, dropout=0.3))

# Dense Layers
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# %%
# Compile the model
optimizer = Adam(learning_rate=5e-4)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d_8 (Conv3D)               │ (None, 22, 128, 128,   │         2,624 │
# │                                 │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_24          │ (None, 22, 128, 128,   │           128 │
# │ (BatchNormalization)            │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_8 (MaxPooling3D)  │ (None, 11, 64, 64, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_24 (Dropout)            │ (None, 11, 64, 64, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_9 (Conv3D)               │ (None, 11, 64, 64, 64) │        55,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_25          │ (None, 11, 64, 64, 64) │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_9 (MaxPooling3D)  │ (None, 5, 32, 32, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_25 (Dropout)            │ (None, 5, 32, 32, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_69             │ (None, 5, 65536)       │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_5 (GRU)                     │ (None, 64)             │    12,595,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_26 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,662,917 (48.31 MB)
#  Trainable params: 12,662,725 (48.30 MB)
#  Non-trainable params: 192 (768.00 B)

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

##

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

print(steps_per_epoch,validation_steps)
print(num_epochs)
# Out:
# 67 10
# 40

# %%
# Define callbacks
LR = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=4,
    min_lr=1e-6,
    verbose=1
)

checkpoint = ModelCheckpoint(
    filepath='model_best.keras',
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

# Combine all callbacks
callbacks_list = [LR, checkpoint]

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                    callbacks=callbacks_list, validation_data=val_generator,
                    validation_steps=validation_steps, class_weight=None, initial_epoch=0)
# Out:
# Source path = C:\Users\admin\Vidhya\Project_data\train ; batch size = 10
# Number of folders: 663
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_588\950058156.py:46: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# Epoch 1/40
# 65/67 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - accuracy: 0.1755 - loss: 1.7949
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_588\950058156.py:101: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1761 - loss: 1.7930Source path = C:\Users\admin\Vidhya\Project_data\val ; batch size = 10
# Number of folders: 100
#
# Epoch 1: val_loss improved from inf to 1.60309, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - accuracy: 0.1765 - loss: 1.7921 - val_accuracy: 0.2700 - val_loss: 1.6031 - learning_rate: 5.0000e-04
# Epoch 2/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2023 - loss: 1.6940
# Epoch 2: val_loss did not improve from 1.60309
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 99s 1s/step - accuracy: 0.2022 - loss: 1.6937 - val_accuracy: 0.2100 - val_loss: 1.6439 - learning_rate: 5.0000e-04
# Epoch 3/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1914 - loss: 1.6761
# Epoch 3: val_loss did not improve from 1.60309
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 98s 1s/step - accuracy: 0.1913 - loss: 1.6760 - val_accuracy: 0.2500 - val_loss: 1.6182 - learning_rate: 5.0000e-04
# Epoch 4/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2160 - loss: 1.6401
# Epoch 4: val_loss did not improve from 1.60309
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.2160 - loss: 1.6403 - val_accuracy: 0.2900 - val_loss: 1.6057 - learning_rate: 5.0000e-04
# Epoch 5/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2336 - loss: 1.6285
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 5: val_loss did not improve from 1.60309
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 97s 1s/step - accuracy: 0.2337 - loss: 1.6283 - val_accuracy: 0.2400 - val_loss: 1.6088 - learning_rate: 5.0000e-04
# Epoch 6/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1876 - loss: 1.6328
# Epoch 6: val_loss improved from 1.60309 to 1.60153, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 97s 1s/step - accuracy: 0.1879 - loss: 1.6328 - val_accuracy: 0.2300 - val_loss: 1.6015 - learning_rate: 1.0000e-04
# Epoch 7/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1894 - loss: 1.6216
# Epoch 7: val_loss improved from 1.60153 to 1.59029, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.1896 - loss: 1.6215 - val_accuracy: 0.2300 - val_loss: 1.5903 - learning_rate: 1.0000e-04
# Epoch 8/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2199 - loss: 1.5947
# Epoch 8: val_loss improved from 1.59029 to 1.58548, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.2199 - loss: 1.5949 - val_accuracy: 0.2600 - val_loss: 1.5855 - learning_rate: 1.0000e-04
# Epoch 9/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2327 - loss: 1.5958
# Epoch 9: val_loss did not improve from 1.58548
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 93s 1s/step - accuracy: 0.2328 - loss: 1.5958 - val_accuracy: 0.2600 - val_loss: 1.5882 - learning_rate: 1.0000e-04
# Epoch 10/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2581 - loss: 1.5942
# Epoch 10: val_loss improved from 1.58548 to 1.57451, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.2576 - loss: 1.5943 - val_accuracy: 0.3100 - val_loss: 1.5745 - learning_rate: 1.0000e-04
# Epoch 11/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2239 - loss: 1.6002
# Epoch 11: val_loss improved from 1.57451 to 1.57267, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.2237 - loss: 1.6002 - val_accuracy: 0.3000 - val_loss: 1.5727 - learning_rate: 1.0000e-04
# Epoch 12/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2253 - loss: 1.5936
# Epoch 12: val_loss improved from 1.57267 to 1.56793, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.2258 - loss: 1.5935 - val_accuracy: 0.3100 - val_loss: 1.5679 - learning_rate: 1.0000e-04
# Epoch 13/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2200 - loss: 1.5984
# Epoch 13: val_loss improved from 1.56793 to 1.56567, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.2202 - loss: 1.5984 - val_accuracy: 0.3300 - val_loss: 1.5657 - learning_rate: 1.0000e-04
# Epoch 14/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2361 - loss: 1.5898
# Epoch 14: val_loss did not improve from 1.56567
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.2361 - loss: 1.5898 - val_accuracy: 0.3200 - val_loss: 1.5712 - learning_rate: 1.0000e-04
# Epoch 15/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2657 - loss: 1.5766
# Epoch 15: val_loss did not improve from 1.56567
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.2655 - loss: 1.5767 - val_accuracy: 0.2700 - val_loss: 1.5722 - learning_rate: 1.0000e-04
# Epoch 16/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2857 - loss: 1.5743
# Epoch 16: val_loss did not improve from 1.56567
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.2855 - loss: 1.5743 - val_accuracy: 0.3000 - val_loss: 1.5708 - learning_rate: 1.0000e-04
# Epoch 17/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2594 - loss: 1.5745
# Epoch 17: val_loss improved from 1.56567 to 1.55408, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.2599 - loss: 1.5743 - val_accuracy: 0.3100 - val_loss: 1.5541 - learning_rate: 1.0000e-04
# Epoch 18/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3214 - loss: 1.5487
# Epoch 18: val_loss improved from 1.55408 to 1.53745, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.3212 - loss: 1.5486 - val_accuracy: 0.3900 - val_loss: 1.5375 - learning_rate: 1.0000e-04
# Epoch 19/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3082 - loss: 1.5543
# Epoch 19: val_loss improved from 1.53745 to 1.52772, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.3082 - loss: 1.5542 - val_accuracy: 0.3700 - val_loss: 1.5277 - learning_rate: 1.0000e-04
# Epoch 20/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3513 - loss: 1.5216
# Epoch 20: val_loss improved from 1.52772 to 1.50904, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.3512 - loss: 1.5217 - val_accuracy: 0.4100 - val_loss: 1.5090 - learning_rate: 1.0000e-04
# Epoch 21/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3508 - loss: 1.5034
# Epoch 21: val_loss did not improve from 1.50904
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.3509 - loss: 1.5034 - val_accuracy: 0.3900 - val_loss: 1.5254 - learning_rate: 1.0000e-04
# Epoch 22/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3182 - loss: 1.5221
# Epoch 22: val_loss did not improve from 1.50904
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.3183 - loss: 1.5222 - val_accuracy: 0.3900 - val_loss: 1.5234 - learning_rate: 1.0000e-04
# Epoch 23/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3407 - loss: 1.5041
# Epoch 23: val_loss improved from 1.50904 to 1.48272, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.3409 - loss: 1.5041 - val_accuracy: 0.3800 - val_loss: 1.4827 - learning_rate: 1.0000e-04
# Epoch 24/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3674 - loss: 1.4927
# Epoch 24: val_loss did not improve from 1.48272
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 93s 1s/step - accuracy: 0.3672 - loss: 1.4927 - val_accuracy: 0.3800 - val_loss: 1.5062 - learning_rate: 1.0000e-04
# Epoch 25/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4097 - loss: 1.4465
# Epoch 25: val_loss did not improve from 1.48272
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.4094 - loss: 1.4468 - val_accuracy: 0.3100 - val_loss: 1.4966 - learning_rate: 1.0000e-04
# Epoch 26/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3942 - loss: 1.4488
# Epoch 26: val_loss improved from 1.48272 to 1.44203, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.3939 - loss: 1.4489 - val_accuracy: 0.3600 - val_loss: 1.4420 - learning_rate: 1.0000e-04
# Epoch 27/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4097 - loss: 1.4290
# Epoch 27: val_loss improved from 1.44203 to 1.41172, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.4097 - loss: 1.4288 - val_accuracy: 0.4000 - val_loss: 1.4117 - learning_rate: 1.0000e-04
# Epoch 28/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4254 - loss: 1.3905
# Epoch 28: val_loss improved from 1.41172 to 1.39748, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.4251 - loss: 1.3908 - val_accuracy: 0.4100 - val_loss: 1.3975 - learning_rate: 1.0000e-04
# Epoch 29/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4304 - loss: 1.4095
# Epoch 29: val_loss improved from 1.39748 to 1.38314, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.4304 - loss: 1.4092 - val_accuracy: 0.4100 - val_loss: 1.3831 - learning_rate: 1.0000e-04
# Epoch 30/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4218 - loss: 1.3767
# Epoch 30: val_loss improved from 1.38314 to 1.37565, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.4219 - loss: 1.3768 - val_accuracy: 0.4100 - val_loss: 1.3756 - learning_rate: 1.0000e-04
# Epoch 31/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4449 - loss: 1.3312
# Epoch 31: val_loss improved from 1.37565 to 1.32854, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.4449 - loss: 1.3312 - val_accuracy: 0.4300 - val_loss: 1.3285 - learning_rate: 1.0000e-04
# Epoch 32/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4612 - loss: 1.3390
# Epoch 32: val_loss improved from 1.32854 to 1.26686, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.4611 - loss: 1.3390 - val_accuracy: 0.5100 - val_loss: 1.2669 - learning_rate: 1.0000e-04
# Epoch 33/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4742 - loss: 1.3139
# Epoch 33: val_loss did not improve from 1.26686
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.4741 - loss: 1.3137 - val_accuracy: 0.5100 - val_loss: 1.2746 - learning_rate: 1.0000e-04
# Epoch 34/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4773 - loss: 1.2945
# Epoch 34: val_loss did not improve from 1.26686
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.4772 - loss: 1.2947 - val_accuracy: 0.4200 - val_loss: 1.3069 - learning_rate: 1.0000e-04
# Epoch 35/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4522 - loss: 1.3052
# Epoch 35: val_loss improved from 1.26686 to 1.20107, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 97s 1s/step - accuracy: 0.4528 - loss: 1.3045 - val_accuracy: 0.5600 - val_loss: 1.2011 - learning_rate: 1.0000e-04
# Epoch 36/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4959 - loss: 1.2330
# Epoch 36: val_loss improved from 1.20107 to 1.19516, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.4958 - loss: 1.2330 - val_accuracy: 0.5700 - val_loss: 1.1952 - learning_rate: 1.0000e-04
# Epoch 37/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4842 - loss: 1.2964
# Epoch 37: val_loss improved from 1.19516 to 1.18931, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.4846 - loss: 1.2954 - val_accuracy: 0.5300 - val_loss: 1.1893 - learning_rate: 1.0000e-04
# Epoch 38/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5165 - loss: 1.1772
# Epoch 38: val_loss did not improve from 1.18931
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.5164 - loss: 1.1773 - val_accuracy: 0.5300 - val_loss: 1.1977 - learning_rate: 1.0000e-04
# Epoch 39/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5550 - loss: 1.1738
# Epoch 39: val_loss improved from 1.18931 to 1.14150, saving model to model_best.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.5549 - loss: 1.1736 - val_accuracy: 0.5400 - val_loss: 1.1415 - learning_rate: 1.0000e-04
# Epoch 40/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5432 - loss: 1.1573
# Epoch 40: val_loss did not improve from 1.14150
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.5430 - loss: 1.1574 - val_accuracy: 0.5600 - val_loss: 1.1440 - learning_rate: 1.0000e-04

# %%
plot_training_conv3d(history)

# %%
Adding more layers,
# Out:
#   Cell In[142], line 1
#     Adding more layers,
#            ^
# SyntaxError: invalid syntax

# %%
'''from tensorflow.keras.models import Sequential
#from tensorflow.keras.layers import Conv3D, BatchNormalization, MaxPooling3D, Dropout
from tensorflow.keras.layers import Flatten, GRU, Dense, GlobalAveragePooling3D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint

# Define input shape and parameters
input_shape = (22, 128, 128, 3)
num_classes = 5

# Initialize Sequential model
model = Sequential([
    # First Conv3D Block
    Conv3D(64, kernel_size=(3, 3, 3), activation='relu', padding='same',
           input_shape=input_shape, kernel_initializer='he_normal'),
    BatchNormalization(),
    Conv3D(64, kernel_size=(3, 3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling3D(pool_size=(1, 2, 2)),
    Dropout(0.25),

    # Second Conv3D Block
    Conv3D(128, kernel_size=(3, 3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    Conv3D(128, kernel_size=(3, 3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling3D(pool_size=(1, 2, 2)),
    Dropout(0.25),

    # Third Conv3D Block
    Conv3D(256, kernel_size=(3, 3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    Conv3D(256, kernel_size=(3, 3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling3D(pool_size=(1, 2, 2)),
    Dropout(0.25),

    # Fourth Conv3D Block
    Conv3D(512, kernel_size=(3, 3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    Conv3D(512, kernel_size=(3, 3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling3D(pool_size=(1, 2, 2)),
    Dropout(0.25),

    # Fifth Conv3D Block - Added for more feature extraction
    Conv3D(512, kernel_size=(3, 3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    Conv3D(512, kernel_size=(3, 3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling3D(pool_size=(2, 2, 2)),  # Now we reduce temporal dimension
    Dropout(0.25),

    # Global Average Pooling
    GlobalAveragePooling3D(),

    # Dense layers with residual connections
    Dense(1024, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),

    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),

    Dense(num_classes, activation='softmax')
])

# Compile with optimized learning rate and gradient clipping
optimizer = Adam(learning_rate=0.0001, clipnorm=1.0)
model.compile(optimizer=optimizer,
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# Enhanced callbacks for better training
callbacks = [
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.2,
        patience=5,
        min_lr=1e-7,
        verbose=1
    ),
    ModelCheckpoint(
        filepath='model_best.keras',
        save_best_only=True,
        monitor='val_loss',
        mode='min',
        verbose=1
    )
]'''
# Out:
# "from tensorflow.keras.models import Sequential\n#from tensorflow.keras.layers import Conv3D, BatchNormalization, MaxPooling3D, Dropout\nfrom tensorflow.keras.layers import Flatten, GRU, Dense, GlobalAveragePooling3D\nfrom tensorflow.keras.optimizers import Adam\nfrom tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint\n\n# Define input shape and parameters\ninput_shape = (22, 128, 128, 3)\nnum_classes = 5\n\n# Initialize Sequential model\nmodel = Sequential([\n    # First Conv3D Block\n    Conv3D(64, kernel_size=(3, 3, 3), activation='relu', padding='same',\n           input_shape=input_shape, kernel_initializer='he_normal'),\n    BatchNormalization(),\n    Conv3D(64, kernel_size=(3, 3, 3), activation='relu', padding='same'),\n    BatchNormalization(),\n    MaxPooling3D(pool_size=(1, 2, 2)),\n    Dropout(0.25),\n\n    # Second Conv3D Block\n    Conv3D(128, kernel_size=(3, 3, 3), activation='relu', padding='same'),\n    BatchNormalization(),\n    Conv3D(128, kernel_size=(3, 3, 3), activation='relu', padding='same'),\n    BatchNormalization(),\n    MaxPooling3D(pool_size=(1, 2, 2)),\n    Dropout(0.25),\n\n    # Third Conv3D Block\n    Conv3D(256, kernel_size=(3, 3, 3), activation='relu', padding='same'),\n    BatchNormalization(),\n    Conv3D(256, kernel_size=(3, 3, 3), activation='relu', padding='same'),\n    BatchNormalization(),\n    MaxPooling3D(pool_size=(1, 2, 2)),\n    Dropout(0.25),\n\n    # Fourth Conv3D Block\n    Conv3D(512, kernel_size=(3, 3, 3), activation='relu', padding='same'),\n    BatchNormalization(),\n    Conv3D(512, kernel_size=(3, 3, 3), activation='relu', padding='same'),\n    BatchNormalization(),\n    MaxPooling3D(pool_size=(1, 2, 2)),\n    Dropout(0.25),\n\n    # Fifth Conv3D Block - Added for more feature extraction\n    Conv3D(512, kernel_size=(3, 3, 3), activation='relu', padding='same'),\n    BatchNormalization(),\n    Conv3D(512, kernel_size=(3, 3, 3), activation='relu', padding='same'),\n    BatchNormalization(),\n    MaxPooling3D(pool_size=(2, 2, 2)),  # Now we reduce temporal dimension\n    Dropout(0.25),\n\n    # Global Average Pooling\n    GlobalAveragePooling3D(),\n\n    # Dense layers with residual connections\n    Dense(1024, activation='relu'),\n    BatchNormalization(),\n    Dropout(0.5),\n\n    Dense(512, activation='relu'),\n    BatchNormalization(),\n    Dropout(0.5),\n\n    Dense(num_classes, activation='softmax')\n])\n\n# Compile with optimized learning rate and gradient clipping\noptimizer = Adam(learning_rate=0.0001, clipnorm=1.0)\nmodel.compile(optimizer=optimizer,\n             loss='categorical_crossentropy',\n             metrics=['accuracy'])\n\n# Enhanced callbacks for better training\ncallbacks = [\n    ReduceLROnPlateau(\n        monitor='val_loss',\n        factor=0.2,\n        patience=5,\n        min_lr=1e-7,\n        verbose=1\n    ),\n    ModelCheckpoint(\n        filepath='model_best.keras',\n        save_best_only=True,\n        monitor='val_loss',\n        mode='min',\n        verbose=1\n    )\n]"

# %%
#model.summary()

# %% [markdown]
# ### Double-click (or enter) to edit

# %% [markdown]
# ### Final Analysis
# Throughout our experiments, the Conv2D + GRU architecture emerged as the most effective model for our gesture recognition task. By selecting 20 frames, increasing the epochs to 40, and balancing model complexity with regularization, we achieved a substantial improvement in validation accuracy, reaching approximately 72%.
#
# Frame Selection & Epochs: Increasing the number of frames and epochs proved crucial in enhancing model performance, as it provided a richer temporal context and allowed the model more time to converge.
# Simplified Architecture with GRU: While LSTMs struggled to generalize well on data, GRUs maintained a balance, leading to better validation performance.
# Regularization & Dropout: Regularization techniques like Dropout effectively reduced overfitting, particularly in complex architectures.
# Avoiding Overly Complex Layers: Deeper architectures with multiple Conv3D layers and high frame counts tended to overfit, learning noise rather than valuable features. Simplified Conv2D layers with GRU performed best by capturing temporal dynamics without excessive complexity. Future improvements could include fine-tuning hyperparameters, experimenting with slightly lower batch sizes (if memory allows), and using techniques like learning rate scheduling to further refine convergence. Looks like, complex architectures often introduce noise, reaffirming that simpler, well-regularized models are often more robust for this type of sequential data.
