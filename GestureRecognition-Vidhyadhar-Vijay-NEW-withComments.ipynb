# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
#!pip install tensorflow

# %%
#!pip3 install opencv-python

# %%
import numpy as np
import os
# from scipy.misc import imread, imresize
import datetime
import os
import tensorflow as tf
from imageio import imread
import cv2

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K

tf.random.set_seed(30)

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
train_doc = np.random.permutation(open(r'C:\Users\admin\Vidhya\Project_data\train.csv').readlines())
val_doc = np.random.permutation(open(r'C:\Users\admin\Vidhya\Project_data\val.csv').readlines())
batch_size = 10 #experiment with the batch size

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
#Set the parameters, should be used in model architecture also

#More images
start_frames = [1, 2, 3, 6]  # Gesture initiation
middle_frames = [8, 9, 10, 14, 15, 16, 17, 20]  # Early movement & middle
end_frames = [22, 23, 24, 25, 26, 27, 28, 29]  # Gesture completion

# Combine selected frames
img_idx = start_frames + middle_frames + end_frames


y, z = 128, 128  # Desired height and width
target_size = (y, z)
x = len(img_idx)  # Number of frames per video
print(x)
print(img_idx)
# Out:
# 20
# [1, 2, 3, 6, 8, 9, 10, 14, 15, 16, 17, 20, 22, 23, 24, 25, 26, 27, 28, 29]

# %%
def generator(source_path, folder_list, batch_size):
    print('Source path =', source_path, '; batch size =', batch_size)

    #print('Source path =', source_path, '; batch size =', batch_size)
    print('Number of folders:', len(folder_list))  # Debug print
    
    # Validate inputs
    if folder_list.size == 0:  # Check if folder_list is empty
        raise ValueError("folder_list is empty")
    

    img_idx = [1, 2, 3, 6, 8, 9, 10, 14, 15, 16, 17, 20, 22, 23, 24, 25, 26, 27, 28, 29]
    
    y, z = 128, 128  # Desired height and width
    target_size = (y, z)
    x = len(img_idx)  # Number of frames per video

    
    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(folder_list) // batch_size
        
        for batch in range(num_batches):
            batch_data = np.zeros((batch_size, x, y, z, 3))
            batch_labels = np.zeros((batch_size, 5))
            
            for folder in range(batch_size):
                #folder_path = os.path.normpath((os.path.join(source_path, t[folder + (batch * batch_size)].strip().split(';')[0])))
                folder_name = t[folder + (batch * batch_size)].strip().split(';')[0]
                folder_path = os.path.join(source_path, folder_name)
                folder_path = os.path.normpath(folder_path)  # Ensure a consistent path format

                imgs = os.listdir(folder_path)
                
                for idx, item in enumerate(img_idx):
                    if item >= len(imgs):
                        print(f"Warning: Frame {item} not found in folder, skipping...")
                        continue
                    
                    image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
                    
                    # Crop to square and resize
                    if image.shape[1] > image.shape[0]:
                        crop_start = (image.shape[1] - image.shape[0]) // 2
                        crop_end = crop_start + image.shape[0]
                        image = image[:, crop_start:crop_end]
                    elif image.shape[0] > image.shape[1]:
                        crop_start = (image.shape[0] - image.shape[1]) // 2
                        crop_end = crop_start + image.shape[1]
                        image = image[crop_start:crop_end, :]

                    image_resized = cv2.resize(image, target_size, interpolation=cv2.INTER_LINEAR)

                    # Augmentation: Horizontal flip and brightness adjustment
                    if rn.choice([True, False]):  # Random horizontal flip
                        image_resized = cv2.flip(image_resized, 1)
                    
                    brightness_factor = 0.8 + 0.4 * rn.random()  # Random brightness factor
                    image_resized = np.clip(image_resized * brightness_factor, 0, 255)

                    # Normalize each channel
                    mean_r, mean_g, mean_b = image_resized[:, :, 0].mean(), image_resized[:, :, 1].mean(), image_resized[:, :, 2].mean()
                    std_r, std_g, std_b = image_resized[:, :, 0].std(), image_resized[:, :, 1].std(), image_resized[:, :, 2].std()

                    batch_data[folder, idx, :, :, 0] = (image_resized[:, :, 0] - mean_r) / (std_r + 1e-7)
                    batch_data[folder, idx, :, :, 1] = (image_resized[:, :, 1] - mean_g) / (std_g + 1e-7)
                    batch_data[folder, idx, :, :, 2] = (image_resized[:, :, 2] - mean_b) / (std_b + 1e-7)
                
                # Set one-hot encoded label
                label_index = int(t[folder + (batch * batch_size)].strip().split(';')[2])
                batch_labels[folder, label_index] = 1
            
            yield batch_data, batch_labels  # Yield the batch

        # Process remaining data points
        remaining_datapoints = len(folder_list) % batch_size
        if remaining_datapoints > 0:
            batch_data = np.zeros((remaining_datapoints, x, y, z, 3))
            batch_labels = np.zeros((remaining_datapoints, 5))
            start_index = num_batches * batch_size
            
            for folder in range(remaining_datapoints):
                #folder_path = os.path.normpath(os.path.join(source_path, t[folder + start_index].strip().split(';')[0]))
                folder_name = t[folder + start_index].strip().split(';')[0]
                folder_path = os.path.join(source_path, folder_name)
                folder_path = os.path.normpath(folder_path)  # Ensure a consistent path format

                imgs = os.listdir(folder_path)
                
                for idx, item in enumerate(img_idx):
                    if item >= len(imgs):
                        print(f"Warning: Frame {item} not found in folder, skipping...")
                        continue
                    
                    image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
                    
                    # Crop to square and resize
                    if image.shape[1] > image.shape[0]:
                        crop_start = (image.shape[1] - image.shape[0]) // 2
                        crop_end = crop_start + image.shape[0]
                        image = image[:, crop_start:crop_end]
                    elif image.shape[0] > image.shape[1]:
                        crop_start = (image.shape[0] - image.shape[1]) // 2
                        crop_end = crop_start + image.shape[1]
                        image = image[crop_start:crop_end, :]

                    image_resized = cv2.resize(image, target_size, interpolation=cv2.INTER_LINEAR)

                    # Augmentation
                    if rn.choice([True, False]):
                        image_resized = cv2.flip(image_resized, 1)
                    
                    brightness_factor = 0.8 + 0.4 * rn.random()
                    image_resized = np.clip(image_resized * brightness_factor, 0, 255)

                    # Normalize each channel
                    mean_r, mean_g, mean_b = image_resized[:, :, 0].mean(), image_resized[:, :, 1].mean(), image_resized[:, :, 2].mean()
                    std_r, std_g, std_b = image_resized[:, :, 0].std(), image_resized[:, :, 1].std(), image_resized[:, :, 2].std()

                    batch_data[folder, idx, :, :, 0] = (image_resized[:, :, 0] - mean_r) / (std_r + 1e-7)
                    batch_data[folder, idx, :, :, 1] = (image_resized[:, :, 1] - mean_g) / (std_g + 1e-7)
                    batch_data[folder, idx, :, :, 2] = (image_resized[:, :, 2] - mean_b) / (std_b + 1e-7)
                
                label_index = int(t[folder + start_index].strip().split(';')[2])
                batch_labels[folder, label_index] = 1
            
            yield batch_data, batch_labels  # Yield the remaining batch

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = r'C:\Users\admin\Vidhya\Project_data\train'
val_path = r'C:\Users\admin\Vidhya\Project_data\val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 20
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 20

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout, LSTM
# from keras.layers.convolutional import Conv3D, MaxPooling3D
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Conv3D, MaxPooling3D

from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout, LSTM
# from keras.layers.convolutional import Conv3D, MaxPooling3D
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Conv3D, MaxPooling3D

from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers

#write your model here

# Define input shape (frames, height, width, channels)
input_shape = (15, 128, 128, 3)
num_classes = 5

model = Sequential()

# First Conv2D Block - More aggressive pooling
model.add(TimeDistributed(Conv2D(16, (3, 3), padding='same'), input_shape=input_shape))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(Activation('relu')))
model.add(TimeDistributed(MaxPooling2D((4, 4))))  # More aggressive pooling

# Second Conv2D Block
model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(Activation('relu')))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Dropout(0.25)))

# Flatten and LSTM
model.add(TimeDistributed(Flatten()))
model.add(LSTM(64))
model.add(Dense(num_classes, activation='softmax'))

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = 'adam'
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed_100            │ (None, 15, 128, 128,   │           448 │
# │ (TimeDistributed)               │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_101            │ (None, 15, 128, 128,   │            64 │
# │ (TimeDistributed)               │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_102            │ (None, 15, 128, 128,   │             0 │
# │ (TimeDistributed)               │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_103            │ (None, 15, 32, 32, 16) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_104            │ (None, 15, 32, 32, 32) │         4,640 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_105            │ (None, 15, 32, 32, 32) │           128 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_106            │ (None, 15, 32, 32, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_107            │ (None, 15, 16, 16, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_108            │ (None, 15, 16, 16, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_109            │ (None, 15, 8192)       │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_8 (LSTM)                   │ (None, 64)             │     2,113,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 5)              │           325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,119,397 (8.08 MB)
#  Trainable params: 2,119,301 (8.08 MB)
#  Non-trainable params: 96 (384.00 B)
# None

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
#model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','_').replace(':','_') + '/'

if not os.path.exists(model_name):
    os.mkdir(model_name)

#filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.keras'

#checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', save_freq='epoch')

#LR = # write the REducelronplateau code here
LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-6, verbose=1)
callbacks_list = [checkpoint, LR]

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

print(steps_per_epoch,validation_steps)
# Out:
# 67 10

# %%
# At the start of your script, let's print folder contents
#print("Checking paths and data...")
#print(f"Train path exists: {os.path.exists(train_path)}")
"""print(f"Val path exists: {os.path.exists(val_path)}")
print(f"Length of train_doc: {len(train_doc)}")
print(f"Length of val_doc: {len(val_doc)}")
print(type(train_doc))
#print(train_doc)

# Before creating generators, let's verify batch_size is defined
if 'batch_size' not in locals():
    batch_size = 32  # or whatever default you want
print(f"Batch size: {batch_size}")

# Let's modify your generator creation to include try-except
try:
    print("Creating train generator...")
    train_generator = generator(train_path, train_doc, batch_size)
    # Verify generator works by getting first batch
    print("Testing train generator...")
    first_batch = next(train_generator)
    print("Train generator successfully created and tested")
except Exception as e:
    print(f"Error with train generator: {str(e)}")
    raise

try:
    print("Creating validation generator...")
    val_generator = generator(val_path, val_doc, batch_size)
    # Verify generator works by getting first batch
    print("Testing validation generator...")
    first_batch = next(val_generator)
    print("Validation generator successfully created and tested")
except Exception as e:
    print(f"Error with validation generator: {str(e)}")
    raise

# Print your steps calculations
print(f"Number of train sequences: {num_train_sequences}")
print(f"Number of val sequences: {num_val_sequences}")
print(f"Calculated steps_per_epoch: {steps_per_epoch}")
print(f"Calculated validation_steps: {validation_steps}")

# Then proceed with your model.fit()"""
# Out:
# 'print(f"Val path exists: {os.path.exists(val_path)}")\nprint(f"Length of train_doc: {len(train_doc)}")\nprint(f"Length of val_doc: {len(val_doc)}")\nprint(type(train_doc))\n#print(train_doc)\n\n# Before creating generators, let\'s verify batch_size is defined\nif \'batch_size\' not in locals():\n    batch_size = 32  # or whatever default you want\nprint(f"Batch size: {batch_size}")\n\n# Let\'s modify your generator creation to include try-except\ntry:\n    print("Creating train generator...")\n    train_generator = generator(train_path, train_doc, batch_size)\n    # Verify generator works by getting first batch\n    print("Testing train generator...")\n    first_batch = next(train_generator)\n    print("Train generator successfully created and tested")\nexcept Exception as e:\n    print(f"Error with train generator: {str(e)}")\n    raise\n\ntry:\n    print("Creating validation generator...")\n    val_generator = generator(val_path, val_doc, batch_size)\n    # Verify generator works by getting first batch\n    print("Testing validation generator...")\n    first_batch = next(val_generator)\n    print("Validation generator successfully created and tested")\nexcept Exception as e:\n    print(f"Error with validation generator: {str(e)}")\n    raise\n\n# Print your steps calculations\nprint(f"Number of train sequences: {num_train_sequences}")\nprint(f"Number of val sequences: {num_val_sequences}")\nprint(f"Calculated steps_per_epoch: {steps_per_epoch}")\nprint(f"Calculated validation_steps: {validation_steps}")\n\n# Then proceed with your model.fit()'

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, initial_epoch=0)
# Out:
# Source path = C:\Users\admin\Vidhya\Project_data\train ; batch size = 10
# Number of folders: 663
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_2128\2155616922.py:40: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# Epoch 1/20
# 65/67 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - categorical_accuracy: 0.2202 - loss: 1.7386
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_2128\2155616922.py:95: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2194 - loss: 1.7370Source path = C:\Users\admin\Vidhya\Project_data\val ; batch size = 10
# Number of folders: 100
#
# Epoch 1: saving model to model_init_2024-11-10_11_58_15.045640/model-00001-1.68358-0.19457-1.60725-0.18000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 135s 2s/step - categorical_accuracy: 0.2191 - loss: 1.7362 - val_categorical_accuracy: 0.1800 - val_loss: 1.6073 - learning_rate: 0.0010
# Epoch 2/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.2103 - loss: 1.6150
# Epoch 2: saving model to model_init_2024-11-10_11_58_15.045640/model-00002-1.62677-0.19910-1.59369-0.21000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 111s 2s/step - categorical_accuracy: 0.2101 - loss: 1.6152 - val_categorical_accuracy: 0.2100 - val_loss: 1.5937 - learning_rate: 0.0010
# Epoch 3/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.3091 - loss: 1.5777
# Epoch 3: saving model to model_init_2024-11-10_11_58_15.045640/model-00003-1.57102-0.32730-1.55950-0.29000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 113s 2s/step - categorical_accuracy: 0.3094 - loss: 1.5776 - val_categorical_accuracy: 0.2900 - val_loss: 1.5595 - learning_rate: 0.0010
# Epoch 4/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.3991 - loss: 1.5561
# Epoch 4: saving model to model_init_2024-11-10_11_58_15.045640/model-00004-1.54655-0.36802-1.55108-0.25000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 108s 2s/step - categorical_accuracy: 0.3987 - loss: 1.5560 - val_categorical_accuracy: 0.2500 - val_loss: 1.5511 - learning_rate: 0.0010
# Epoch 5/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.3382 - loss: 1.5245
# Epoch 5: saving model to model_init_2024-11-10_11_58_15.045640/model-00005-1.52858-0.34691-1.50832-0.45000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 115s 2s/step - categorical_accuracy: 0.3383 - loss: 1.5246 - val_categorical_accuracy: 0.4500 - val_loss: 1.5083 - learning_rate: 0.0010
# Epoch 6/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.4195 - loss: 1.5013
# Epoch 6: saving model to model_init_2024-11-10_11_58_15.045640/model-00006-1.49829-0.43288-1.49570-0.45000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 111s 2s/step - categorical_accuracy: 0.4197 - loss: 1.5012 - val_categorical_accuracy: 0.4500 - val_loss: 1.4957 - learning_rate: 0.0010
# Epoch 7/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.4555 - loss: 1.4865
# Epoch 7: saving model to model_init_2024-11-10_11_58_15.045640/model-00007-1.47543-0.48265-1.46712-0.49000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 111s 2s/step - categorical_accuracy: 0.4559 - loss: 1.4863 - val_categorical_accuracy: 0.4900 - val_loss: 1.4671 - learning_rate: 0.0010
# Epoch 8/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.4592 - loss: 1.4678
# Epoch 8: saving model to model_init_2024-11-10_11_58_15.045640/model-00008-1.46097-0.47210-1.47304-0.48000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 113s 2s/step - categorical_accuracy: 0.4594 - loss: 1.4677 - val_categorical_accuracy: 0.4800 - val_loss: 1.4730 - learning_rate: 0.0010
# Epoch 9/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.5215 - loss: 1.4418
# Epoch 9: saving model to model_init_2024-11-10_11_58_15.045640/model-00009-1.44995-0.49170-1.47038-0.40000.keras
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 112s 2s/step - categorical_accuracy: 0.5211 - loss: 1.4419 - val_categorical_accuracy: 0.4000 - val_loss: 1.4704 - learning_rate: 0.0010
# Epoch 10/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.5150 - loss: 1.4177
# Epoch 10: saving model to model_init_2024-11-10_11_58_15.045640/model-00010-1.40399-0.52489-1.43130-0.52000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 111s 2s/step - categorical_accuracy: 0.5151 - loss: 1.4175 - val_categorical_accuracy: 0.5200 - val_loss: 1.4313 - learning_rate: 5.0000e-04
# Epoch 11/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.5242 - loss: 1.3947
# Epoch 11: saving model to model_init_2024-11-10_11_58_15.045640/model-00011-1.38160-0.54449-1.42581-0.51000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 111s 2s/step - categorical_accuracy: 0.5245 - loss: 1.3945 - val_categorical_accuracy: 0.5100 - val_loss: 1.4258 - learning_rate: 5.0000e-04
# Epoch 12/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.5989 - loss: 1.3383
# Epoch 12: saving model to model_init_2024-11-10_11_58_15.045640/model-00012-1.34847-0.57164-1.46301-0.45000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 111s 2s/step - categorical_accuracy: 0.5985 - loss: 1.3385 - val_categorical_accuracy: 0.4500 - val_loss: 1.4630 - learning_rate: 5.0000e-04
# Epoch 13/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.5890 - loss: 1.3352
# Epoch 13: saving model to model_init_2024-11-10_11_58_15.045640/model-00013-1.33546-0.57466-1.38358-0.53000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 111s 2s/step - categorical_accuracy: 0.5888 - loss: 1.3352 - val_categorical_accuracy: 0.5300 - val_loss: 1.3836 - learning_rate: 5.0000e-04
# Epoch 14/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.6168 - loss: 1.3113
# Epoch 14: saving model to model_init_2024-11-10_11_58_15.045640/model-00014-1.31434-0.59427-1.39567-0.50000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 111s 2s/step - categorical_accuracy: 0.6165 - loss: 1.3113 - val_categorical_accuracy: 0.5000 - val_loss: 1.3957 - learning_rate: 5.0000e-04
# Epoch 15/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.6319 - loss: 1.2750
# Epoch 15: saving model to model_init_2024-11-10_11_58_15.045640/model-00015-1.30278-0.59729-1.39626-0.47000.keras
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - categorical_accuracy: 0.6314 - loss: 1.2754 - val_categorical_accuracy: 0.4700 - val_loss: 1.3963 - learning_rate: 5.0000e-04
# Epoch 16/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.5988 - loss: 1.2576
# Epoch 16: saving model to model_init_2024-11-10_11_58_15.045640/model-00016-1.26314-0.62594-1.36804-0.53000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 111s 2s/step - categorical_accuracy: 0.5992 - loss: 1.2577 - val_categorical_accuracy: 0.5300 - val_loss: 1.3680 - learning_rate: 2.5000e-04
# Epoch 17/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.6610 - loss: 1.2314
# Epoch 17: saving model to model_init_2024-11-10_11_58_15.045640/model-00017-1.24213-0.67119-1.35005-0.53000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 111s 2s/step - categorical_accuracy: 0.6612 - loss: 1.2316 - val_categorical_accuracy: 0.5300 - val_loss: 1.3500 - learning_rate: 2.5000e-04
# Epoch 18/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.7111 - loss: 1.2188
# Epoch 18: saving model to model_init_2024-11-10_11_58_15.045640/model-00018-1.22443-0.66817-1.35593-0.48000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 111s 2s/step - categorical_accuracy: 0.7105 - loss: 1.2189 - val_categorical_accuracy: 0.4800 - val_loss: 1.3559 - learning_rate: 2.5000e-04
# Epoch 19/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.6665 - loss: 1.2169
# Epoch 19: saving model to model_init_2024-11-10_11_58_15.045640/model-00019-1.20329-0.68477-1.33905-0.56000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - categorical_accuracy: 0.6667 - loss: 1.2167 - val_categorical_accuracy: 0.5600 - val_loss: 1.3390 - learning_rate: 2.5000e-04
# Epoch 20/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.7172 - loss: 1.1652
# Epoch 20: saving model to model_init_2024-11-10_11_58_15.045640/model-00020-1.16889-0.70287-1.32684-0.54000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 104s 2s/step - categorical_accuracy: 0.7169 - loss: 1.1653 - val_categorical_accuracy: 0.5400 - val_loss: 1.3268 - learning_rate: 2.5000e-04

# %% [markdown]
# ### While the categorical accuracy is 72%,the validation accuracy is 54% indicating the overfitting of the data

# %%
# Plotting function
import matplotlib.pyplot as plt

def plot_training(history):
    plt.figure(figsize=(12, 6))

    # Plot accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['categorical_accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_categorical_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Training and Validation Accuracy')

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Training and Validation Loss')

    plt.show()

plot_training(history)

# %% [markdown]
# # Model 2 CONV2D + RNN (more complex)

# %%
# Updated model architecture
model = Sequential()

# First Conv2D Block
model.add(TimeDistributed(Conv2D(16, (3, 3), padding='same'), input_shape=input_shape))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(Activation('relu')))
model.add(TimeDistributed(MaxPooling2D((2, 2))))

# Second Conv2D Block
model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(Activation('relu')))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Dropout(0.25)))

# Third Conv2D Block
model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(Activation('relu')))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Dropout(0.25)))

# Flatten and LSTM
model.add(TimeDistributed(Flatten()))
model.add(LSTM(128, return_sequences=False))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# %%
from tensorflow.keras.optimizers import Adam
#learning_rate = 0.0001
optimizer = 'adam'
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed_110            │ (None, 15, 128, 128,   │           448 │
# │ (TimeDistributed)               │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_111            │ (None, 15, 128, 128,   │            64 │
# │ (TimeDistributed)               │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_112            │ (None, 15, 128, 128,   │             0 │
# │ (TimeDistributed)               │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_113            │ (None, 15, 64, 64, 16) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_114            │ (None, 15, 64, 64, 32) │         4,640 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_115            │ (None, 15, 64, 64, 32) │           128 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_116            │ (None, 15, 64, 64, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_117            │ (None, 15, 32, 32, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_118            │ (None, 15, 32, 32, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_119            │ (None, 15, 32, 32, 64) │        18,496 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_120            │ (None, 15, 32, 32, 64) │           256 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_121            │ (None, 15, 32, 32, 64) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_122            │ (None, 15, 16, 16, 64) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_123            │ (None, 15, 16, 16, 64) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_124            │ (None, 15, 16384)      │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_9 (LSTM)                   │ (None, 128)            │     8,454,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,479,333 (32.35 MB)
#  Trainable params: 8,479,109 (32.35 MB)
#  Non-trainable params: 224 (896.00 B)
# None

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
print(curr_dt_time)
# Out:
# 2024-11-10 11:58:15.045640

# %%
curr_dt_time = datetime.datetime.now()
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','_').replace(':','_') + '/'

    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
#filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.keras'

#checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', save_freq='epoch')

#LR = # write the REducelronplateau code here
LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-6, verbose=1)
callbacks_list = [checkpoint, LR]

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

print(steps_per_epoch,validation_steps)
# Out:
# 67 10

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                    callbacks=callbacks_list, validation_data=val_generator,
                    validation_steps=validation_steps, class_weight=None, initial_epoch=0)
# Out:
# Source path = C:\Users\admin\Vidhya\Project_data\train ; batch size = 10
# Number of folders: 663
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_2128\2155616922.py:40: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# Epoch 1/20
# 65/67 ━━━━━━━━━━━━━━━━━━━━ 5s 3s/step - categorical_accuracy: 0.1829 - loss: 2.1391
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_2128\2155616922.py:95: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.1830 - loss: 2.1358Source path = C:\Users\admin\Vidhya\Project_data\val ; batch size = 10
# Number of folders: 100
#
# Epoch 1: saving model to model_init_2024-11-10_12_39_45.124937/model-00001-2.02898-0.18552-1.62125-0.18000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 246s 3s/step - categorical_accuracy: 0.1830 - loss: 2.1343 - val_categorical_accuracy: 0.1800 - val_loss: 1.6213 - learning_rate: 0.0010
# Epoch 2/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1769 - loss: 1.9039
# Epoch 2: saving model to model_init_2024-11-10_12_39_45.124937/model-00002-1.88707-0.19005-1.60998-0.23000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 168s 3s/step - categorical_accuracy: 0.1771 - loss: 1.9037 - val_categorical_accuracy: 0.2300 - val_loss: 1.6100 - learning_rate: 0.0010
# Epoch 3/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1986 - loss: 1.9206
# Epoch 3: saving model to model_init_2024-11-10_12_39_45.124937/model-00003-1.86562-0.18703-1.61558-0.21000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - categorical_accuracy: 0.1984 - loss: 1.9198 - val_categorical_accuracy: 0.2100 - val_loss: 1.6156 - learning_rate: 0.0010
# Epoch 4/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2010 - loss: 1.8536
# Epoch 4: saving model to model_init_2024-11-10_12_39_45.124937/model-00004-1.80716-0.21418-1.61056-0.21000.keras
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 133s 2s/step - categorical_accuracy: 0.2012 - loss: 1.8529 - val_categorical_accuracy: 0.2100 - val_loss: 1.6106 - learning_rate: 0.0010
# Epoch 5/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1677 - loss: 1.7997
# Epoch 5: saving model to model_init_2024-11-10_12_39_45.124937/model-00005-1.78799-0.18552-1.60926-0.21000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - categorical_accuracy: 0.1679 - loss: 1.7996 - val_categorical_accuracy: 0.2100 - val_loss: 1.6093 - learning_rate: 5.0000e-04
# Epoch 6/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1741 - loss: 1.8338
# Epoch 6: saving model to model_init_2024-11-10_12_39_45.124937/model-00006-1.84006-0.16742-1.60880-0.18000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 137s 2s/step - categorical_accuracy: 0.1740 - loss: 1.8339 - val_categorical_accuracy: 0.1800 - val_loss: 1.6088 - learning_rate: 5.0000e-04
# Epoch 7/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2014 - loss: 1.7863
# Epoch 7: saving model to model_init_2024-11-10_12_39_45.124937/model-00007-1.80112-0.19005-1.60525-0.21000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 136s 2s/step - categorical_accuracy: 0.2013 - loss: 1.7865 - val_categorical_accuracy: 0.2100 - val_loss: 1.6053 - learning_rate: 5.0000e-04
# Epoch 8/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2020 - loss: 1.7356
# Epoch 8: saving model to model_init_2024-11-10_12_39_45.124937/model-00008-1.75275-0.17496-1.61002-0.23000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 135s 2s/step - categorical_accuracy: 0.2016 - loss: 1.7359 - val_categorical_accuracy: 0.2300 - val_loss: 1.6100 - learning_rate: 5.0000e-04
# Epoch 9/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1848 - loss: 1.8055
# Epoch 9: saving model to model_init_2024-11-10_12_39_45.124937/model-00009-1.76554-0.20362-1.61335-0.18000.keras
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 134s 2s/step - categorical_accuracy: 0.1851 - loss: 1.8049 - val_categorical_accuracy: 0.1800 - val_loss: 1.6133 - learning_rate: 5.0000e-04
# Epoch 10/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2407 - loss: 1.7123
# Epoch 10: saving model to model_init_2024-11-10_12_39_45.124937/model-00010-1.72515-0.21870-1.61131-0.18000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 135s 2s/step - categorical_accuracy: 0.2403 - loss: 1.7125 - val_categorical_accuracy: 0.1800 - val_loss: 1.6113 - learning_rate: 2.5000e-04
# Epoch 11/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2172 - loss: 1.7193
# Epoch 11: saving model to model_init_2024-11-10_12_39_45.124937/model-00011-1.71866-0.22323-1.60803-0.18000.keras
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 134s 2s/step - categorical_accuracy: 0.2173 - loss: 1.7193 - val_categorical_accuracy: 0.1800 - val_loss: 1.6080 - learning_rate: 2.5000e-04
# Epoch 12/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2086 - loss: 1.7412
# Epoch 12: saving model to model_init_2024-11-10_12_39_45.124937/model-00012-1.75279-0.19608-1.60944-0.18000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 134s 2s/step - categorical_accuracy: 0.2085 - loss: 1.7414 - val_categorical_accuracy: 0.1800 - val_loss: 1.6094 - learning_rate: 1.2500e-04
# Epoch 13/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1859 - loss: 1.7490
# Epoch 13: saving model to model_init_2024-11-10_12_39_45.124937/model-00013-1.73185-0.20211-1.60993-0.18000.keras
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 134s 2s/step - categorical_accuracy: 0.1862 - loss: 1.7487 - val_categorical_accuracy: 0.1800 - val_loss: 1.6099 - learning_rate: 1.2500e-04
# Epoch 14/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2182 - loss: 1.6824
# Epoch 14: saving model to model_init_2024-11-10_12_39_45.124937/model-00014-1.69299-0.21267-1.61044-0.18000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 134s 2s/step - categorical_accuracy: 0.2181 - loss: 1.6826 - val_categorical_accuracy: 0.1800 - val_loss: 1.6104 - learning_rate: 6.2500e-05
# Epoch 15/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2025 - loss: 1.7283
# Epoch 15: saving model to model_init_2024-11-10_12_39_45.124937/model-00015-1.74639-0.19457-1.61002-0.18000.keras
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 134s 2s/step - categorical_accuracy: 0.2024 - loss: 1.7286 - val_categorical_accuracy: 0.1800 - val_loss: 1.6100 - learning_rate: 6.2500e-05
# Epoch 16/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2237 - loss: 1.7341
# Epoch 16: saving model to model_init_2024-11-10_12_39_45.124937/model-00016-1.72876-0.20814-1.61006-0.18000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 134s 2s/step - categorical_accuracy: 0.2235 - loss: 1.7340 - val_categorical_accuracy: 0.1800 - val_loss: 1.6101 - learning_rate: 3.1250e-05
# Epoch 17/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1926 - loss: 1.7538
# Epoch 17: saving model to model_init_2024-11-10_12_39_45.124937/model-00017-1.74443-0.18552-1.60976-0.18000.keras
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 136s 2s/step - categorical_accuracy: 0.1925 - loss: 1.7536 - val_categorical_accuracy: 0.1800 - val_loss: 1.6098 - learning_rate: 3.1250e-05
# Epoch 18/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2653 - loss: 1.6764
# Epoch 18: saving model to model_init_2024-11-10_12_39_45.124937/model-00018-1.69679-0.23529-1.60956-0.18000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 136s 2s/step - categorical_accuracy: 0.2649 - loss: 1.6767 - val_categorical_accuracy: 0.1800 - val_loss: 1.6096 - learning_rate: 1.5625e-05
# Epoch 19/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2121 - loss: 1.7322
# Epoch 19: saving model to model_init_2024-11-10_12_39_45.124937/model-00019-1.72296-0.22323-1.60937-0.18000.keras
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 139s 2s/step - categorical_accuracy: 0.2123 - loss: 1.7321 - val_categorical_accuracy: 0.1800 - val_loss: 1.6094 - learning_rate: 1.5625e-05
# Epoch 20/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2299 - loss: 1.7071
# Epoch 20: saving model to model_init_2024-11-10_12_39_45.124937/model-00020-1.74392-0.20664-1.60934-0.18000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 134s 2s/step - categorical_accuracy: 0.2296 - loss: 1.7076 - val_categorical_accuracy: 0.1800 - val_loss: 1.6093 - learning_rate: 7.8125e-06

# %%
plot_training(history)

# %% [markdown]
# ###While the categorical accuracy is 22%,the validation accuracy is 18% indicating the underfitting of the data

# %% [markdown]
# ### Exp 2 - Extremely low accuracy

# %% [markdown]
# ## Experiment 3 Conv2D + LSTM, mor images, increased filters
# Will select more images, back to same learning rate, changes in model Architecture, increased filters

# %%
# Define input shape (frames, height, width, channels)
input_shape = (20, 128, 128, 3)
num_classes = 5

# Updated model architecture
model = Sequential()

# First Conv2D Block
model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same'), input_shape=input_shape))  # Increased filters
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(Activation('relu')))
model.add(TimeDistributed(MaxPooling2D((2, 2))))

# Second Conv2D Block
model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same')))  # Increased filters
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(Activation('relu')))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Dropout(0.2)))  # Adjusted dropout

# Third Conv2D Block
model.add(TimeDistributed(Conv2D(128, (3, 3), padding='same')))  # Increased filters
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(Activation('relu')))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Dropout(0.3)))  # Adjusted dropout

# Flatten and LSTM
model.add(TimeDistributed(Flatten()))
model.add(LSTM(256, return_sequences=False))  # Increased LSTM units
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# Compile the model with a lower learning rate
#model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
optimiser = 'adam'
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed_125            │ (None, 20, 128, 128,   │           896 │
# │ (TimeDistributed)               │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_126            │ (None, 20, 128, 128,   │           128 │
# │ (TimeDistributed)               │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_127            │ (None, 20, 128, 128,   │             0 │
# │ (TimeDistributed)               │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_128            │ (None, 20, 64, 64, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_129            │ (None, 20, 64, 64, 64) │        18,496 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_130            │ (None, 20, 64, 64, 64) │           256 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_131            │ (None, 20, 64, 64, 64) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_132            │ (None, 20, 32, 32, 64) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_133            │ (None, 20, 32, 32, 64) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_134            │ (None, 20, 32, 32,     │        73,856 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_135            │ (None, 20, 32, 32,     │           512 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_136            │ (None, 20, 32, 32,     │             0 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_137            │ (None, 20, 16, 16,     │             0 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_138            │ (None, 20, 16, 16,     │             0 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_139            │ (None, 20, 32768)      │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_10 (LSTM)                  │ (None, 256)            │    33,817,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_22 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 33,913,029 (129.37 MB)
#  Trainable params: 33,912,581 (129.37 MB)
#  Non-trainable params: 448 (1.75 KB)
# None

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
curr_dt_time = datetime.datetime.now()
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','_').replace(':','_') + '/'

    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
#filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.keras'

#checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', save_freq='epoch')

#LR = # write the REducelronplateau code here
LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-6, verbose=1)
callbacks_list = [checkpoint, LR]

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

print(steps_per_epoch,validation_steps)
# Out:
# 67 10

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                    callbacks=callbacks_list, validation_data=val_generator,
                    validation_steps=validation_steps, class_weight=None, initial_epoch=0)
# Out:
# Source path = C:\Users\admin\Vidhya\Project_data\train ; batch size = 10
# Number of folders: 663
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_2128\2155616922.py:40: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# Epoch 1/20
# 64/67 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - categorical_accuracy: 0.2287 - loss: 1.8822
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_2128\2155616922.py:95: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.2281 - loss: 1.8801Source path = C:\Users\admin\Vidhya\Project_data\val ; batch size = 10
# Number of folders: 100
#
# Epoch 1: saving model to model_init_2024-11-10_13_33_56.829777/model-00001-1.83525-0.21569-1.60601-0.23000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 249s 3s/step - categorical_accuracy: 0.2279 - loss: 1.8794 - val_categorical_accuracy: 0.2300 - val_loss: 1.6060 - learning_rate: 0.0010
# Epoch 2/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.2237 - loss: 1.7592
# Epoch 2: saving model to model_init_2024-11-10_13_33_56.829777/model-00002-1.79367-0.20664-1.60936-0.22000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 212s 3s/step - categorical_accuracy: 0.2234 - loss: 1.7597 - val_categorical_accuracy: 0.2200 - val_loss: 1.6094 - learning_rate: 0.0010
# Epoch 3/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.2004 - loss: 1.8164
# Epoch 3: saving model to model_init_2024-11-10_13_33_56.829777/model-00003-1.80477-0.20211-1.62077-0.21000.keras
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 210s 3s/step - categorical_accuracy: 0.2004 - loss: 1.8163 - val_categorical_accuracy: 0.2100 - val_loss: 1.6208 - learning_rate: 0.0010
# Epoch 4/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.1928 - loss: 1.8160
# Epoch 4: saving model to model_init_2024-11-10_13_33_56.829777/model-00004-1.80792-0.18401-1.60985-0.21000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 213s 3s/step - categorical_accuracy: 0.1927 - loss: 1.8159 - val_categorical_accuracy: 0.2100 - val_loss: 1.6099 - learning_rate: 5.0000e-04
# Epoch 5/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.1806 - loss: 1.7897
# Epoch 5: saving model to model_init_2024-11-10_13_33_56.829777/model-00005-1.77877-0.18854-1.60643-0.23000.keras
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 223s 3s/step - categorical_accuracy: 0.1807 - loss: 1.7895 - val_categorical_accuracy: 0.2300 - val_loss: 1.6064 - learning_rate: 5.0000e-04
# Epoch 6/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.2180 - loss: 1.7526
# Epoch 6: saving model to model_init_2024-11-10_13_33_56.829777/model-00006-1.74711-0.20362-1.59844-0.23000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 220s 3s/step - categorical_accuracy: 0.2178 - loss: 1.7525 - val_categorical_accuracy: 0.2300 - val_loss: 1.5984 - learning_rate: 2.5000e-04
# Epoch 7/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.2530 - loss: 1.6909
# Epoch 7: saving model to model_init_2024-11-10_13_33_56.829777/model-00007-1.72946-0.22021-1.60951-0.19000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 220s 3s/step - categorical_accuracy: 0.2525 - loss: 1.6915 - val_categorical_accuracy: 0.1900 - val_loss: 1.6095 - learning_rate: 2.5000e-04
# Epoch 8/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.1835 - loss: 1.8111
# Epoch 8: saving model to model_init_2024-11-10_13_33_56.829777/model-00008-1.78923-0.17044-1.60577-0.22000.keras
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 219s 3s/step - categorical_accuracy: 0.1833 - loss: 1.8108 - val_categorical_accuracy: 0.2200 - val_loss: 1.6058 - learning_rate: 2.5000e-04
# Epoch 9/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.1718 - loss: 1.7837
# Epoch 9: saving model to model_init_2024-11-10_13_33_56.829777/model-00009-1.76055-0.19306-1.60405-0.23000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 220s 3s/step - categorical_accuracy: 0.1721 - loss: 1.7833 - val_categorical_accuracy: 0.2300 - val_loss: 1.6040 - learning_rate: 1.2500e-04
# Epoch 10/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.1914 - loss: 1.7776
# Epoch 10: saving model to model_init_2024-11-10_13_33_56.829777/model-00010-1.76639-0.18703-1.60244-0.20000.keras
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 219s 3s/step - categorical_accuracy: 0.1913 - loss: 1.7774 - val_categorical_accuracy: 0.2000 - val_loss: 1.6024 - learning_rate: 1.2500e-04
# Epoch 11/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.1806 - loss: 1.7969
# Epoch 11: saving model to model_init_2024-11-10_13_33_56.829777/model-00011-1.77064-0.19005-1.59953-0.24000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 219s 3s/step - categorical_accuracy: 0.1807 - loss: 1.7965 - val_categorical_accuracy: 0.2400 - val_loss: 1.5995 - learning_rate: 6.2500e-05
# Epoch 12/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.1547 - loss: 1.7651
# Epoch 12: saving model to model_init_2024-11-10_13_33_56.829777/model-00012-1.72314-0.18854-1.60106-0.24000.keras
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 220s 3s/step - categorical_accuracy: 0.1552 - loss: 1.7645 - val_categorical_accuracy: 0.2400 - val_loss: 1.6011 - learning_rate: 6.2500e-05
# Epoch 13/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.2419 - loss: 1.7189
# Epoch 13: saving model to model_init_2024-11-10_13_33_56.829777/model-00013-1.73822-0.21569-1.59772-0.20000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 220s 3s/step - categorical_accuracy: 0.2415 - loss: 1.7191 - val_categorical_accuracy: 0.2000 - val_loss: 1.5977 - learning_rate: 3.1250e-05
# Epoch 14/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.1852 - loss: 1.7425
# Epoch 14: saving model to model_init_2024-11-10_13_33_56.829777/model-00014-1.74704-0.18100-1.60398-0.24000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 219s 3s/step - categorical_accuracy: 0.1852 - loss: 1.7426 - val_categorical_accuracy: 0.2400 - val_loss: 1.6040 - learning_rate: 3.1250e-05
# Epoch 15/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.1960 - loss: 1.7276
# Epoch 15: saving model to model_init_2024-11-10_13_33_56.829777/model-00015-1.73536-0.19759-1.60596-0.22000.keras
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 219s 3s/step - categorical_accuracy: 0.1960 - loss: 1.7277 - val_categorical_accuracy: 0.2200 - val_loss: 1.6060 - learning_rate: 3.1250e-05
# Epoch 16/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.2497 - loss: 1.6914
# Epoch 16: saving model to model_init_2024-11-10_13_33_56.829777/model-00016-1.71408-0.23680-1.60119-0.24000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 223s 3s/step - categorical_accuracy: 0.2495 - loss: 1.6918 - val_categorical_accuracy: 0.2400 - val_loss: 1.6012 - learning_rate: 1.5625e-05
# Epoch 17/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.2144 - loss: 1.7191
# Epoch 17: saving model to model_init_2024-11-10_13_33_56.829777/model-00017-1.69757-0.23680-1.59780-0.27000.keras
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 220s 3s/step - categorical_accuracy: 0.2147 - loss: 1.7187 - val_categorical_accuracy: 0.2700 - val_loss: 1.5978 - learning_rate: 1.5625e-05
# Epoch 18/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.2210 - loss: 1.6975
# Epoch 18: saving model to model_init_2024-11-10_13_33_56.829777/model-00018-1.70601-0.20664-1.59825-0.25000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 219s 3s/step - categorical_accuracy: 0.2208 - loss: 1.6976 - val_categorical_accuracy: 0.2500 - val_loss: 1.5983 - learning_rate: 7.8125e-06
# Epoch 19/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.1973 - loss: 1.7264
# Epoch 19: saving model to model_init_2024-11-10_13_33_56.829777/model-00019-1.73248-0.20060-1.60131-0.26000.keras
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 220s 3s/step - categorical_accuracy: 0.1974 - loss: 1.7265 - val_categorical_accuracy: 0.2600 - val_loss: 1.6013 - learning_rate: 7.8125e-06
# Epoch 20/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.2001 - loss: 1.7533
# Epoch 20: saving model to model_init_2024-11-10_13_33_56.829777/model-00020-1.72333-0.22624-1.59813-0.25000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 217s 3s/step - categorical_accuracy: 0.2005 - loss: 1.7529 - val_categorical_accuracy: 0.2500 - val_loss: 1.5981 - learning_rate: 3.9063e-06

# %%
plot_training(history)

# %% [markdown]
# ### Above one gave better results with 20 epochs. So we will do 20 epochs atleast.
# Also will try to reduce the model complexity and see once.

# %% [markdown]
# ## Exp 4 - Conv2D + GRU

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import TimeDistributed, Conv2D, BatchNormalization, Activation, MaxPooling2D, Dropout, Flatten, GRU, Dense
from tensorflow.keras.optimizers import Adam

# Define input shape and parameters
input_shape = (20, 128, 128, 3)  # 20 frames
num_classes = 5

# Initialize Sequential model
model = Sequential()

# First Conv2D Block
model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same', activation='relu'), input_shape=input_shape))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Dropout(0.2)))  # Moderate dropout

# Second Conv2D Block
model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Dropout(0.3)))  # Adjusted dropout to reduce overfitting

# Third Conv2D Block
model.add(TimeDistributed(Conv2D(128, (3, 3), padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Dropout(0.3)))

# Fourth Conv2D Block (if needed, you can remove this if the model is still complex)
model.add(TimeDistributed(Conv2D(256, (3, 3), padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Dropout(0.4)))  # Higher dropout to improve generalization

# Flatten and GRU
model.add(TimeDistributed(Flatten()))
model.add(GRU(128, return_sequences=False))  # Reduced GRU units for efficiency
model.add(Dropout(0.5))

# Output Layer
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# Summary of the model
model.summary()
# Out:
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed_140            │ (None, 20, 128, 128,   │           896 │
# │ (TimeDistributed)               │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_141            │ (None, 20, 128, 128,   │           128 │
# │ (TimeDistributed)               │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_142            │ (None, 20, 64, 64, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_143            │ (None, 20, 64, 64, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_144            │ (None, 20, 64, 64, 64) │        18,496 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_145            │ (None, 20, 64, 64, 64) │           256 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_146            │ (None, 20, 32, 32, 64) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_147            │ (None, 20, 32, 32, 64) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_148            │ (None, 20, 32, 32,     │        73,856 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_149            │ (None, 20, 32, 32,     │           512 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_150            │ (None, 20, 16, 16,     │             0 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_151            │ (None, 20, 16, 16,     │             0 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_152            │ (None, 20, 16, 16,     │       295,168 │
# │ (TimeDistributed)               │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_153            │ (None, 20, 16, 16,     │         1,024 │
# │ (TimeDistributed)               │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_154            │ (None, 20, 8, 8, 256)  │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_155            │ (None, 20, 8, 8, 256)  │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_156            │ (None, 20, 16384)      │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ (None, 128)            │     6,341,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_27 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,732,357 (25.68 MB)
#  Trainable params: 6,731,397 (25.68 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
curr_dt_time = datetime.datetime.now()
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','_').replace(':','_') + '/'

    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
#filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.keras'

#checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', save_freq='epoch')

#LR = # write the REducelronplateau code here
LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-6, verbose=1)
callbacks_list = [checkpoint, LR]

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

print(steps_per_epoch,validation_steps)
print(num_epochs)
# Out:
# 67 10
# 20

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                    callbacks=callbacks_list, validation_data=val_generator,
                    validation_steps=validation_steps, class_weight=None, initial_epoch=0)
# Out:
# Source path = C:\Users\admin\Vidhya\Project_data\train ; batch size = 10
# Number of folders: 663
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_2128\2155616922.py:40: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# Epoch 1/20
# 65/67 ━━━━━━━━━━━━━━━━━━━━ 5s 3s/step - categorical_accuracy: 0.2329 - loss: 2.1802
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_2128\2155616922.py:95: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.2335 - loss: 2.1767Source path = C:\Users\admin\Vidhya\Project_data\val ; batch size = 10
# Number of folders: 100
#
# Epoch 1: saving model to model_init_2024-11-10_14_53_57.951236/model-00001-2.05830-0.25339-1.46671-0.42000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 236s 3s/step - categorical_accuracy: 0.2338 - loss: 2.1749 - val_categorical_accuracy: 0.4200 - val_loss: 1.4667 - learning_rate: 1.0000e-04
# Epoch 2/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.3198 - loss: 1.7945
# Epoch 2: saving model to model_init_2024-11-10_14_53_57.951236/model-00002-1.75512-0.33484-1.46433-0.48000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 188s 3s/step - categorical_accuracy: 0.3201 - loss: 1.7940 - val_categorical_accuracy: 0.4800 - val_loss: 1.4643 - learning_rate: 1.0000e-04
# Epoch 3/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.3349 - loss: 1.7099
# Epoch 3: saving model to model_init_2024-11-10_14_53_57.951236/model-00003-1.66220-0.33786-1.41244-0.50000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 186s 3s/step - categorical_accuracy: 0.3349 - loss: 1.7092 - val_categorical_accuracy: 0.5000 - val_loss: 1.4124 - learning_rate: 1.0000e-04
# Epoch 4/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.4299 - loss: 1.5004
# Epoch 4: saving model to model_init_2024-11-10_14_53_57.951236/model-00004-1.48682-0.42232-1.36191-0.48000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 179s 3s/step - categorical_accuracy: 0.4298 - loss: 1.5002 - val_categorical_accuracy: 0.4800 - val_loss: 1.3619 - learning_rate: 1.0000e-04
# Epoch 5/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.4134 - loss: 1.4987
# Epoch 5: saving model to model_init_2024-11-10_14_53_57.951236/model-00005-1.46335-0.43741-1.24147-0.56000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 184s 3s/step - categorical_accuracy: 0.4138 - loss: 1.4982 - val_categorical_accuracy: 0.5600 - val_loss: 1.2415 - learning_rate: 1.0000e-04
# Epoch 6/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5183 - loss: 1.2467
# Epoch 6: saving model to model_init_2024-11-10_14_53_57.951236/model-00006-1.31023-0.49472-1.27663-0.54000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 184s 3s/step - categorical_accuracy: 0.5180 - loss: 1.2476 - val_categorical_accuracy: 0.5400 - val_loss: 1.2766 - learning_rate: 1.0000e-04
# Epoch 7/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5433 - loss: 1.2027
# Epoch 7: saving model to model_init_2024-11-10_14_53_57.951236/model-00007-1.25068-0.52338-1.45486-0.54000.keras
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 183s 3s/step - categorical_accuracy: 0.5430 - loss: 1.2034 - val_categorical_accuracy: 0.5400 - val_loss: 1.4549 - learning_rate: 1.0000e-04
# Epoch 8/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5417 - loss: 1.1837
# Epoch 8: saving model to model_init_2024-11-10_14_53_57.951236/model-00008-1.17506-0.54902-1.49366-0.52000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 183s 3s/step - categorical_accuracy: 0.5418 - loss: 1.1836 - val_categorical_accuracy: 0.5200 - val_loss: 1.4937 - learning_rate: 5.0000e-05
# Epoch 9/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5828 - loss: 1.1108
# Epoch 9: saving model to model_init_2024-11-10_14_53_57.951236/model-00009-1.07848-0.59276-1.38416-0.57000.keras
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 187s 3s/step - categorical_accuracy: 0.5830 - loss: 1.1103 - val_categorical_accuracy: 0.5700 - val_loss: 1.3842 - learning_rate: 5.0000e-05
# Epoch 10/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5993 - loss: 0.9942
# Epoch 10: saving model to model_init_2024-11-10_14_53_57.951236/model-00010-1.04191-0.59427-1.41779-0.52000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 188s 3s/step - categorical_accuracy: 0.5992 - loss: 0.9949 - val_categorical_accuracy: 0.5200 - val_loss: 1.4178 - learning_rate: 2.5000e-05
# Epoch 11/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6385 - loss: 0.9370
# Epoch 11: saving model to model_init_2024-11-10_14_53_57.951236/model-00011-0.95366-0.63801-1.34670-0.59000.keras
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 188s 3s/step - categorical_accuracy: 0.6385 - loss: 0.9373 - val_categorical_accuracy: 0.5900 - val_loss: 1.3467 - learning_rate: 2.5000e-05
# Epoch 12/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6122 - loss: 1.0061
# Epoch 12: saving model to model_init_2024-11-10_14_53_57.951236/model-00012-0.94199-0.64253-1.26828-0.58000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 187s 3s/step - categorical_accuracy: 0.6126 - loss: 1.0051 - val_categorical_accuracy: 0.5800 - val_loss: 1.2683 - learning_rate: 1.2500e-05
# Epoch 13/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6741 - loss: 0.8645
# Epoch 13: saving model to model_init_2024-11-10_14_53_57.951236/model-00013-0.84893-0.66365-1.36899-0.61000.keras
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 188s 3s/step - categorical_accuracy: 0.6740 - loss: 0.8643 - val_categorical_accuracy: 0.6100 - val_loss: 1.3690 - learning_rate: 1.2500e-05
# Epoch 14/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6571 - loss: 0.8649
# Epoch 14: saving model to model_init_2024-11-10_14_53_57.951236/model-00014-0.85164-0.66667-1.28382-0.60000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 187s 3s/step - categorical_accuracy: 0.6572 - loss: 0.8647 - val_categorical_accuracy: 0.6000 - val_loss: 1.2838 - learning_rate: 6.2500e-06
# Epoch 15/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6629 - loss: 0.8824
# Epoch 15: saving model to model_init_2024-11-10_14_53_57.951236/model-00015-0.85273-0.68326-1.32926-0.56000.keras
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 187s 3s/step - categorical_accuracy: 0.6632 - loss: 0.8819 - val_categorical_accuracy: 0.5600 - val_loss: 1.3293 - learning_rate: 6.2500e-06
# Epoch 16/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7165 - loss: 0.8158
# Epoch 16: saving model to model_init_2024-11-10_14_53_57.951236/model-00016-0.85045-0.68929-1.37610-0.57000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 186s 3s/step - categorical_accuracy: 0.7161 - loss: 0.8163 - val_categorical_accuracy: 0.5700 - val_loss: 1.3761 - learning_rate: 3.1250e-06
# Epoch 17/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6888 - loss: 0.7853
# Epoch 17: saving model to model_init_2024-11-10_14_53_57.951236/model-00017-0.80453-0.68929-1.46778-0.55000.keras
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 187s 3s/step - categorical_accuracy: 0.6888 - loss: 0.7856 - val_categorical_accuracy: 0.5500 - val_loss: 1.4678 - learning_rate: 3.1250e-06
# Epoch 18/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6623 - loss: 0.9077
# Epoch 18: saving model to model_init_2024-11-10_14_53_57.951236/model-00018-0.85741-0.68024-1.33900-0.56000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 189s 3s/step - categorical_accuracy: 0.6625 - loss: 0.9069 - val_categorical_accuracy: 0.5600 - val_loss: 1.3390 - learning_rate: 1.5625e-06
# Epoch 19/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6472 - loss: 0.8442
# Epoch 19: saving model to model_init_2024-11-10_14_53_57.951236/model-00019-0.84538-0.64404-1.40003-0.56000.keras
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 188s 3s/step - categorical_accuracy: 0.6471 - loss: 0.8442 - val_categorical_accuracy: 0.5600 - val_loss: 1.4000 - learning_rate: 1.5625e-06
# Epoch 20/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6873 - loss: 0.8445
# Epoch 20: saving model to model_init_2024-11-10_14_53_57.951236/model-00020-0.86271-0.67270-1.29780-0.61000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 188s 3s/step - categorical_accuracy: 0.6871 - loss: 0.8448 - val_categorical_accuracy: 0.6100 - val_loss: 1.2978 - learning_rate: 1.0000e-06

# %%
plot_training(history)

# %% [markdown]
# ### The pattern in the results suggests that while the model's training accuracy improves, the validation accuracy remains stagnant at around 50%. This hints at possible overfitting or issues in the model's capacity to generalize effectively. Here are some adjustments to try:
#
# Experiment with More Layers: Consider adding an additional Conv2D block with fewer filters (to keep memory usage in check) to capture more nuanced spatial features before passing data to the GRU.
#
# Reduce Conv2D Filter Sizes: Try smaller filter sizes (e.g., (3, 3) and (2, 2)) in initial layers to improve feature granularity.
#
# Tweak Dropout: Increasing dropout in both Conv2D and GRU layers can help generalization. Using SpatialDropout2D after Conv2D layers may also help, as it drops entire feature maps, encouraging robust feature extraction.
#
# Early Stop & LR Tuning: Since the learning rate already reduces, consider early stopping based on validation loss if the accuracy doesn't increase after a set number of epochs.

# %% [markdown]
# ## EXP 4 - Conv2D + GRU, more epochs, improved Generalization with SpacialDropout, an additional Conv2D layers

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import TimeDistributed, Conv2D, BatchNormalization, Activation, MaxPooling2D, Dropout, Flatten, GRU, Dense, SpatialDropout2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint

# Define input shape and parameters
input_shape = (20, 128, 128, 3)  #
num_classes = 5

# Initialize Sequential model
model = Sequential()

# First Conv2D Block
model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same', activation='relu'), input_shape=input_shape))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(SpatialDropout2D(0.2)))  # Improved generalization

# Second Conv2D Block
model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(SpatialDropout2D(0.3)))

# Third Conv2D Block (additional layer for deeper feature extraction)
model.add(TimeDistributed(Conv2D(128, (2, 2), padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(SpatialDropout2D(0.3)))

# Fourth Conv2D Block
model.add(TimeDistributed(Conv2D(256, (2, 2), padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Dropout(0.4)))

# Flatten and GRU
model.add(TimeDistributed(Flatten()))
model.add(GRU(128, return_sequences=False))
model.add(Dropout(0.5))

# Output Layer
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# Summary of the model
model.summary()
# Out:
# Model: "sequential_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed_174            │ (None, 20, 128, 128,   │           896 │
# │ (TimeDistributed)               │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_175            │ (None, 20, 128, 128,   │           128 │
# │ (TimeDistributed)               │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_176            │ (None, 20, 64, 64, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_177            │ (None, 20, 64, 64, 32) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_178            │ (None, 20, 64, 64, 64) │        18,496 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_179            │ (None, 20, 64, 64, 64) │           256 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_180            │ (None, 20, 32, 32, 64) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_181            │ (None, 20, 32, 32, 64) │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_182            │ (None, 20, 32, 32,     │        32,896 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_183            │ (None, 20, 32, 32,     │           512 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_184            │ (None, 20, 16, 16,     │             0 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_185            │ (None, 20, 16, 16,     │             0 │
# │ (TimeDistributed)               │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_186            │ (None, 20, 16, 16,     │       131,328 │
# │ (TimeDistributed)               │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_187            │ (None, 20, 16, 16,     │         1,024 │
# │ (TimeDistributed)               │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_188            │ (None, 20, 8, 8, 256)  │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_189            │ (None, 20, 8, 8, 256)  │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_190            │ (None, 20, 16384)      │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ (None, 128)            │     6,341,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_31 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,527,557 (24.90 MB)
#  Trainable params: 6,526,597 (24.90 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
#increase epochs
num_epochs = 40

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
curr_dt_time = datetime.datetime.now()
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','_').replace(':','_') + '/'

    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
#filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.keras'

#checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', save_freq='epoch')

#LR = # write the REducelronplateau code here
LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-6, verbose=1)
callbacks_list = [checkpoint, LR]

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

print(steps_per_epoch,validation_steps)
print(num_epochs)
# Out:
# 67 10
# 40

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                    callbacks=callbacks_list, validation_data=val_generator,
                    validation_steps=validation_steps, class_weight=None, initial_epoch=0)
# Out:
# Source path = C:\Users\admin\Vidhya\Project_data\train ; batch size = 10
# Number of folders: 663
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_2128\2155616922.py:40: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# Epoch 1/40
# 65/67 ━━━━━━━━━━━━━━━━━━━━ 5s 3s/step - categorical_accuracy: 0.2369 - loss: 2.0351
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_2128\2155616922.py:95: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.2382 - loss: 2.0306Source path = C:\Users\admin\Vidhya\Project_data\val ; batch size = 10
# Number of folders: 100
#
# Epoch 1: saving model to model_init_2024-11-10_16_00_54.000134/model-00001-1.88391-0.28054-1.20311-0.55000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 243s 3s/step - categorical_accuracy: 0.2389 - loss: 2.0284 - val_categorical_accuracy: 0.5500 - val_loss: 1.2031 - learning_rate: 1.0000e-04
# Epoch 2/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.3516 - loss: 1.6896
# Epoch 2: saving model to model_init_2024-11-10_16_00_54.000134/model-00002-1.70624-0.33484-1.29885-0.58000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 182s 3s/step - categorical_accuracy: 0.3513 - loss: 1.6899 - val_categorical_accuracy: 0.5800 - val_loss: 1.2989 - learning_rate: 1.0000e-04
# Epoch 3/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.4041 - loss: 1.5312
# Epoch 3: saving model to model_init_2024-11-10_16_00_54.000134/model-00003-1.46818-0.42836-1.23623-0.55000.keras
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 180s 3s/step - categorical_accuracy: 0.4045 - loss: 1.5302 - val_categorical_accuracy: 0.5500 - val_loss: 1.2362 - learning_rate: 1.0000e-04
# Epoch 4/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.4332 - loss: 1.4642
# Epoch 4: saving model to model_init_2024-11-10_16_00_54.000134/model-00004-1.38454-0.46908-1.16021-0.63000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 174s 3s/step - categorical_accuracy: 0.4337 - loss: 1.4631 - val_categorical_accuracy: 0.6300 - val_loss: 1.1602 - learning_rate: 5.0000e-05
# Epoch 5/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5251 - loss: 1.2239
# Epoch 5: saving model to model_init_2024-11-10_16_00_54.000134/model-00005-1.23614-0.50679-1.13528-0.59000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 179s 3s/step - categorical_accuracy: 0.5248 - loss: 1.2241 - val_categorical_accuracy: 0.5900 - val_loss: 1.1353 - learning_rate: 5.0000e-05
# Epoch 6/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.4966 - loss: 1.2899
# Epoch 6: saving model to model_init_2024-11-10_16_00_54.000134/model-00006-1.24221-0.51584-1.11099-0.65000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 176s 3s/step - categorical_accuracy: 0.4969 - loss: 1.2892 - val_categorical_accuracy: 0.6500 - val_loss: 1.1110 - learning_rate: 5.0000e-05
# Epoch 7/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5250 - loss: 1.2259
# Epoch 7: saving model to model_init_2024-11-10_16_00_54.000134/model-00007-1.18803-0.53695-1.18294-0.61000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 176s 3s/step - categorical_accuracy: 0.5252 - loss: 1.2253 - val_categorical_accuracy: 0.6100 - val_loss: 1.1829 - learning_rate: 5.0000e-05
# Epoch 8/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5345 - loss: 1.2143
# Epoch 8: saving model to model_init_2024-11-10_16_00_54.000134/model-00008-1.14139-0.56259-1.11183-0.63000.keras
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.5349 - loss: 1.2132 - val_categorical_accuracy: 0.6300 - val_loss: 1.1118 - learning_rate: 5.0000e-05
# Epoch 9/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5815 - loss: 1.0789
# Epoch 9: saving model to model_init_2024-11-10_16_00_54.000134/model-00009-1.06413-0.58824-1.12826-0.62000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 176s 3s/step - categorical_accuracy: 0.5816 - loss: 1.0787 - val_categorical_accuracy: 0.6200 - val_loss: 1.1283 - learning_rate: 2.5000e-05
# Epoch 10/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6232 - loss: 1.0071
# Epoch 10: saving model to model_init_2024-11-10_16_00_54.000134/model-00010-1.03980-0.59879-1.05264-0.65000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.6228 - loss: 1.0075 - val_categorical_accuracy: 0.6500 - val_loss: 1.0526 - learning_rate: 2.5000e-05
# Epoch 11/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6205 - loss: 0.9856
# Epoch 11: saving model to model_init_2024-11-10_16_00_54.000134/model-00011-1.01727-0.61991-1.12375-0.65000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 176s 3s/step - categorical_accuracy: 0.6205 - loss: 0.9861 - val_categorical_accuracy: 0.6500 - val_loss: 1.1237 - learning_rate: 2.5000e-05
# Epoch 12/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6278 - loss: 0.9248
# Epoch 12: saving model to model_init_2024-11-10_16_00_54.000134/model-00012-0.94604-0.62896-1.08565-0.64000.keras
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 176s 3s/step - categorical_accuracy: 0.6278 - loss: 0.9251 - val_categorical_accuracy: 0.6400 - val_loss: 1.0856 - learning_rate: 2.5000e-05
# Epoch 13/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6444 - loss: 0.9242
# Epoch 13: saving model to model_init_2024-11-10_16_00_54.000134/model-00013-0.94412-0.64103-1.06837-0.66000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 176s 3s/step - categorical_accuracy: 0.6444 - loss: 0.9245 - val_categorical_accuracy: 0.6600 - val_loss: 1.0684 - learning_rate: 1.2500e-05
# Epoch 14/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6264 - loss: 0.9659
# Epoch 14: saving model to model_init_2024-11-10_16_00_54.000134/model-00014-0.93363-0.64253-1.07178-0.65000.keras
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 177s 3s/step - categorical_accuracy: 0.6267 - loss: 0.9654 - val_categorical_accuracy: 0.6500 - val_loss: 1.0718 - learning_rate: 1.2500e-05
# Epoch 15/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6756 - loss: 0.8757
# Epoch 15: saving model to model_init_2024-11-10_16_00_54.000134/model-00015-0.90029-0.64857-1.04098-0.64000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 176s 3s/step - categorical_accuracy: 0.6752 - loss: 0.8761 - val_categorical_accuracy: 0.6400 - val_loss: 1.0410 - learning_rate: 6.2500e-06
# Epoch 16/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7106 - loss: 0.8675
# Epoch 16: saving model to model_init_2024-11-10_16_00_54.000134/model-00016-0.85142-0.69080-1.06023-0.64000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 176s 3s/step - categorical_accuracy: 0.7104 - loss: 0.8672 - val_categorical_accuracy: 0.6400 - val_loss: 1.0602 - learning_rate: 6.2500e-06
# Epoch 17/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6426 - loss: 0.9149
# Epoch 17: saving model to model_init_2024-11-10_16_00_54.000134/model-00017-0.88657-0.65309-1.07185-0.66000.keras
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.6428 - loss: 0.9145 - val_categorical_accuracy: 0.6600 - val_loss: 1.0719 - learning_rate: 6.2500e-06
# Epoch 18/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6660 - loss: 0.8659
# Epoch 18: saving model to model_init_2024-11-10_16_00_54.000134/model-00018-0.91968-0.62745-1.04351-0.65000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 176s 3s/step - categorical_accuracy: 0.6654 - loss: 0.8667 - val_categorical_accuracy: 0.6500 - val_loss: 1.0435 - learning_rate: 3.1250e-06
# Epoch 19/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6342 - loss: 0.8838
# Epoch 19: saving model to model_init_2024-11-10_16_00_54.000134/model-00019-0.87001-0.65762-1.09302-0.65000.keras
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 176s 3s/step - categorical_accuracy: 0.6346 - loss: 0.8835 - val_categorical_accuracy: 0.6500 - val_loss: 1.0930 - learning_rate: 3.1250e-06
# Epoch 20/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6742 - loss: 0.8929
# Epoch 20: saving model to model_init_2024-11-10_16_00_54.000134/model-00020-0.87983-0.66667-1.02611-0.63000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 176s 3s/step - categorical_accuracy: 0.6740 - loss: 0.8927 - val_categorical_accuracy: 0.6300 - val_loss: 1.0261 - learning_rate: 1.5625e-06
# Epoch 21/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6277 - loss: 0.8804
# Epoch 21: saving model to model_init_2024-11-10_16_00_54.000134/model-00021-0.86845-0.64706-1.07289-0.64000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.6279 - loss: 0.8803 - val_categorical_accuracy: 0.6400 - val_loss: 1.0729 - learning_rate: 1.5625e-06
# Epoch 22/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6794 - loss: 0.8689
# Epoch 22: saving model to model_init_2024-11-10_16_00_54.000134/model-00022-0.86155-0.67270-1.14894-0.63000.keras
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 176s 3s/step - categorical_accuracy: 0.6793 - loss: 0.8687 - val_categorical_accuracy: 0.6300 - val_loss: 1.1489 - learning_rate: 1.5625e-06
# Epoch 23/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6707 - loss: 0.8042
# Epoch 23: saving model to model_init_2024-11-10_16_00_54.000134/model-00023-0.82237-0.68326-1.00630-0.65000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 196s 3s/step - categorical_accuracy: 0.6709 - loss: 0.8045 - val_categorical_accuracy: 0.6500 - val_loss: 1.0063 - learning_rate: 1.0000e-06
# Epoch 24/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.6617 - loss: 0.8682
# Epoch 24: saving model to model_init_2024-11-10_16_00_54.000134/model-00024-0.87561-0.67270-1.08530-0.65000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 239s 4s/step - categorical_accuracy: 0.6619 - loss: 0.8684 - val_categorical_accuracy: 0.6500 - val_loss: 1.0853 - learning_rate: 1.0000e-06
# Epoch 25/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6629 - loss: 0.8681
# Epoch 25: saving model to model_init_2024-11-10_16_00_54.000134/model-00025-0.85040-0.67873-1.04314-0.65000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.6631 - loss: 0.8679 - val_categorical_accuracy: 0.6500 - val_loss: 1.0431 - learning_rate: 1.0000e-06
# Epoch 26/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6845 - loss: 0.8405
# Epoch 26: saving model to model_init_2024-11-10_16_00_54.000134/model-00026-0.83484-0.68024-1.03075-0.67000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.6844 - loss: 0.8404 - val_categorical_accuracy: 0.6700 - val_loss: 1.0308 - learning_rate: 1.0000e-06
# Epoch 27/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6813 - loss: 0.8701
# Epoch 27: saving model to model_init_2024-11-10_16_00_54.000134/model-00027-0.86181-0.67119-1.05664-0.66000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 176s 3s/step - categorical_accuracy: 0.6812 - loss: 0.8700 - val_categorical_accuracy: 0.6600 - val_loss: 1.0566 - learning_rate: 1.0000e-06
# Epoch 28/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6622 - loss: 0.9011
# Epoch 28: saving model to model_init_2024-11-10_16_00_54.000134/model-00028-0.84448-0.69985-1.09807-0.66000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.6628 - loss: 0.9003 - val_categorical_accuracy: 0.6600 - val_loss: 1.0981 - learning_rate: 1.0000e-06
# Epoch 29/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6344 - loss: 0.9207
# Epoch 29: saving model to model_init_2024-11-10_16_00_54.000134/model-00029-0.87569-0.66817-1.02398-0.68000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.6349 - loss: 0.9201 - val_categorical_accuracy: 0.6800 - val_loss: 1.0240 - learning_rate: 1.0000e-06
# Epoch 30/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6672 - loss: 0.8432
# Epoch 30: saving model to model_init_2024-11-10_16_00_54.000134/model-00030-0.83427-0.67421-1.06925-0.67000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.6673 - loss: 0.8430 - val_categorical_accuracy: 0.6700 - val_loss: 1.0692 - learning_rate: 1.0000e-06
# Epoch 31/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6372 - loss: 0.9377
# Epoch 31: saving model to model_init_2024-11-10_16_00_54.000134/model-00031-0.86460-0.65762-1.08517-0.65000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 176s 3s/step - categorical_accuracy: 0.6375 - loss: 0.9366 - val_categorical_accuracy: 0.6500 - val_loss: 1.0852 - learning_rate: 1.0000e-06
# Epoch 32/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6700 - loss: 0.8518
# Epoch 32: saving model to model_init_2024-11-10_16_00_54.000134/model-00032-0.82300-0.68929-1.10207-0.70000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.6703 - loss: 0.8514 - val_categorical_accuracy: 0.7000 - val_loss: 1.1021 - learning_rate: 1.0000e-06
# Epoch 33/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6839 - loss: 0.8011
# Epoch 33: saving model to model_init_2024-11-10_16_00_54.000134/model-00033-0.83846-0.67873-1.05276-0.63000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 176s 3s/step - categorical_accuracy: 0.6839 - loss: 0.8016 - val_categorical_accuracy: 0.6300 - val_loss: 1.0528 - learning_rate: 1.0000e-06
# Epoch 34/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6653 - loss: 0.8495
# Epoch 34: saving model to model_init_2024-11-10_16_00_54.000134/model-00034-0.84231-0.66365-1.03199-0.65000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 176s 3s/step - categorical_accuracy: 0.6653 - loss: 0.8494 - val_categorical_accuracy: 0.6500 - val_loss: 1.0320 - learning_rate: 1.0000e-06
# Epoch 35/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6547 - loss: 0.8524
# Epoch 35: saving model to model_init_2024-11-10_16_00_54.000134/model-00035-0.84036-0.65762-1.06383-0.65000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.6548 - loss: 0.8523 - val_categorical_accuracy: 0.6500 - val_loss: 1.0638 - learning_rate: 1.0000e-06
# Epoch 36/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7057 - loss: 0.8655
# Epoch 36: saving model to model_init_2024-11-10_16_00_54.000134/model-00036-0.83736-0.70739-1.11495-0.65000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 175s 3s/step - categorical_accuracy: 0.7057 - loss: 0.8651 - val_categorical_accuracy: 0.6500 - val_loss: 1.1149 - learning_rate: 1.0000e-06
# Epoch 37/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6567 - loss: 0.8753
# Epoch 37: saving model to model_init_2024-11-10_16_00_54.000134/model-00037-0.86788-0.66063-1.05891-0.67000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 174s 3s/step - categorical_accuracy: 0.6568 - loss: 0.8752 - val_categorical_accuracy: 0.6700 - val_loss: 1.0589 - learning_rate: 1.0000e-06
# Epoch 38/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6552 - loss: 0.8505
# Epoch 38: saving model to model_init_2024-11-10_16_00_54.000134/model-00038-0.85924-0.64253-1.04219-0.66000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 177s 3s/step - categorical_accuracy: 0.6550 - loss: 0.8506 - val_categorical_accuracy: 0.6600 - val_loss: 1.0422 - learning_rate: 1.0000e-06
# Epoch 39/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6586 - loss: 0.8569
# Epoch 39: saving model to model_init_2024-11-10_16_00_54.000134/model-00039-0.85959-0.65309-1.07562-0.64000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 176s 3s/step - categorical_accuracy: 0.6586 - loss: 0.8569 - val_categorical_accuracy: 0.6400 - val_loss: 1.0756 - learning_rate: 1.0000e-06
# Epoch 40/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6361 - loss: 0.8897
# Epoch 40: saving model to model_init_2024-11-10_16_00_54.000134/model-00040-0.86971-0.66063-1.05819-0.66000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 176s 3s/step - categorical_accuracy: 0.6365 - loss: 0.8894 - val_categorical_accuracy: 0.6600 - val_loss: 1.0582 - learning_rate: 1.0000e-06

# %%
plot_training(history)

# %% [markdown]
# ### Results: Training accuracy improved substancially to 86%, but validation accuracy is ppears to be plateauing around 72-73%.
#
# Will try Conv3d with some adjustments 1) Add a bit more frames 20 to 22 2) Finetune ReduceLROnPlateau, increase patience for stability 3) Try Conv3D

# %% [markdown]
# ## Experiment 5 - Conv3D

# %%
from tensorflow.keras.layers import Conv3D, MaxPooling3D, BatchNormalization, Dropout, Flatten, Dense


# Define input shape and parameters
input_shape = (22, 128, 128, 3)  # Adjust as per frame count, image size, and channels
num_classes = 5

# Initialize Sequential model
model = Sequential()

# First Conv3D Block
model.add(Conv3D(32, (3, 3, 3), activation='relu', padding='same', input_shape=input_shape))
model.add(BatchNormalization())
model.add(MaxPooling3D((2, 2, 2)))
model.add(Dropout(0.2))

# Second Conv3D Block
model.add(Conv3D(64, (3, 3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling3D((2, 2, 2)))
model.add(Dropout(0.3))

# Third Conv3D Block
model.add(Conv3D(128, (2, 2, 2), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling3D((2, 2, 2)))
model.add(Dropout(0.3))

# Fourth Conv3D Block
model.add(Conv3D(256, (2, 2, 2), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling3D((2, 2, 2)))
model.add(Dropout(0.4))

# Flatten and Fully Connected Layers
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_17"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d_8 (Conv3D)               │ (None, 22, 128, 128,   │         2,624 │
# │                                 │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_48          │ (None, 22, 128, 128,   │           128 │
# │ (BatchNormalization)            │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_8 (MaxPooling3D)  │ (None, 11, 64, 64, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_42 (Dropout)            │ (None, 11, 64, 64, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_9 (Conv3D)               │ (None, 11, 64, 64, 64) │        55,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_49          │ (None, 11, 64, 64, 64) │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_9 (MaxPooling3D)  │ (None, 5, 32, 32, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_43 (Dropout)            │ (None, 5, 32, 32, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_10 (Conv3D)              │ (None, 5, 32, 32, 128) │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_50          │ (None, 5, 32, 32, 128) │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_10 (MaxPooling3D) │ (None, 2, 16, 16, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_44 (Dropout)            │ (None, 2, 16, 16, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_11 (Conv3D)              │ (None, 2, 16, 16, 256) │       262,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_51          │ (None, 2, 16, 16, 256) │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_11 (MaxPooling3D) │ (None, 1, 8, 8, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_45 (Dropout)            │ (None, 1, 8, 8, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_16 (Flatten)            │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 512)            │     8,389,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_46 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 5)              │         2,565 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,779,653 (33.49 MB)
#  Trainable params: 8,778,693 (33.49 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
# Fine-tuned ReduceLROnPlateau for gradual learning rate adjustment
LR = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,       # Slightly more conservative reduction
    patience=5,       # Increased patience for stability
    min_lr=1e-6,
    verbose=1
)

checkpoint = ModelCheckpoint(filepath='model_init_{epoch:05d}-{loss:.5f}-{accuracy:.5f}-{val_loss:.5f}-{val_accuracy:.5f}.keras',
                             save_best_only=True,
                             monitor='val_loss',
                             mode='min',
                             verbose=1)

callbacks_list = [checkpoint, LR]

# %%
curr_dt_time = datetime.datetime.now()
train_path = r'C:\Users\admin\Vidhya\Project_data\train'
val_path = r'C:\Users\admin\Vidhya\Project_data\val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 40
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 40

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
#curr_dt_time = datetime.datetime.now()
#model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','_').replace(':','_') + '/'

    
#if not os.path.exists(model_name):
#    os.mkdir(model_name)
        
#filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'
#filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.keras'

#checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)
#checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', save_freq='epoch')

#LR = # write the REducelronplateau code here
#LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-6, verbose=1)
#callbacks_list = [checkpoint, LR]

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

print(steps_per_epoch,validation_steps)
# Out:
# 67 10

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                    callbacks=callbacks_list, validation_data=val_generator,
                    validation_steps=validation_steps, class_weight=None, initial_epoch=0)
# Out:
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_2128\2155616922.py:40: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# Epoch 1/40
# 63/67 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - accuracy: 0.7161 - loss: 0.6041
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_2128\2155616922.py:95: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7168 - loss: 0.6042
# Epoch 1: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 115s 2s/step - accuracy: 0.7170 - loss: 0.6042 - val_accuracy: 0.6100 - val_loss: 2.0814 - learning_rate: 3.1250e-05
# Epoch 2/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7556 - loss: 0.5614
# Epoch 2: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 114s 2s/step - accuracy: 0.7555 - loss: 0.5615 - val_accuracy: 0.5500 - val_loss: 2.8057 - learning_rate: 3.1250e-05
# Epoch 3/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7067 - loss: 0.6347
# Epoch 3: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 112s 2s/step - accuracy: 0.7070 - loss: 0.6342 - val_accuracy: 0.5500 - val_loss: 2.9184 - learning_rate: 3.1250e-05
# Epoch 4/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7677 - loss: 0.5520
# Epoch 4: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.7677 - loss: 0.5519 - val_accuracy: 0.5500 - val_loss: 2.1805 - learning_rate: 3.1250e-05
# Epoch 5/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7513 - loss: 0.5373
# Epoch 5: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 112s 2s/step - accuracy: 0.7514 - loss: 0.5374 - val_accuracy: 0.5400 - val_loss: 2.7247 - learning_rate: 3.1250e-05
# Epoch 6/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7337 - loss: 0.6069
# Epoch 6: val_loss did not improve from 1.59633
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.7338 - loss: 0.6062 - val_accuracy: 0.6000 - val_loss: 2.7210 - learning_rate: 3.1250e-05
# Epoch 7/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7351 - loss: 0.5731
# Epoch 7: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.7351 - loss: 0.5729 - val_accuracy: 0.5800 - val_loss: 2.0411 - learning_rate: 1.5625e-05
# Epoch 8/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7637 - loss: 0.5686
# Epoch 8: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.7637 - loss: 0.5686 - val_accuracy: 0.5900 - val_loss: 2.5592 - learning_rate: 1.5625e-05
# Epoch 9/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7292 - loss: 0.5467
# Epoch 9: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.7294 - loss: 0.5470 - val_accuracy: 0.5800 - val_loss: 2.2881 - learning_rate: 1.5625e-05
# Epoch 10/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7252 - loss: 0.5988
# Epoch 10: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 109s 2s/step - accuracy: 0.7251 - loss: 0.5986 - val_accuracy: 0.5600 - val_loss: 2.2008 - learning_rate: 1.5625e-05
# Epoch 11/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7707 - loss: 0.5213
# Epoch 11: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.7706 - loss: 0.5215 - val_accuracy: 0.5500 - val_loss: 2.5243 - learning_rate: 1.5625e-05
# Epoch 12/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7837 - loss: 0.5639
# Epoch 12: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.7836 - loss: 0.5638 - val_accuracy: 0.5600 - val_loss: 1.9384 - learning_rate: 1.5625e-05
# Epoch 13/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7443 - loss: 0.5636
# Epoch 13: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.7444 - loss: 0.5632 - val_accuracy: 0.5900 - val_loss: 2.8544 - learning_rate: 1.5625e-05
# Epoch 14/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7475 - loss: 0.5209
# Epoch 14: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.7477 - loss: 0.5210 - val_accuracy: 0.5400 - val_loss: 3.1977 - learning_rate: 1.5625e-05
# Epoch 15/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7800 - loss: 0.5124
# Epoch 15: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.7799 - loss: 0.5125 - val_accuracy: 0.6000 - val_loss: 2.4854 - learning_rate: 1.5625e-05
# Epoch 16/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7391 - loss: 0.5415
# Epoch 16: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.7391 - loss: 0.5416 - val_accuracy: 0.6000 - val_loss: 2.5289 - learning_rate: 1.5625e-05
# Epoch 17/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7406 - loss: 0.5350
# Epoch 17: val_loss did not improve from 1.59633
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.7408 - loss: 0.5350 - val_accuracy: 0.5500 - val_loss: 2.3459 - learning_rate: 1.5625e-05
# Epoch 18/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7497 - loss: 0.5846
# Epoch 18: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.7500 - loss: 0.5839 - val_accuracy: 0.5500 - val_loss: 2.8478 - learning_rate: 7.8125e-06
# Epoch 19/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7813 - loss: 0.5221
# Epoch 19: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.7812 - loss: 0.5221 - val_accuracy: 0.6100 - val_loss: 1.8856 - learning_rate: 7.8125e-06
# Epoch 20/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7614 - loss: 0.5295
# Epoch 20: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.7616 - loss: 0.5294 - val_accuracy: 0.5800 - val_loss: 2.1710 - learning_rate: 7.8125e-06
# Epoch 21/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7694 - loss: 0.5166
# Epoch 21: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.7695 - loss: 0.5166 - val_accuracy: 0.6100 - val_loss: 3.2045 - learning_rate: 7.8125e-06
# Epoch 22/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7637 - loss: 0.5607
# Epoch 22: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.7637 - loss: 0.5603 - val_accuracy: 0.5200 - val_loss: 2.4932 - learning_rate: 7.8125e-06
# Epoch 23/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7782 - loss: 0.5060
# Epoch 23: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 111s 2s/step - accuracy: 0.7781 - loss: 0.5062 - val_accuracy: 0.6300 - val_loss: 2.4699 - learning_rate: 7.8125e-06
# Epoch 24/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8065 - loss: 0.4604
# Epoch 24: val_loss did not improve from 1.59633
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.8058 - loss: 0.4611 - val_accuracy: 0.5200 - val_loss: 2.0164 - learning_rate: 7.8125e-06
# Epoch 25/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7463 - loss: 0.5727
# Epoch 25: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.7468 - loss: 0.5719 - val_accuracy: 0.5700 - val_loss: 3.1436 - learning_rate: 3.9063e-06
# Epoch 26/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7807 - loss: 0.5140
# Epoch 26: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.7809 - loss: 0.5137 - val_accuracy: 0.6000 - val_loss: 2.1040 - learning_rate: 3.9063e-06
# Epoch 27/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7495 - loss: 0.5488
# Epoch 27: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.7497 - loss: 0.5490 - val_accuracy: 0.5500 - val_loss: 2.9123 - learning_rate: 3.9063e-06
# Epoch 28/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7533 - loss: 0.5688
# Epoch 28: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 109s 2s/step - accuracy: 0.7531 - loss: 0.5688 - val_accuracy: 0.5100 - val_loss: 2.8936 - learning_rate: 3.9063e-06
# Epoch 29/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7884 - loss: 0.4703
# Epoch 29: val_loss did not improve from 1.59633
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 109s 2s/step - accuracy: 0.7881 - loss: 0.4708 - val_accuracy: 0.5900 - val_loss: 2.3034 - learning_rate: 3.9063e-06
# Epoch 30/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7937 - loss: 0.4840
# Epoch 30: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 109s 2s/step - accuracy: 0.7933 - loss: 0.4847 - val_accuracy: 0.6000 - val_loss: 2.4555 - learning_rate: 1.9531e-06
# Epoch 31/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7719 - loss: 0.5408
# Epoch 31: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 109s 2s/step - accuracy: 0.7717 - loss: 0.5409 - val_accuracy: 0.5900 - val_loss: 1.8192 - learning_rate: 1.9531e-06
# Epoch 32/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7495 - loss: 0.5474
# Epoch 32: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 114s 2s/step - accuracy: 0.7497 - loss: 0.5473 - val_accuracy: 0.5100 - val_loss: 3.1208 - learning_rate: 1.9531e-06
# Epoch 33/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7632 - loss: 0.5113
# Epoch 33: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.7631 - loss: 0.5118 - val_accuracy: 0.6100 - val_loss: 2.7371 - learning_rate: 1.9531e-06
# Epoch 34/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8018 - loss: 0.4746
# Epoch 34: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.8015 - loss: 0.4750 - val_accuracy: 0.6000 - val_loss: 2.0143 - learning_rate: 1.9531e-06
# Epoch 35/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7616 - loss: 0.5390
# Epoch 35: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.7617 - loss: 0.5388 - val_accuracy: 0.5100 - val_loss: 2.8502 - learning_rate: 1.9531e-06
# Epoch 36/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7959 - loss: 0.4784
# Epoch 36: val_loss did not improve from 1.59633
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 111s 2s/step - accuracy: 0.7955 - loss: 0.4790 - val_accuracy: 0.6100 - val_loss: 2.3993 - learning_rate: 1.9531e-06
# Epoch 37/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7763 - loss: 0.5309
# Epoch 37: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.7763 - loss: 0.5307 - val_accuracy: 0.5700 - val_loss: 2.8390 - learning_rate: 1.0000e-06
# Epoch 38/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7509 - loss: 0.5586
# Epoch 38: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.7509 - loss: 0.5586 - val_accuracy: 0.5700 - val_loss: 1.9668 - learning_rate: 1.0000e-06
# Epoch 39/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7321 - loss: 0.5911
# Epoch 39: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 109s 2s/step - accuracy: 0.7322 - loss: 0.5906 - val_accuracy: 0.5800 - val_loss: 2.3272 - learning_rate: 1.0000e-06
# Epoch 40/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7451 - loss: 0.5251
# Epoch 40: val_loss did not improve from 1.59633
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 109s 2s/step - accuracy: 0.7450 - loss: 0.5253 - val_accuracy: 0.5600 - val_loss: 2.5304 - learning_rate: 1.0000e-06

# %% [markdown]
# ### It looks like model has a good start but is struggling to generalize to the validation set, resulting in a high validation loss and inconsistent validation accuracy. This issue often arises due to overfitting or insufficient feature extraction in earlier layers.
#
# Add more convolutional layers , increase filter sizes Add a TimeDistributed Layer with an RNN Lower Dropout Values
#
# learning rate might be too high even with ReduceLROnPlateau

# %% [markdown]
# ## Exp 6 - Conv3D + RNN

# %% [markdown]
# #### starting with a slightly lower initial learning rate, such as 1e-4 Decrease patience

# %%
from tensorflow.keras.layers import Conv3D, MaxPooling3D, BatchNormalization, Dropout, Flatten, Dense, TimeDistributed, GRU
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

# Define input shape and parameters
input_shape = (22, 128, 128, 3)  # Adjust as per frame count, image size, and channels
num_classes = 5

# Initialize Sequential model
model = Sequential()

# Conv3D Blocks
model.add(Conv3D(32, (3, 3, 3), activation='relu', padding='same', input_shape=input_shape))
model.add(BatchNormalization())
model.add(MaxPooling3D((2, 2, 2)))
model.add(Dropout(0.2))

model.add(Conv3D(64, (3, 3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling3D((2, 2, 2)))
model.add(Dropout(0.3))

model.add(Conv3D(128, (3, 3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling3D((2, 2, 2)))
model.add(Dropout(0.3))

model.add(Conv3D(256, (3, 3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling3D((2, 2, 2)))
model.add(Dropout(0.4))

# Adding TimeDistributed wrapper and RNN for temporal features
model.add(TimeDistributed(Flatten()))
model.add(GRU(128, return_sequences=False, dropout=0.3))

# Fully Connected Layers
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# %%
# Compile the model
optimizer = Adam(learning_rate=1e-4)  # Lower initial learning rate for gradual optimization
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_21"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d_24 (Conv3D)              │ (None, 22, 128, 128,   │         2,624 │
# │                                 │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_64          │ (None, 22, 128, 128,   │           128 │
# │ (BatchNormalization)            │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_24 (MaxPooling3D) │ (None, 11, 64, 64, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_62 (Dropout)            │ (None, 11, 64, 64, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_25 (Conv3D)              │ (None, 11, 64, 64, 64) │        55,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_65          │ (None, 11, 64, 64, 64) │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_25 (MaxPooling3D) │ (None, 5, 32, 32, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_63 (Dropout)            │ (None, 5, 32, 32, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_26 (Conv3D)              │ (None, 5, 32, 32, 128) │       221,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_66          │ (None, 5, 32, 32, 128) │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_26 (MaxPooling3D) │ (None, 2, 16, 16, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_64 (Dropout)            │ (None, 2, 16, 16, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_27 (Conv3D)              │ (None, 2, 16, 16, 256) │       884,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_67          │ (None, 2, 16, 16, 256) │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_27 (MaxPooling3D) │ (None, 1, 8, 8, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_65 (Dropout)            │ (None, 1, 8, 8, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_194            │ (None, 1, 16384)       │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_6 (GRU)                     │ (None, 128)            │     6,341,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 512)            │        66,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_66 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_27 (Dense)                │ (None, 5)              │         2,565 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,576,197 (28.90 MB)
#  Trainable params: 7,575,237 (28.90 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
# Callbacks
LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1)
checkpoint = ModelCheckpoint(filepath='model_best.keras', save_best_only=True, monitor='val_loss', mode='min', verbose=1)
callbacks_list = [checkpoint, LR]

# %%
curr_dt_time = datetime.datetime.now()
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','_').replace(':','_') + '/'

    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
#filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{accuracy:.5f}-{val_loss:.5f}-{val_accuracy:.5f}.keras'

#checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', save_freq='epoch')

#LR = # write the REducelronplateau code here
LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-6, verbose=1)
callbacks_list = [checkpoint, LR]

# %%
# Model Training
history = model.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=num_epochs,
    callbacks=callbacks_list,
    validation_data=val_generator,
    validation_steps=validation_steps,
    class_weight=None,
    initial_epoch=0
)
# Out:
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_2128\2155616922.py:40: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# Epoch 1/40
# 55/67 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.1712 - loss: 1.6871
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_2128\2155616922.py:95: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1748 - loss: 1.6835
# Epoch 1: saving model to model_init_2024-11-10_22_30_06.897262/model-00001-1.66226-0.20211-1.60818-0.23000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.1752 - loss: 1.6832 - val_accuracy: 0.2300 - val_loss: 1.6082 - learning_rate: 1.0000e-04
# Epoch 2/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2041 - loss: 1.6535
# Epoch 2: saving model to model_init_2024-11-10_22_30_06.897262/model-00002-1.63328-0.22021-1.61613-0.18000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 110s 2s/step - accuracy: 0.2043 - loss: 1.6532 - val_accuracy: 0.1800 - val_loss: 1.6161 - learning_rate: 1.0000e-04
# Epoch 3/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2587 - loss: 1.5976
# Epoch 3: saving model to model_init_2024-11-10_22_30_06.897262/model-00003-1.58696-0.26546-1.59733-0.25000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 111s 2s/step - accuracy: 0.2588 - loss: 1.5975 - val_accuracy: 0.2500 - val_loss: 1.5973 - learning_rate: 1.0000e-04
# Epoch 4/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3120 - loss: 1.5503
# Epoch 4: saving model to model_init_2024-11-10_22_30_06.897262/model-00004-1.52917-0.33032-1.56773-0.24000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - accuracy: 0.3123 - loss: 1.5500 - val_accuracy: 0.2400 - val_loss: 1.5677 - learning_rate: 1.0000e-04
# Epoch 5/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3386 - loss: 1.5061
# Epoch 5: saving model to model_init_2024-11-10_22_30_06.897262/model-00005-1.49485-0.34992-1.57029-0.27000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 127s 2s/step - accuracy: 0.3387 - loss: 1.5059 - val_accuracy: 0.2700 - val_loss: 1.5703 - learning_rate: 1.0000e-04
# Epoch 6/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3394 - loss: 1.4803
# Epoch 6: saving model to model_init_2024-11-10_22_30_06.897262/model-00006-1.45208-0.36048-1.50291-0.30000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 128s 2s/step - accuracy: 0.3398 - loss: 1.4799 - val_accuracy: 0.3000 - val_loss: 1.5029 - learning_rate: 1.0000e-04
# Epoch 7/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4307 - loss: 1.3858
# Epoch 7: saving model to model_init_2024-11-10_22_30_06.897262/model-00007-1.37740-0.42534-1.58600-0.27000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 129s 2s/step - accuracy: 0.4306 - loss: 1.3857 - val_accuracy: 0.2700 - val_loss: 1.5860 - learning_rate: 1.0000e-04
# Epoch 8/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4250 - loss: 1.3634
# Epoch 8: saving model to model_init_2024-11-10_22_30_06.897262/model-00008-1.35051-0.42986-1.59733-0.33000.keras
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 128s 2s/step - accuracy: 0.4251 - loss: 1.3632 - val_accuracy: 0.3300 - val_loss: 1.5973 - learning_rate: 1.0000e-04
# Epoch 9/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4966 - loss: 1.2613
# Epoch 9: saving model to model_init_2024-11-10_22_30_06.897262/model-00009-1.24266-0.50980-1.64627-0.31000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 129s 2s/step - accuracy: 0.4968 - loss: 1.2610 - val_accuracy: 0.3100 - val_loss: 1.6463 - learning_rate: 5.0000e-05
# Epoch 10/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4752 - loss: 1.2627
# Epoch 10: saving model to model_init_2024-11-10_22_30_06.897262/model-00010-1.24386-0.48567-1.65896-0.31000.keras
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 128s 2s/step - accuracy: 0.4754 - loss: 1.2624 - val_accuracy: 0.3100 - val_loss: 1.6590 - learning_rate: 5.0000e-05
# Epoch 11/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5369 - loss: 1.1660
# Epoch 11: saving model to model_init_2024-11-10_22_30_06.897262/model-00011-1.16928-0.53997-1.62728-0.34000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.5369 - loss: 1.1661 - val_accuracy: 0.3400 - val_loss: 1.6273 - learning_rate: 2.5000e-05
# Epoch 12/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5170 - loss: 1.1761
# Epoch 12: saving model to model_init_2024-11-10_22_30_06.897262/model-00012-1.15835-0.54751-1.61006-0.31000.keras
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.5175 - loss: 1.1758 - val_accuracy: 0.3100 - val_loss: 1.6101 - learning_rate: 2.5000e-05
# Epoch 13/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5315 - loss: 1.1470
# Epoch 13: saving model to model_init_2024-11-10_22_30_06.897262/model-00013-1.15659-0.54600-1.68621-0.33000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.5317 - loss: 1.1471 - val_accuracy: 0.3300 - val_loss: 1.6862 - learning_rate: 1.2500e-05
# Epoch 14/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5705 - loss: 1.0760
# Epoch 14: saving model to model_init_2024-11-10_22_30_06.897262/model-00014-1.10878-0.55807-1.65311-0.33000.keras
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.5703 - loss: 1.0764 - val_accuracy: 0.3300 - val_loss: 1.6531 - learning_rate: 1.2500e-05
# Epoch 15/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6044 - loss: 1.0974
# Epoch 15: saving model to model_init_2024-11-10_22_30_06.897262/model-00015-1.11169-0.58522-1.63699-0.32000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.6041 - loss: 1.0976 - val_accuracy: 0.3200 - val_loss: 1.6370 - learning_rate: 6.2500e-06
# Epoch 16/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5676 - loss: 1.1169
# Epoch 16: saving model to model_init_2024-11-10_22_30_06.897262/model-00016-1.11162-0.57919-1.67512-0.34000.keras
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.5678 - loss: 1.1168 - val_accuracy: 0.3400 - val_loss: 1.6751 - learning_rate: 6.2500e-06
# Epoch 17/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5649 - loss: 1.0980
# Epoch 17: saving model to model_init_2024-11-10_22_30_06.897262/model-00017-1.10226-0.56410-1.67491-0.32000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - accuracy: 0.5649 - loss: 1.0981 - val_accuracy: 0.3200 - val_loss: 1.6749 - learning_rate: 3.1250e-06
# Epoch 18/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6166 - loss: 1.0602
# Epoch 18: saving model to model_init_2024-11-10_22_30_06.897262/model-00018-1.08181-0.59427-1.65826-0.32000.keras
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - accuracy: 0.6162 - loss: 1.0605 - val_accuracy: 0.3200 - val_loss: 1.6583 - learning_rate: 3.1250e-06
# Epoch 19/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5353 - loss: 1.1141
# Epoch 19: saving model to model_init_2024-11-10_22_30_06.897262/model-00019-1.09901-0.55354-1.66661-0.34000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - accuracy: 0.5356 - loss: 1.1139 - val_accuracy: 0.3400 - val_loss: 1.6666 - learning_rate: 1.5625e-06
# Epoch 20/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5642 - loss: 1.0955
# Epoch 20: saving model to model_init_2024-11-10_22_30_06.897262/model-00020-1.09859-0.57466-1.67625-0.31000.keras
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.5643 - loss: 1.0955 - val_accuracy: 0.3100 - val_loss: 1.6762 - learning_rate: 1.5625e-06
# Epoch 21/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5722 - loss: 1.0826
# Epoch 21: saving model to model_init_2024-11-10_22_30_06.897262/model-00021-1.10817-0.56410-1.65848-0.35000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.5721 - loss: 1.0830 - val_accuracy: 0.3500 - val_loss: 1.6585 - learning_rate: 1.0000e-06
# Epoch 22/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5322 - loss: 1.0957
# Epoch 22: saving model to model_init_2024-11-10_22_30_06.897262/model-00022-1.11094-0.54902-1.63494-0.34000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.5325 - loss: 1.0960 - val_accuracy: 0.3400 - val_loss: 1.6349 - learning_rate: 1.0000e-06
# Epoch 23/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6060 - loss: 1.0651
# Epoch 23: saving model to model_init_2024-11-10_22_30_06.897262/model-00023-1.07856-0.59125-1.63944-0.34000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.6058 - loss: 1.0653 - val_accuracy: 0.3400 - val_loss: 1.6394 - learning_rate: 1.0000e-06
# Epoch 24/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5748 - loss: 1.1081
# Epoch 24: saving model to model_init_2024-11-10_22_30_06.897262/model-00024-1.10447-0.57617-1.65393-0.35000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.5748 - loss: 1.1081 - val_accuracy: 0.3500 - val_loss: 1.6539 - learning_rate: 1.0000e-06
# Epoch 25/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5702 - loss: 1.0764
# Epoch 25: saving model to model_init_2024-11-10_22_30_06.897262/model-00025-1.09119-0.58069-1.60318-0.37000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - accuracy: 0.5704 - loss: 1.0766 - val_accuracy: 0.3700 - val_loss: 1.6032 - learning_rate: 1.0000e-06
# Epoch 26/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5631 - loss: 1.0892
# Epoch 26: saving model to model_init_2024-11-10_22_30_06.897262/model-00026-1.08905-0.56109-1.65226-0.34000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.5631 - loss: 1.0892 - val_accuracy: 0.3400 - val_loss: 1.6523 - learning_rate: 1.0000e-06
# Epoch 27/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5612 - loss: 1.1112
# Epoch 27: saving model to model_init_2024-11-10_22_30_06.897262/model-00027-1.11107-0.56712-1.65556-0.35000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - accuracy: 0.5613 - loss: 1.1112 - val_accuracy: 0.3500 - val_loss: 1.6556 - learning_rate: 1.0000e-06
# Epoch 28/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5347 - loss: 1.0985
# Epoch 28: saving model to model_init_2024-11-10_22_30_06.897262/model-00028-1.10196-0.53544-1.67079-0.35000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.5347 - loss: 1.0986 - val_accuracy: 0.3500 - val_loss: 1.6708 - learning_rate: 1.0000e-06
# Epoch 29/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5657 - loss: 1.1134
# Epoch 29: saving model to model_init_2024-11-10_22_30_06.897262/model-00029-1.07733-0.59276-1.65001-0.34000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - accuracy: 0.5661 - loss: 1.1129 - val_accuracy: 0.3400 - val_loss: 1.6500 - learning_rate: 1.0000e-06
# Epoch 30/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5624 - loss: 1.1042
# Epoch 30: saving model to model_init_2024-11-10_22_30_06.897262/model-00030-1.10811-0.57164-1.65413-0.34000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.5625 - loss: 1.1043 - val_accuracy: 0.3400 - val_loss: 1.6541 - learning_rate: 1.0000e-06
# Epoch 31/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5806 - loss: 1.0948
# Epoch 31: saving model to model_init_2024-11-10_22_30_06.897262/model-00031-1.09038-0.57617-1.66200-0.36000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.5805 - loss: 1.0947 - val_accuracy: 0.3600 - val_loss: 1.6620 - learning_rate: 1.0000e-06
# Epoch 32/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5330 - loss: 1.1117
# Epoch 32: saving model to model_init_2024-11-10_22_30_06.897262/model-00032-1.07972-0.55958-1.64909-0.36000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.5334 - loss: 1.1112 - val_accuracy: 0.3600 - val_loss: 1.6491 - learning_rate: 1.0000e-06
# Epoch 33/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5724 - loss: 1.0920
# Epoch 33: saving model to model_init_2024-11-10_22_30_06.897262/model-00033-1.08194-0.57466-1.64092-0.35000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.5724 - loss: 1.0918 - val_accuracy: 0.3500 - val_loss: 1.6409 - learning_rate: 1.0000e-06
# Epoch 34/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5593 - loss: 1.1035
# Epoch 34: saving model to model_init_2024-11-10_22_30_06.897262/model-00034-1.08517-0.57466-1.66462-0.35000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.5595 - loss: 1.1033 - val_accuracy: 0.3500 - val_loss: 1.6646 - learning_rate: 1.0000e-06
# Epoch 35/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5673 - loss: 1.0764
# Epoch 35: saving model to model_init_2024-11-10_22_30_06.897262/model-00035-1.09679-0.56109-1.65207-0.33000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.5672 - loss: 1.0767 - val_accuracy: 0.3300 - val_loss: 1.6521 - learning_rate: 1.0000e-06
# Epoch 36/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5628 - loss: 1.0907
# Epoch 36: saving model to model_init_2024-11-10_22_30_06.897262/model-00036-1.09037-0.56863-1.65464-0.35000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.5629 - loss: 1.0907 - val_accuracy: 0.3500 - val_loss: 1.6546 - learning_rate: 1.0000e-06
# Epoch 37/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5673 - loss: 1.0768
# Epoch 37: saving model to model_init_2024-11-10_22_30_06.897262/model-00037-1.09892-0.56109-1.65132-0.35000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.5672 - loss: 1.0771 - val_accuracy: 0.3500 - val_loss: 1.6513 - learning_rate: 1.0000e-06
# Epoch 38/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5825 - loss: 1.1092
# Epoch 38: saving model to model_init_2024-11-10_22_30_06.897262/model-00038-1.05965-0.59578-1.67633-0.33000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.5827 - loss: 1.1085 - val_accuracy: 0.3300 - val_loss: 1.6763 - learning_rate: 1.0000e-06
# Epoch 39/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5387 - loss: 1.1076
# Epoch 39: saving model to model_init_2024-11-10_22_30_06.897262/model-00039-1.11596-0.53846-1.67038-0.34000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - accuracy: 0.5387 - loss: 1.1077 - val_accuracy: 0.3400 - val_loss: 1.6704 - learning_rate: 1.0000e-06
# Epoch 40/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6111 - loss: 1.0366
# Epoch 40: saving model to model_init_2024-11-10_22_30_06.897262/model-00040-1.06258-0.59578-1.67401-0.37000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.6108 - loss: 1.0369 - val_accuracy: 0.3700 - val_loss: 1.6740 - learning_rate: 1.0000e-06

# %%
# Plotting function
def plot_training_conv3d(history):
    plt.figure(figsize=(12, 6))

    # Plot accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Training and Validation Accuracy')

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Training and Validation Loss')

    plt.show()

plot_training_conv3d(history)

# %% [markdown]
# #### Overfitting: Training accuracy reaches ~56% while validation accuracy stays around 34-44% Validation loss often increases while training loss decreases Large gap between training and validation metrics
#
# Analysis Looks like model is complex Four Conv3D layers might be excessive The architecture might be learning noise rather than meaningful features.

# %%
#Simlified architecture with early stopping

input_shape = (22, 128, 128, 3)  # Your current input shape
num_classes = 5

# Initialize Sequential model
model = Sequential()

# First Conv3D Block
model.add(Conv3D(32, (3, 3, 3), activation='relu', padding='same', input_shape=input_shape))
model.add(BatchNormalization())
model.add(MaxPooling3D((2, 2, 2)))
model.add(Dropout(0.3))

# Second Conv3D Block
model.add(Conv3D(64, (3, 3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling3D((2, 2, 2)))
model.add(Dropout(0.4))

# Flatten and RNN
model.add(TimeDistributed(Flatten()))
model.add(GRU(64, dropout=0.3))

# Dense Layers
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# %%
# Compile the model
optimizer = Adam(learning_rate=5e-4)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_22"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d_28 (Conv3D)              │ (None, 22, 128, 128,   │         2,624 │
# │                                 │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_68          │ (None, 22, 128, 128,   │           128 │
# │ (BatchNormalization)            │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_28 (MaxPooling3D) │ (None, 11, 64, 64, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_67 (Dropout)            │ (None, 11, 64, 64, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_29 (Conv3D)              │ (None, 11, 64, 64, 64) │        55,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_69          │ (None, 11, 64, 64, 64) │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_29 (MaxPooling3D) │ (None, 5, 32, 32, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_68 (Dropout)            │ (None, 5, 32, 32, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_195            │ (None, 5, 65536)       │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_7 (GRU)                     │ (None, 64)             │    12,595,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_69 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,662,917 (48.31 MB)
#  Trainable params: 12,662,725 (48.30 MB)
#  Non-trainable params: 192 (768.00 B)

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

##

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

print(steps_per_epoch,validation_steps)
print(num_epochs)
# Out:
# 67 10
# 40

# %%
# Define callbacks
LR = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=4,
    min_lr=1e-6,
    verbose=1
)

checkpoint = ModelCheckpoint(
    filepath='model_best.keras',
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

# Combine all callbacks
callbacks_list = [LR, checkpoint]

# %%
curr_dt_time = datetime.datetime.now()
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','_').replace(':','_') + '/'

    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
#filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{accuracy:.5f}-{val_loss:.5f}-{val_accuracy:.5f}.keras'

#checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', save_freq='epoch')

#LR = # write the REducelronplateau code here
LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-6, verbose=1)
callbacks_list = [checkpoint, LR]

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                    callbacks=callbacks_list, validation_data=val_generator,
                    validation_steps=validation_steps, class_weight=None, initial_epoch=0)
# Out:
# Source path = C:\Users\admin\Vidhya\Project_data\train ; batch size = 10
# Number of folders: 663
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_2128\2155616922.py:40: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# Epoch 1/40
# 65/67 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - accuracy: 0.1820 - loss: 1.8004
# C:\Users\admin\AppData\Local\Temp\2\ipykernel_2128\2155616922.py:95: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(os.path.join(folder_path, imgs[item])).astype(np.float32)
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1821 - loss: 1.7990Source path = C:\Users\admin\Vidhya\Project_data\val ; batch size = 10
# Number of folders: 100
#
# Epoch 1: saving model to model_init_2024-11-10_23_53_30.899750/model-00001-1.75363-0.18250-1.60508-0.26000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 126s 2s/step - accuracy: 0.1821 - loss: 1.7983 - val_accuracy: 0.2600 - val_loss: 1.6051 - learning_rate: 5.0000e-04
# Epoch 2/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2155 - loss: 1.6864
# Epoch 2: saving model to model_init_2024-11-10_23_53_30.899750/model-00002-1.67692-0.21870-1.59334-0.25000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.2155 - loss: 1.6863 - val_accuracy: 0.2500 - val_loss: 1.5933 - learning_rate: 5.0000e-04
# Epoch 3/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1946 - loss: 1.6396
# Epoch 3: saving model to model_init_2024-11-10_23_53_30.899750/model-00003-1.62180-0.21569-1.59842-0.19000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.1949 - loss: 1.6394 - val_accuracy: 0.1900 - val_loss: 1.5984 - learning_rate: 5.0000e-04
# Epoch 4/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2607 - loss: 1.5859
# Epoch 4: saving model to model_init_2024-11-10_23_53_30.899750/model-00004-1.57601-0.26546-1.59685-0.22000.keras
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 112s 2s/step - accuracy: 0.2607 - loss: 1.5857 - val_accuracy: 0.2200 - val_loss: 1.5969 - learning_rate: 5.0000e-04
# Epoch 5/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2828 - loss: 1.5808
# Epoch 5: saving model to model_init_2024-11-10_23_53_30.899750/model-00005-1.59200-0.25792-1.55837-0.27000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 118s 2s/step - accuracy: 0.2825 - loss: 1.5810 - val_accuracy: 0.2700 - val_loss: 1.5584 - learning_rate: 2.5000e-04
# Epoch 6/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2807 - loss: 1.5590
# Epoch 6: saving model to model_init_2024-11-10_23_53_30.899750/model-00006-1.56401-0.28507-1.53162-0.32000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - accuracy: 0.2808 - loss: 1.5591 - val_accuracy: 0.3200 - val_loss: 1.5316 - learning_rate: 2.5000e-04
# Epoch 7/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2742 - loss: 1.5490
# Epoch 7: saving model to model_init_2024-11-10_23_53_30.899750/model-00007-1.55543-0.26546-1.54181-0.28000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - accuracy: 0.2740 - loss: 1.5491 - val_accuracy: 0.2800 - val_loss: 1.5418 - learning_rate: 2.5000e-04
# Epoch 8/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3171 - loss: 1.5416
# Epoch 8: saving model to model_init_2024-11-10_23_53_30.899750/model-00008-1.54387-0.30317-1.56914-0.25000.keras
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 115s 2s/step - accuracy: 0.3169 - loss: 1.5416 - val_accuracy: 0.2500 - val_loss: 1.5691 - learning_rate: 2.5000e-04
# Epoch 9/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2982 - loss: 1.5585
# Epoch 9: saving model to model_init_2024-11-10_23_53_30.899750/model-00009-1.54517-0.31071-1.53335-0.41000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - accuracy: 0.2984 - loss: 1.5583 - val_accuracy: 0.4100 - val_loss: 1.5334 - learning_rate: 1.2500e-04
# Epoch 10/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2830 - loss: 1.5328
# Epoch 10: saving model to model_init_2024-11-10_23_53_30.899750/model-00010-1.52882-0.30769-1.50824-0.44000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 115s 2s/step - accuracy: 0.2833 - loss: 1.5327 - val_accuracy: 0.4400 - val_loss: 1.5082 - learning_rate: 1.2500e-04
# Epoch 11/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3656 - loss: 1.5011
# Epoch 11: saving model to model_init_2024-11-10_23_53_30.899750/model-00011-1.51855-0.33786-1.50668-0.35000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - accuracy: 0.3652 - loss: 1.5014 - val_accuracy: 0.3500 - val_loss: 1.5067 - learning_rate: 1.2500e-04
# Epoch 12/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3709 - loss: 1.5033
# Epoch 12: saving model to model_init_2024-11-10_23_53_30.899750/model-00012-1.50150-0.35143-1.48894-0.46000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 115s 2s/step - accuracy: 0.3706 - loss: 1.5033 - val_accuracy: 0.4600 - val_loss: 1.4889 - learning_rate: 1.2500e-04
# Epoch 13/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3420 - loss: 1.5051
# Epoch 13: saving model to model_init_2024-11-10_23_53_30.899750/model-00013-1.49597-0.33786-1.47567-0.47000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 115s 2s/step - accuracy: 0.3420 - loss: 1.5050 - val_accuracy: 0.4700 - val_loss: 1.4757 - learning_rate: 1.2500e-04
# Epoch 14/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4245 - loss: 1.4207
# Epoch 14: saving model to model_init_2024-11-10_23_53_30.899750/model-00014-1.45859-0.37707-1.47778-0.42000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - accuracy: 0.4238 - loss: 1.4212 - val_accuracy: 0.4200 - val_loss: 1.4778 - learning_rate: 1.2500e-04
# Epoch 15/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4100 - loss: 1.4468
# Epoch 15: saving model to model_init_2024-11-10_23_53_30.899750/model-00015-1.45262-0.39517-1.45776-0.45000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - accuracy: 0.4098 - loss: 1.4469 - val_accuracy: 0.4500 - val_loss: 1.4578 - learning_rate: 1.2500e-04
# Epoch 16/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4237 - loss: 1.4316
# Epoch 16: saving model to model_init_2024-11-10_23_53_30.899750/model-00016-1.44370-0.40121-1.41593-0.49000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - accuracy: 0.4233 - loss: 1.4318 - val_accuracy: 0.4900 - val_loss: 1.4159 - learning_rate: 1.2500e-04
# Epoch 17/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4156 - loss: 1.4227
# Epoch 17: saving model to model_init_2024-11-10_23_53_30.899750/model-00017-1.41079-0.40875-1.40708-0.48000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - accuracy: 0.4155 - loss: 1.4225 - val_accuracy: 0.4800 - val_loss: 1.4071 - learning_rate: 1.2500e-04
# Epoch 18/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4059 - loss: 1.4051
# Epoch 18: saving model to model_init_2024-11-10_23_53_30.899750/model-00018-1.39682-0.41478-1.39048-0.53000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 115s 2s/step - accuracy: 0.4060 - loss: 1.4050 - val_accuracy: 0.5300 - val_loss: 1.3905 - learning_rate: 1.2500e-04
# Epoch 19/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4169 - loss: 1.3996
# Epoch 19: saving model to model_init_2024-11-10_23_53_30.899750/model-00019-1.39628-0.41026-1.35763-0.44000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 115s 2s/step - accuracy: 0.4168 - loss: 1.3995 - val_accuracy: 0.4400 - val_loss: 1.3576 - learning_rate: 1.2500e-04
# Epoch 20/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4265 - loss: 1.3780
# Epoch 20: saving model to model_init_2024-11-10_23_53_30.899750/model-00020-1.35750-0.46154-1.35709-0.55000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - accuracy: 0.4270 - loss: 1.3777 - val_accuracy: 0.5500 - val_loss: 1.3571 - learning_rate: 1.2500e-04
# Epoch 21/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4186 - loss: 1.3779
# Epoch 21: saving model to model_init_2024-11-10_23_53_30.899750/model-00021-1.38173-0.41780-1.34396-0.55000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - accuracy: 0.4186 - loss: 1.3779 - val_accuracy: 0.5500 - val_loss: 1.3440 - learning_rate: 1.2500e-04
# Epoch 22/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4441 - loss: 1.3677
# Epoch 22: saving model to model_init_2024-11-10_23_53_30.899750/model-00022-1.34837-0.46757-1.39402-0.50000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - accuracy: 0.4445 - loss: 1.3674 - val_accuracy: 0.5000 - val_loss: 1.3940 - learning_rate: 1.2500e-04
# Epoch 23/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4370 - loss: 1.3415
# Epoch 23: saving model to model_init_2024-11-10_23_53_30.899750/model-00023-1.34038-0.45249-1.30165-0.50000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 115s 2s/step - accuracy: 0.4372 - loss: 1.3415 - val_accuracy: 0.5000 - val_loss: 1.3016 - learning_rate: 1.2500e-04
# Epoch 24/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4845 - loss: 1.3158
# Epoch 24: saving model to model_init_2024-11-10_23_53_30.899750/model-00024-1.32178-0.46908-1.39075-0.37000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 115s 2s/step - accuracy: 0.4843 - loss: 1.3159 - val_accuracy: 0.3700 - val_loss: 1.3907 - learning_rate: 1.2500e-04
# Epoch 25/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4261 - loss: 1.3617
# Epoch 25: saving model to model_init_2024-11-10_23_53_30.899750/model-00025-1.33864-0.44042-1.31513-0.49000.keras
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 115s 2s/step - accuracy: 0.4263 - loss: 1.3613 - val_accuracy: 0.4900 - val_loss: 1.3151 - learning_rate: 1.2500e-04
# Epoch 26/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4746 - loss: 1.2714
# Epoch 26: saving model to model_init_2024-11-10_23_53_30.899750/model-00026-1.26845-0.49774-1.26477-0.55000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 115s 2s/step - accuracy: 0.4749 - loss: 1.2713 - val_accuracy: 0.5500 - val_loss: 1.2648 - learning_rate: 6.2500e-05
# Epoch 27/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4969 - loss: 1.2635
# Epoch 27: saving model to model_init_2024-11-10_23_53_30.899750/model-00027-1.25864-0.48416-1.27393-0.56000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 114s 2s/step - accuracy: 0.4967 - loss: 1.2634 - val_accuracy: 0.5600 - val_loss: 1.2739 - learning_rate: 6.2500e-05
# Epoch 28/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4682 - loss: 1.2643
# Epoch 28: saving model to model_init_2024-11-10_23_53_30.899750/model-00028-1.27052-0.45701-1.24465-0.57000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 115s 2s/step - accuracy: 0.4681 - loss: 1.2644 - val_accuracy: 0.5700 - val_loss: 1.2447 - learning_rate: 6.2500e-05
# Epoch 29/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5417 - loss: 1.1798
# Epoch 29: saving model to model_init_2024-11-10_23_53_30.899750/model-00029-1.23394-0.51282-1.23830-0.55000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 114s 2s/step - accuracy: 0.5413 - loss: 1.1806 - val_accuracy: 0.5500 - val_loss: 1.2383 - learning_rate: 6.2500e-05
# Epoch 30/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5319 - loss: 1.1925
# Epoch 30: saving model to model_init_2024-11-10_23_53_30.899750/model-00030-1.18233-0.54148-1.20181-0.56000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 117s 2s/step - accuracy: 0.5320 - loss: 1.1923 - val_accuracy: 0.5600 - val_loss: 1.2018 - learning_rate: 6.2500e-05
# Epoch 31/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5719 - loss: 1.1509
# Epoch 31: saving model to model_init_2024-11-10_23_53_30.899750/model-00031-1.18045-0.56109-1.20552-0.55000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 115s 2s/step - accuracy: 0.5717 - loss: 1.1513 - val_accuracy: 0.5500 - val_loss: 1.2055 - learning_rate: 6.2500e-05
# Epoch 32/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5398 - loss: 1.1864
# Epoch 32: saving model to model_init_2024-11-10_23_53_30.899750/model-00032-1.16831-0.54299-1.17976-0.59000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 115s 2s/step - accuracy: 0.5399 - loss: 1.1861 - val_accuracy: 0.5900 - val_loss: 1.1798 - learning_rate: 6.2500e-05
# Epoch 33/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5677 - loss: 1.1812
# Epoch 33: saving model to model_init_2024-11-10_23_53_30.899750/model-00033-1.15204-0.57617-1.15174-0.58000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 114s 2s/step - accuracy: 0.5678 - loss: 1.1808 - val_accuracy: 0.5800 - val_loss: 1.1517 - learning_rate: 6.2500e-05
# Epoch 34/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5596 - loss: 1.1502
# Epoch 34: saving model to model_init_2024-11-10_23_53_30.899750/model-00034-1.18240-0.53997-1.15571-0.54000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 115s 2s/step - accuracy: 0.5594 - loss: 1.1506 - val_accuracy: 0.5400 - val_loss: 1.1557 - learning_rate: 6.2500e-05
# Epoch 35/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5526 - loss: 1.1129
# Epoch 35: saving model to model_init_2024-11-10_23_53_30.899750/model-00035-1.13227-0.54299-1.19299-0.59000.keras
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 115s 2s/step - accuracy: 0.5524 - loss: 1.1132 - val_accuracy: 0.5900 - val_loss: 1.1930 - learning_rate: 6.2500e-05
# Epoch 36/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6025 - loss: 1.0965
# Epoch 36: saving model to model_init_2024-11-10_23_53_30.899750/model-00036-1.11771-0.58522-1.11941-0.60000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 114s 2s/step - accuracy: 0.6022 - loss: 1.0968 - val_accuracy: 0.6000 - val_loss: 1.1194 - learning_rate: 3.1250e-05
# Epoch 37/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6028 - loss: 1.0666
# Epoch 37: saving model to model_init_2024-11-10_23_53_30.899750/model-00037-1.10041-0.59427-1.14985-0.58000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 114s 2s/step - accuracy: 0.6027 - loss: 1.0671 - val_accuracy: 0.5800 - val_loss: 1.1499 - learning_rate: 3.1250e-05
# Epoch 38/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5683 - loss: 1.1280
# Epoch 38: saving model to model_init_2024-11-10_23_53_30.899750/model-00038-1.08270-0.59125-1.16523-0.54000.keras
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 114s 2s/step - accuracy: 0.5686 - loss: 1.1273 - val_accuracy: 0.5400 - val_loss: 1.1652 - learning_rate: 3.1250e-05
# Epoch 39/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6180 - loss: 1.0794
# Epoch 39: saving model to model_init_2024-11-10_23_53_30.899750/model-00039-1.07252-0.62443-1.17113-0.57000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 114s 2s/step - accuracy: 0.6181 - loss: 1.0793 - val_accuracy: 0.5700 - val_loss: 1.1711 - learning_rate: 1.5625e-05
# Epoch 40/40
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6275 - loss: 1.0420
# Epoch 40: saving model to model_init_2024-11-10_23_53_30.899750/model-00040-1.05866-0.60784-1.14516-0.57000.keras
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 114s 2s/step - accuracy: 0.6272 - loss: 1.0422 - val_accuracy: 0.5700 - val_loss: 1.1452 - learning_rate: 1.5625e-05

# %%
plot_training_conv3d(history)

# %%
Adding more layers,
# Out:
#   Cell In[142], line 1
#     Adding more layers,
#            ^
# SyntaxError: invalid syntax

# %%
'''from tensorflow.keras.models import Sequential
#from tensorflow.keras.layers import Conv3D, BatchNormalization, MaxPooling3D, Dropout
from tensorflow.keras.layers import Flatten, GRU, Dense, GlobalAveragePooling3D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint

# Define input shape and parameters
input_shape = (22, 128, 128, 3)
num_classes = 5

# Initialize Sequential model
model = Sequential([
    # First Conv3D Block
    Conv3D(64, kernel_size=(3, 3, 3), activation='relu', padding='same',
           input_shape=input_shape, kernel_initializer='he_normal'),
    BatchNormalization(),
    Conv3D(64, kernel_size=(3, 3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling3D(pool_size=(1, 2, 2)),
    Dropout(0.25),

    # Second Conv3D Block
    Conv3D(128, kernel_size=(3, 3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    Conv3D(128, kernel_size=(3, 3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling3D(pool_size=(1, 2, 2)),
    Dropout(0.25),

    # Third Conv3D Block
    Conv3D(256, kernel_size=(3, 3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    Conv3D(256, kernel_size=(3, 3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling3D(pool_size=(1, 2, 2)),
    Dropout(0.25),

    # Fourth Conv3D Block
    Conv3D(512, kernel_size=(3, 3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    Conv3D(512, kernel_size=(3, 3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling3D(pool_size=(1, 2, 2)),
    Dropout(0.25),

    # Fifth Conv3D Block - Added for more feature extraction
    Conv3D(512, kernel_size=(3, 3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    Conv3D(512, kernel_size=(3, 3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling3D(pool_size=(2, 2, 2)),  # Now we reduce temporal dimension
    Dropout(0.25),

    # Global Average Pooling
    GlobalAveragePooling3D(),

    # Dense layers with residual connections
    Dense(1024, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),

    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),

    Dense(num_classes, activation='softmax')
])

# Compile with optimized learning rate and gradient clipping
optimizer = Adam(learning_rate=0.0001, clipnorm=1.0)
model.compile(optimizer=optimizer,
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# Enhanced callbacks for better training
callbacks = [
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.2,
        patience=5,
        min_lr=1e-7,
        verbose=1
    ),
    ModelCheckpoint(
        filepath='model_best.keras',
        save_best_only=True,
        monitor='val_loss',
        mode='min',
        verbose=1
    )
]'''
# Out:
# "from tensorflow.keras.models import Sequential\n#from tensorflow.keras.layers import Conv3D, BatchNormalization, MaxPooling3D, Dropout\nfrom tensorflow.keras.layers import Flatten, GRU, Dense, GlobalAveragePooling3D\nfrom tensorflow.keras.optimizers import Adam\nfrom tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint\n\n# Define input shape and parameters\ninput_shape = (22, 128, 128, 3)\nnum_classes = 5\n\n# Initialize Sequential model\nmodel = Sequential([\n    # First Conv3D Block\n    Conv3D(64, kernel_size=(3, 3, 3), activation='relu', padding='same',\n           input_shape=input_shape, kernel_initializer='he_normal'),\n    BatchNormalization(),\n    Conv3D(64, kernel_size=(3, 3, 3), activation='relu', padding='same'),\n    BatchNormalization(),\n    MaxPooling3D(pool_size=(1, 2, 2)),\n    Dropout(0.25),\n\n    # Second Conv3D Block\n    Conv3D(128, kernel_size=(3, 3, 3), activation='relu', padding='same'),\n    BatchNormalization(),\n    Conv3D(128, kernel_size=(3, 3, 3), activation='relu', padding='same'),\n    BatchNormalization(),\n    MaxPooling3D(pool_size=(1, 2, 2)),\n    Dropout(0.25),\n\n    # Third Conv3D Block\n    Conv3D(256, kernel_size=(3, 3, 3), activation='relu', padding='same'),\n    BatchNormalization(),\n    Conv3D(256, kernel_size=(3, 3, 3), activation='relu', padding='same'),\n    BatchNormalization(),\n    MaxPooling3D(pool_size=(1, 2, 2)),\n    Dropout(0.25),\n\n    # Fourth Conv3D Block\n    Conv3D(512, kernel_size=(3, 3, 3), activation='relu', padding='same'),\n    BatchNormalization(),\n    Conv3D(512, kernel_size=(3, 3, 3), activation='relu', padding='same'),\n    BatchNormalization(),\n    MaxPooling3D(pool_size=(1, 2, 2)),\n    Dropout(0.25),\n\n    # Fifth Conv3D Block - Added for more feature extraction\n    Conv3D(512, kernel_size=(3, 3, 3), activation='relu', padding='same'),\n    BatchNormalization(),\n    Conv3D(512, kernel_size=(3, 3, 3), activation='relu', padding='same'),\n    BatchNormalization(),\n    MaxPooling3D(pool_size=(2, 2, 2)),  # Now we reduce temporal dimension\n    Dropout(0.25),\n\n    # Global Average Pooling\n    GlobalAveragePooling3D(),\n\n    # Dense layers with residual connections\n    Dense(1024, activation='relu'),\n    BatchNormalization(),\n    Dropout(0.5),\n\n    Dense(512, activation='relu'),\n    BatchNormalization(),\n    Dropout(0.5),\n\n    Dense(num_classes, activation='softmax')\n])\n\n# Compile with optimized learning rate and gradient clipping\noptimizer = Adam(learning_rate=0.0001, clipnorm=1.0)\nmodel.compile(optimizer=optimizer,\n             loss='categorical_crossentropy',\n             metrics=['accuracy'])\n\n# Enhanced callbacks for better training\ncallbacks = [\n    ReduceLROnPlateau(\n        monitor='val_loss',\n        factor=0.2,\n        patience=5,\n        min_lr=1e-7,\n        verbose=1\n    ),\n    ModelCheckpoint(\n        filepath='model_best.keras',\n        save_best_only=True,\n        monitor='val_loss',\n        mode='min',\n        verbose=1\n    )\n]"

# %%
#model.summary()

# %% [markdown]
# ### Double-click (or enter) to edit

# %% [markdown]
# ### Final Analysis
# Throughout our experiments, the Conv2D + GRU architecture emerged as the most effective model for our gesture recognition task. By selecting 20 frames, increasing the epochs to 40, and balancing model complexity with regularization, we achieved a substantial improvement in validation accuracy, reaching approximately 72%.
#
# Frame Selection & Epochs: Increasing the number of frames and epochs proved crucial in enhancing model performance, as it provided a richer temporal context and allowed the model more time to converge.
# Simplified Architecture with GRU: While LSTMs struggled to generalize well on data, GRUs maintained a balance, leading to better validation performance.
# Regularization & Dropout: Regularization techniques like Dropout effectively reduced overfitting, particularly in complex architectures.
# Avoiding Overly Complex Layers: Deeper architectures with multiple Conv3D layers and high frame counts tended to overfit, learning noise rather than valuable features. Simplified Conv2D layers with GRU performed best by capturing temporal dynamics without excessive complexity. Future improvements could include fine-tuning hyperparameters, experimenting with slightly lower batch sizes (if memory allows), and using techniques like learning rate scheduling to further refine convergence. Looks like, complex architectures often introduce noise, reaffirming that simpler, well-regularized models are often more robust for this type of sequential data.
